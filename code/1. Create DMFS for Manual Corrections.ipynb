# %% [markdown]
# # First Notebook: Create DMFS

# %% [markdown]
# The purpose of this Notebook is to create DM-FS by merging the three crowdsourced databases together, using Fatally Shot Civilians from 1 January 2015 until 31 December 2020. The code will highlight any discrepancy found within the databases. The end result of this notebook will be a DM-FS that needs manual corrections, as well as a list of manual corrections that need to be made.

# %% [markdown]
# # 0 | Imports & Settings

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import Counter # Unique value ID

# %%
from thefuzz import fuzz
import math

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # 1 | Loads & Cleans Datasets

# %% [markdown]
# Loads & Subsets all 3 DFs | Handles NAs | Recodes so their names are consistent

# %% [markdown]
# ### 1.1 | Loads DFs

# %% [markdown]
# Loads data, ensures column names are consistent, filters only relevant deaths (non-suicides, gunshots), and ensures deaths are within date range

# %%
# Loads DFs
DIR_DATABASE = "res/1.0 - Original Fatal Shooting Databases/"
fe = pd.read_csv(f"{DIR_DATABASE}db_FE.csv", low_memory = False)
mpv = pd.read_csv(f"{DIR_DATABASE}db_MPV.csv")
wp= pd.read_csv(f"{DIR_DATABASE}db_WP.csv")

# %%
# Subsets MPV to just include fatal shootings. FE will be subsetted later, after it undergoes preprocessing
mpv = mpv[ mpv["cause_of_death"] == "Gunshot"]

# %%
# COLUMNS

# Subset databases to only those columns we need
fe = fe[ [' Date of injury resulting in death (month/day/year)', 'Name', 'Age', 'Gender', 'Race', 'Location of death (city)', 'State', 'Agency or agencies involved', 'Supporting document link'] ]
mpv = mpv[ ['date', 'name', 'age', 'gender', 'race', 'city', 'state', 'agency_responsible', 'news_urls', ] ]
wp = wp[ ['date', 'name', 'age', 'gender', 'race', 'city', 'state', 'agency_ids',] ]
wp["URL"] = "None"

# Makes col names consistent between databases
COL_NAMES = ['date', 'victim_name', 'victim_age', 'victim_gender', 'victim_race', 'city_of_death', 'state_of_death', 'agency_responsible', "URL"]
fe.columns = COL_NAMES
mpv.columns = COL_NAMES
wp.columns = COL_NAMES

# %%
# DATES

# Converts dates to proper datatype
fe['date'] = pd.to_datetime(fe['date'])
mpv['date'] = pd.to_datetime(mpv['date'])
wp['date'] = pd.to_datetime(wp['date'])

# Filters dates to only include deaths from Jan 1, 2015 until December 31, 2020
fe = fe[ (fe['date'] >= '2015-01-01') & (fe['date'] <= '2020-12-31') ]
mpv = mpv[ (mpv['date'] >= '2015-01-01') & (mpv['date'] <= '2020-12-31') ]
wp = wp[ (wp['date'] >= '2015-01-01') & (wp['date'] <= '2020-12-31') ]

# Ensures the most recent date comes first in all the databases, followed by name in alpha order
fe = fe.sort_values(by=['date', 'victim_name'], ascending=[False, True])
mpw = mpv.sort_values(by=['date', 'victim_name'], ascending=[False, True] )
wp = wp.sort_values(by=['date', 'victim_name'], ascending=[False, True] )

# %% [markdown]
# ### 1.2 | Handles missing values

# %%
# Prints missing values
print("FE")
print(fe.isna().sum())

print("\nMPV")
print(mpv.isna().sum())

print("\nWP")
print(wp.isna().sum())
# Out:
# FE
# date                    0
# victim_name             0
# victim_age            526
# victim_gender          54
# victim_race             0
# city_of_death           3
# state_of_death          0
# agency_responsible      3
# URL                     0
# dtype: int64
#
# MPV
# date                    0
# victim_name             0
# victim_age            232
# victim_gender           0
# victim_race             1
# city_of_death           4
# state_of_death          0
# agency_responsible      1
# URL                     0
# dtype: int64
#
# WP
# date                    0
# victim_name           140
# victim_age            170
# victim_gender           1
# victim_race           395
# city_of_death           1
# state_of_death          0
# agency_responsible      0
# URL                     0
# dtype: int64

# %%
# Replaces misisng lEAs with 'Unknown'
fe['agency_responsible'] = fe['agency_responsible'].replace('', 'Unknown')
fe['agency_responsible'] = fe['agency_responsible'].fillna('Unknown')

mpv['agency_responsible'] = mpv['agency_responsible'].replace('', 'Unknown')
mpv['agency_responsible'] = mpv['agency_responsible'].fillna('Unknown')

wp['agency_responsible'] = wp['agency_responsible'].replace('', -1) # WP uses internal LEA codes, not text, to ID LEAs

# %%
# Replaces an unknown victim age with -1

fe['victim_age'] = pd.to_numeric(fe['victim_age'], errors='coerce')
fe['victim_age'] = fe['victim_age'].fillna(-1.0)
fe['victim_age'] = fe['victim_age'].astype(int)

mpv['victim_age'] = pd.to_numeric(mpv['victim_age'], errors='coerce')
mpv['victim_age'] = mpv['victim_age'].fillna(-1.0)
mpv['victim_age'] = mpv['victim_age'].astype(int)


wp['victim_age'] = pd.to_numeric(wp['victim_age'], errors='coerce')
wp['victim_age'] = wp['victim_age'].fillna(-1.0)
wp['victim_age'] = wp['victim_age'].astype(int)

# %%
# Replaces missing values with "Unknown" string for all remaining columns

# Victim Name
wp['victim_name'] = wp['victim_name'].fillna("Unknown")

# Victim Gender
fe['victim_gender'] = fe['victim_gender'].fillna("Unknown")
mpv['victim_gender'] = mpv['victim_gender'].fillna("Unknown")
wp['victim_gender'] = wp['victim_gender'].fillna("Unknown")

# Victim Race
mpv['victim_race'] = mpv['victim_race'].fillna("Unknown")
wp['victim_race'] = wp['victim_race'].fillna("Unknown")

# City of Death
fe['city_of_death'] = fe['city_of_death'].fillna("Unknown")
mpv['city_of_death'] = mpv['city_of_death'].fillna("Unknown")
wp['city_of_death'] = wp['city_of_death'].fillna("Unknown")

# Staet of Death
fe['state_of_death'] = fe['state_of_death'].fillna("Unknown")
mpv['state_of_death'] = mpv['state_of_death'].fillna("Unknown")
wp['state_of_death'] = wp['state_of_death'].fillna("Unknown")

# %%
# Prints missing values
assert(fe.isna().sum().eq(0).all() )
assert(mpv.isna().sum().eq(0).all() )
assert(wp.isna().sum().eq(0).all() )
print("All assertions passed. There are no NAs in any of the subsetted dataframes")
# Out:
# All assertions passed. There are no NAs in any of the subsetted dataframes

# %% [markdown]
# ### 1.3 | Remaps Datasets so they all have Consistent Values

# %% [markdown]
# e.g., all datasets will list the same races, genders, etc.

# %%
def print_vals(df_dict, col_to_print):
    for name, df in df_dict.items():
        print(f"Print database [{name}]")
        print(df[col_to_print].value_counts())
        print()

# %%
# GENDER

# Remaps WP Gender so it's consistent with FE & WP
wp['victim_gender'] = wp['victim_gender'].replace( {"male" : "Male", "female" : "Female"} )
print_vals( {"fe" : fe, "mpv" : mpv, "wp" : wp}, 'victim_gender')
# Out:
# Print database [fe]
# victim_gender
# Male           9662
# Female         1039
# Unknown          54
# Transgender      14
# Name: count, dtype: int64
#
# Print database [mpv]
# victim_gender
# Male           5757
# Female          293
# Transgender       9
# Unknown           4
# Name: count, dtype: int64
#
# Print database [wp]
# victim_gender
# Male       5685
# Female      260
# Unknown       1
# Name: count, dtype: int64

# %%
# RACE

# Remaps Race so names are consistent
fe['victim_race'] = fe['victim_race'].replace( {"European-American/White" : "White", 
                                                "African-American/Black" : "Black",
                                               "Hispanic/Latino" : "Hispanic",
                                               "Race unspecified" : "Unknown",
                                               "Asian/Pacific Islander" : "Asian & Pacific Islander",
                                               "Native American/Alaskan" : "Native American", 
                                               "Middle Eastern" : "Other"} )

wp['victim_race'] = wp['victim_race'].replace( {"W" : "White",
                                               "B" : "Black",
                                               "H" : "Hispanic",
                                               "A" : "Asian & Pacific Islander",
                                               "N" : "Native American",
                                               "O" : "Other",
                                               "W;B;N" : "Other"} )

mpv['victim_race'] = mpv['victim_race'].replace( {"Unknown race" : "Unknown",
                                                 "Asian" : "Asian & Pacific Islander",
                                                 "Native Hawaiian and Pacific Islander" : "Asian & Pacific Islander"} )

# Prints current races
print_vals( {"fe" : fe, "mpv" : mpv, "wp" : wp}, 'victim_race')
# Out:
# Print database [fe]
# victim_race
# White                       4377
# Black                       2601
# Unknown                     1928
# Hispanic                    1509
# Asian & Pacific Islander     178
# Native American              151
# Other                         25
# Name: count, dtype: int64
#
# Print database [mpv]
# victim_race
# White                       2740
# Black                       1484
# Hispanic                    1117
# Unknown                      485
# Asian & Pacific Islander     131
# Native American              106
# Name: count, dtype: int64
#
# Print database [wp]
# victim_race
# White                       2811
# Black                       1456
# Hispanic                    1056
# Unknown                      395
# Asian & Pacific Islander     119
# Native American               88
# Other                         21
# Name: count, dtype: int64

# %% [markdown]
# ### 1.4 | Handles Multiple LEAs

# %% [markdown]
# Does this by putting them into unique rows

# %%
# FE: multiple agencies sorted by ','
temp = fe['agency_responsible'].str.split(',', expand=True) # Split 'agency responsible' into different cols
temp.columns = [f'agency_responsible_{i+1}' for i in range(temp.shape[1])] # Rename them
fe = pd.concat([fe.drop('agency_responsible', axis=1), temp], axis=1) # add them to the OG DF

# MPV: multiple agencies sorted by ','
temp = mpv['agency_responsible'].str.split(',', expand=True) # Split 'agency responsible' into different cols
temp.columns = [f'agency_responsible_{i+1}' for i in range(temp.shape[1])] # Rename them
mpv = pd.concat([mpv.drop('agency_responsible', axis=1), temp], axis=1) # add them to the OG DF

# WP: multiple agencies sorted by ';'
temp = wp['agency_responsible'].str.split(';', expand=True) # Split 'agency responsible' into different cols
temp.columns = [f'agency_responsible_{i+1}' for i in range(temp.shape[1])] # Rename them
wp = pd.concat([wp.drop('agency_responsible', axis=1), temp], axis=1) # add them to the OG DF

# %% [markdown]
# For WP: Replace the IDs with the names of the LEAs

# %%
wp_agencies = pd.read_csv("WP - Fatal Shooting Agencies.csv")
wp_agencies.head(3)
# Out:
#      id                               name          type state oricodes  \
# 0  3145  Abbeville County Sheriff's Office       sheriff    SC  SC00100
# 1  2576         Aberdeen Police Department  local_police    WA  WA01401
# 2  2114          Abilene Police Department  local_police    TX  TX22101
#
#    total_shootings
# 0                1
# 1                1
# 2                6

# %%
# Maps IDs to LEA Name
wp_agencies['id'] = wp_agencies['id'].astype(str)
id_to_name = dict(zip(wp_agencies['id'], wp_agencies['name']))
id_to_name['-1'] = "Unknown"

# %%
for i in range(1, 6):
    wp[f'agency_responsible_{i}'] = wp[f'agency_responsible_{i}'].astype(str) # Ensures similar datatypes
    wp[f'agency_responsible_{i}'] = wp[f'agency_responsible_{i}'].replace(id_to_name)

# %% [markdown]
# ### 1.5 | Check that databases are consistent

# %%
fe.head(3)
# Out:
#            date               victim_name  victim_age victim_gender  \
# 1998 2020-12-31    David Randall Shephard          39          Male
# 2000 2020-12-31   Name withheld by police          -1        Female
# 1999 2020-12-31  Rodolfo Caraballo Moreno          -1          Male
#
#      victim_race city_of_death state_of_death  \
# 1998       White      Beaumont             TX
# 2000     Unknown        Odessa             TX
# 1999    Hispanic         Miami             FL
#
#                                                     URL  \
# 1998  https://www.12newsnow.com/article/news/local/s...
# 2000  https://www.oaoa.com/news/crime_justice/law_en...
# 1999  https://www.local10.com/news/local/2021/01/01/...
#
#             agency_responsible_1 agency_responsible_2 agency_responsible_3  \
# 1998  Beaumont Police Department                 None                 None
# 2000    Odessa Police Department                 None                 None
# 1999     Miami Police Department                 None                 None
#
#      agency_responsible_4 agency_responsible_5 agency_responsible_6  \
# 1998                 None                 None                 None
# 2000                 None                 None                 None
# 1999                 None                 None                 None
#
#      agency_responsible_7 agency_responsible_8
# 1998                 None                 None
# 2000                 None                 None
# 1999                 None                 None

# %%
mpv.head(3)
# Out:
#            date               victim_name  victim_age victim_gender  \
# 4304 2020-12-31    David Randall Shephard          39          Male
# 4305 2020-12-31            Jeffrey Marvin          63          Male
# 4306 2020-12-31  Rodolfo Caraballo Moreno          -1          Male
#
#      victim_race city_of_death state_of_death  \
# 4304       White      Beaumont             TX
# 4305     Unknown       Unknown             IN
# 4306    Hispanic         Miami             FL
#
#                                                     URL  \
# 4304  https://www.usnews.com/news/best-states/texas/...
# 4305  https://wsbt.com/news/local/indiana-state-poli...
# 4306  https://www.local10.com/news/local/2021/01/01/...
#
#                       agency_responsible_1 agency_responsible_2  \
# 4304            Beaumont Police Department                 None
# 4305  Marshall County Sheriff's Department                 None
# 4306               Miami Police Department                 None
#
#      agency_responsible_3 agency_responsible_4 agency_responsible_5  \
# 4304                 None                 None                 None
# 4305                 None                 None                 None
# 4306                 None                 None                 None
#
#      agency_responsible_6
# 4304                 None
# 4305                 None
# 4306                 None

# %%
wp.head(3)
# Out:
#            date             victim_name  victim_age victim_gender  \
# 5944 2020-12-31  David Randall Shepherd          39          Male
# 5945 2020-12-31          Jeffrey Marvin          63          Male
# 5942 2020-12-30   Christian Joseph Hall          19          Male
#
#                    victim_race      city_of_death state_of_death   URL  \
# 5944                     White           Beaumont             TX  None
# 5945                   Unknown      Starke County             IN  None
# 5942  Asian & Pacific Islander  Hamilton Township             PA  None
#
#                       agency_responsible_1 agency_responsible_2  \
# 5944            Beaumont Police Department                 None
# 5945  Marshall County Sheriff's Department                 None
# 5942             Pennsylvania State Police                 None
#
#      agency_responsible_3 agency_responsible_4 agency_responsible_5
# 5944                 None                 None                 None
# 5945                 None                 None                 None
# 5942                 None                 None                 None

# %% [markdown]
# # 2 | NLP Processing

# %% [markdown]
# Cleans victim name, city, and agency names so they're easier to search for and match between databases

# %% [markdown]
# ### 2.1 | Victim Name

# %% [markdown]
# Slight variations in the name's spelling will prevent an exact match. Thus, let's standardize  names between databases.

# %%
# Standardizes  "Name withheld"
fe["victim_name"] = fe["victim_name"].replace({"Name withheld by police" : "Not Disclosed"})
mpv["victim_name"] = mpv["victim_name"].replace({"Name Withheld" : "Not Disclosed"})
wp["victim_name"] = wp["victim_name"].replace({"Unknown" : "Not Disclosed"})

# %%
def extract_first_last_name(full_name):
    parts = full_name.split(' ')
    if len(parts) > 1:
        first_name = parts[0]
        last_name = parts[-1]
    else:
        first_name = parts[0]
        last_name = ''
    return f"{first_name}_{last_name}"

# %%
# Creates a dummy  name column. An abbreviated version of the victim's name we can use for comparison
for df in [fe, mpv, wp]:
    df["name_abr"] = df["victim_name"]
    df['name_abr'] = df['name_abr'].str.strip() # Removes whitespace
    df['name_abr'] = df['name_abr'].str.lower() # Makes lower

    # Fixes weird punctuation
    df['name_abr'] = df['name_abr'].str.replace("'", "")# Removes '
    df['name_abr'] = df['name_abr'].str.replace("\"", "")# Removes "
    df['name_abr'] = df['name_abr'].str.replace(".", "")# Removes .
    df['name_abr'] = df['name_abr'].str.replace("-", " ")# Removes .
    
    # Only keeps first & last names
    df['name_abr'] = df['name_abr'].apply(lambda x: pd.Series(extract_first_last_name(x))) # Removes middle name(s)

# %% [markdown]
# ### 2.2 | Agency

# %%
def remove_parentheses(text):

    if not text:
        return None
    
    result = []
    inside_parentheses = False
    for char in text:
        if char == '(':
            inside_parentheses = True
        elif char == ')':
            inside_parentheses = False
        elif not inside_parentheses:
            result.append(char)
    return ''.join(result).strip()

# %%
# Creates a dummy  name column. An abbreviated version of the victim's name we can use for comparison
for id, df in enumerate(tqdm([fe, mpv, wp])):
    for i in range(1,7):

        # WP only has up to 5 responsible LEAs, not 6
        if i == 6 and id == 2:
            break
            
        col = f'agency_responsible_abr_{i}'
        df[col] = df[f'agency_responsible_{i}'] # Old Col Name
        df[col] = df[col].str.lower() # Makes lower

        # Fixes weird punctuation
        df[col] = df[col].str.replace("'", "")# Removes '
        df[col] = df[col].str.replace("\"", "")# Removes "
        df[col] = df[col].str.replace(".", "")# Removes .
        df[col] = df[col].str.replace("-", " ")# Removes -

        # Removes 'department' and 'office' b/c theyr'e sometimes used interchangeably between databases
        df[col] = df[col].str.replace(" department", "")
        df[col] = df[col].str.replace(" office", "")

        # Removes the (parentheses) that WP adds to some LEAs as notes
        df[col] = df[col].apply(lambda x: pd.Series(remove_parentheses(x))) # Removes middle name(s)
        
        # Misc
        df[col] = df[col].str.replace("sheriffs", "sheriff")
        df[col] = df[col].str.replace("bureau of", "")
        df[col] = df[col].str.replace("division of", "")
        df[col] = df[col].str.replace("metropolitan", "")
        df[col] = df[col].str.replace("department", "")
        df[col] = df[col].str.replace("deparment", "")
        df[col] = df[col].str.replace("county", "")
        df[col] = df[col].str.replace("  ", " ")
        df[col] = df[col].str.replace(" ", "_")
        df[col] = df[col].str.strip() # Removes whitespace
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:09<00:00,  3.26s/it]

# %% [markdown]
# ### 2.3 | City of Death

# %%
# Creates a dummy  name column. An abbreviated version of the victim's name we can use for comparison
for id, df in enumerate(tqdm([fe, mpv, wp])):
            
    col = 'city_of_death_abr'
    df[col] = df['city_of_death'] # Old Col Name

    # Fixes weird punctuation
    df[col] = df[col].str.lower() # Makes lower
    df[col] = df[col].str.replace("'", "")# Removes '
    df[col] = df[col].str.replace("\"", "")# Removes "
    df[col] = df[col].str.replace(".", "")# Removes .
    df[col] = df[col].str.replace("-", " ")# Removes -

    # Misc
    df[col] = df[col].str.replace("  ", " ")
    df[col] = df[col].str.strip() # Removes whitespace
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 89.47it/s]

# %% [markdown]
# # 3 | Subsets FE to just (i) fatal shootings that were (ii) non gunshots

# %% [markdown]
# FE was subsetted so late into the code so that the entire dataset can undergo preprocessing. We're going to split the dataset into (i) suicides (to be compared to WP and MPV later) and (ii) non-suicides, and the non-suicides will be our new FE dataframe

# %% [markdown]
# ### 3.1 | Performs Subsetting

# %%
fe_original = pd.read_csv(f"{DIR_DATABASE}db_FE.csv", low_memory = False)

# Converts dates to proper datatype
fe_original[' Date of injury resulting in death (month/day/year)'] = pd.to_datetime(fe_original[' Date of injury resulting in death (month/day/year)'])

# Filters dates to only include deaths from Jan 1, 2015 until December 31, 2020
fe_original = fe_original[ (fe_original[' Date of injury resulting in death (month/day/year)'] >= '2015-01-01') & (fe_original[' Date of injury resulting in death (month/day/year)'] <= '2020-12-31') ]

# Ensures the most recent date comes first in all the databases, followed by name in alpha order
fe_original = fe_original.sort_values(by=[' Date of injury resulting in death (month/day/year)', 'Name'], ascending=[False, True])

# %%
# Makes sure the indices are equal
assert( fe.index == fe_original.index ).all()
print("Assertion passed. All FE indices are the same as fe_original indices")
# Out:
# Assertion passed. All FE indices are the same as fe_original indices

# %%
# Gets indices to use - i.e., non-suicidal fatal shootings
fe_indices_shootings = fe_original[ (fe_original["Highest level of force"] == "Gunshot") & (fe_original["Intended use of force (Developing)"] != "Suicide") ].index #FE: Exclude Suicides
fe_indices_suicides = fe_original[ fe_original["Intended use of force (Developing)"] == "Suicide"].index

fe_suicides = fe.loc[fe_indices_suicides]
fe = fe.loc[fe_indices_shootings]

print(f"Suicides = {fe_suicides.shape[0]}")
print(f"Non-Suicide Fatal Shootings = {fe.shape[0]}")
# Out:
# Suicides = 1376
# Non-Suicide Fatal Shootings = 6590

# %% [markdown]
# ### 3.2 | Cleans up all datasets

# %%
# Drops columns 'agency_responsible_7' & agency_responsible_8 because only fe_suicides has 7-8 LEAs invovled
fe.drop(columns=["agency_responsible_7", "agency_responsible_8"], inplace = True)
fe_suicides.drop(columns=["agency_responsible_7", "agency_responsible_8"], inplace = True)

# %%
# Finally, reset all dataframe indices
fe = fe.reset_index(drop=True)
fe_suicides = fe_suicides.reset_index(drop=True)
mpv = mpv.reset_index(drop=True)
wp = wp.reset_index(drop=True)

# %%
fe.head(2)
# Out:
#         date               victim_name  victim_age victim_gender victim_race  \
# 0 2020-12-31    David Randall Shephard          39          Male       White
# 1 2020-12-31  Rodolfo Caraballo Moreno          -1          Male    Hispanic
#
#   city_of_death state_of_death  \
# 0      Beaumont             TX
# 1         Miami             FL
#
#                                                  URL  \
# 0  https://www.12newsnow.com/article/news/local/s...
# 1  https://www.local10.com/news/local/2021/01/01/...
#
#          agency_responsible_1 agency_responsible_2 agency_responsible_3  \
# 0  Beaumont Police Department                 None                 None
# 1     Miami Police Department                 None                 None
#
#   agency_responsible_4 agency_responsible_5 agency_responsible_6  \
# 0                 None                 None                 None
# 1                 None                 None                 None
#
#          name_abr agency_responsible_abr_1 agency_responsible_abr_2  \
# 0  david_shephard          beaumont_police                      NaN
# 1  rodolfo_moreno             miami_police                      NaN
#
#   agency_responsible_abr_3 agency_responsible_abr_4 agency_responsible_abr_5  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
#
#   agency_responsible_abr_6 city_of_death_abr
# 0                      NaN          beaumont
# 1                      NaN             miami

# %%
# Records size of original database (to help create descriptive stats later, in Loop III statistics)
# We're doing this now because, as the program progresses, matched entries in MPV and WP will be deleted from their respective dataframes to avoid a double match

fe_original_size = fe.shape[0]
mpv_original_size = mpv.shape[0]
wp_original_size = wp.shape[0]

print(f"Fatally shot civillians by database:\nFE = {fe_original_size}\nMPV = {mpv_original_size}\nWP = {wp_original_size}")
# Out:
# Fatally shot civillians by database:
# FE = 6590
# MPV = 6063
# WP = 5946

# %% [markdown]
# # 4 | Loop Auxilary Functions

# %% [markdown]
# Initiates a sanity check & defines several auxilary functions that are used throughout the loop. The loop is the code that merges the databases with eachother to create DM-FS

# %% [markdown]
# ### 4.1 | Sanity Checks

# %%
# Check to make sure all LEAs contain same number of states
assert( len( np.unique(fe["state_of_death"])  ) == len( np.unique(mpv["state_of_death"])  ) == len( np.unique(wp["state_of_death"])  ) )
print("Assertion passed. All databases contain 51 states (50 states + Puerto Rico)")
# Out:
# Assertion passed. All databases contain 51 states (50 states + Puerto Rico)

# %%
print(f"Size of fe = {fe.shape[0]}")
print(f"Size of mpv = {mpv.shape[0]}")
print(f"Size of wp = {wp.shape[0]}")
# Out:
# Size of fe = 6590
# Size of mpv = 6063
# Size of wp = 5946

# %% [markdown]
# FE is the most extensive of the 3 databases.

# %% [markdown]
# ### 4.2 | Fuzzy Search Functions

# %%
def fuzzy_city_match(row_city):
    threshold = 90
    score = fuzz.ratio(row_city, city)
    return score >= threshold

# %%
def get_candidate_rows_via_fuzzzy_name_search(db, db1_name, db2_name, threshold = 70):

    # Ensures user only inputs a 'Y' or an 'N'
    def verify_fuzzy_match():
        while True:
            user_input = input("Confirm Fuzzy Match? Type 'Y' for Yes or 'N' for No: ").strip().upper()
            if user_input in ['Y', 'N']:
                return user_input
            else:
                print("Invalid input. Please enter 'Y' for Yes or 'N' for No.")

    candidate_indices = []
    
    for candidate_index, candidate_row in db.iterrows():
        
        # Split each row's name into first and last names
        db1_first_name, db1_last_name = name.split("_")
        db2_first_name, db2_last_name = candidate_row["name_abr"].split("_")
    
        # Calculate fuzzy ratio for both first and last names
        first_name_score = fuzz.ratio(db1_first_name, db2_first_name)
        last_name_score = fuzz.ratio(db1_last_name, db2_last_name)
        fuzzy_match = (first_name_score >= threshold) and (last_name_score > threshold)

        # If fuzzy match, verify it
        if fuzzy_match:

            if USE_MANUAL_MATCHING_DATAFRAME:
                manual_verification_record = manual_fuzzy_match_verification_df.query(f"db1 == '{db1_name}' & db2 == '{db2_name}' & db1_index == {i} & db2_index == {candidate_index}")
                match_verified = manual_verification_record["match_verified"].iloc[0]
                if match_verified:
                    candidate_indices.append(candidate_index)
            else:
                print(f"VERIFY NAME MATCH: {db1_name} = [{name}] & {db2_name} = [{candidate_row['name_abr']}]")
                user_input = verify_fuzzy_match()

                # Adds result of our verification to our DF
                next_index = len(manual_fuzzy_match_verification_df)
                manual_fuzzy_match_verification_df.loc[next_index] = {"db1" : db1_name, "db2" : db2_name, "db1_index" : i, "db2_index" : candidate_index,
                                                                      "db1_name" : name, "db2_name" : candidate_row['name_abr'] , "match_verified" : (user_input == "Y")}
                
                if user_input == 'Y':
                    candidate_indices.append(candidate_index)

    return db.loc[candidate_indices]

# %%
# Does a fuzzy search to verify agency discrepencies. 'target_agency' is defined in the loop

def verify_agency_discrepency(agencies_1, agencies_2):

    threshold = 60
    agency_list_1, agency_list_2 = list(agencies_1), list(agencies_2)

    # If there's an agency difference (i.e., an additional or one less agency), then there MUST be a disrepency
    if len(agency_list_1) != len(agency_list_2):
        return True

    # If both databases have the exact same number of LEAs, let's do a fuzzy search to make sure they're really different
    for ind_a1 in agency_list_1:
        match_found = False
        for ind_a2 in agency_list_2:
            #print(f"{ind_a1} | {ind_a2} | {match}")
            
            # If we (i) have yet to find a match but (ii) found one, then flag it as true
            if fuzz.ratio(ind_a1, ind_a2) >= threshold:
                match_found = True

        # We're done with one iteration of the loop.
        # If we still haven't found a match, exit the loop becasue we found a discrepency
        if not match_found:
            return True

    # Else, we have a match for every part of the loop. No discrepency exist
    return False

# %% [markdown]
# ### 4.3 | Discrepancy Check Functions

# %%
# Identifies minor date discrepencies. master_df is the DB that's (i) a copy of FE with (ii) the discrepencies listed/corected. 
# 'i' is its index, the current row it's on within the for loop that this method is called from, the one that cycles through every row of the database to check for issues
# 'fe', 'mpv', 'wp' are a single row in the respective database.
# First, we'll extract the dates, and we'll see if there are any differences. If none, exit the function
# Second, if one of the three databases is aberrant, note the 'odd one out' in the master_df & correct it (if necessary).
# Third, if all 3 databases can't agree, 

def check_for_date_discrepency(master_df, i, fe, mpv, wp):
    
    # Extracts date of victim's death
    fe_date, mpv_date, wp_date =  None if fe is None else fe["date"], None if mpv is None else mpv["date"], None if wp is None else wp["date"]

    # Calculates max date dsicrepency
    def calculate_date_discrepency():
        valid_dates = [date for date in [fe_date, mpv_date, wp_date] if date is not None] # Filters out "None" values
        return max((abs((d1 - d2).days) for i, d1 in enumerate(valid_dates) for d2 in valid_dates[i+1:]), default=None)
    
    # If all 2 or all 3 databases disagree, (i) flag it and (ii) list disagreements in database
    def flag_disagreement():
        
        # Flags Disagreement
        master_df.loc[i, "date"] = f"ERROR - {2 if mpv_date is None or wp_date is None or fe_date is None else 3} Databases Disagree"
        
        # Records the discrepencies
        if fe_date is not None:
            master_df.loc[i, "date_fe"] = fe_date
        if mpv_date is not None:
            master_df.loc[i, "date_mpv"] = mpv_date
        if wp_date is not None:
            master_df.loc[i, "date_wp"] = wp_date

    # Calculates and records date discrepency for all dates. Most common case will be '0'
    master_df.loc[i, "date_discrepancy_days"] = calculate_date_discrepency()
    
    # Handles only 2 databases
    if wp_date is None or mpv_date is None or fe_date is None:
        if (fe_date == mpv_date and wp_date is None) or (fe_date == wp_date and mpv_date is None) or (mpv_date == wp_date and fe_date is None): # Exits function if no discrepency found
            pass
        else: # Else, flag it & exit function
            flag_disagreement()
        return

    # Handles all 3 databases
    # If no discrepency is found, no need for further checks
    if fe_date == mpv_date == wp_date:
        return

    # If one discrepency is found, identifies source of it
    if fe_date == mpv_date and fe_date != wp_date: # WP Wrong
        master_df.loc[i, "date_wp"] = True 

    elif fe_date == wp_date and fe_date != mpv_date: # MPV Wrong
        master_df.loc[i, "date_mpv"] = True 

    elif mpv_date == wp_date and fe_date != mpv_date: # FE Wrong
        master_df.loc[i, "date_fe"] = True 
        master_df.loc[i, "date"] = mpv["date"] # Master_df is a copy of FE, so if FE is wrong, the date needs to be corrected

    # If all 3 databases can't agree, flag that
    else:
        flag_disagreement()

# %%
# Aux function of check_for_agency_discrepencies
# Compresses agencies_responsible into a set, and returns that set (after cleaning it)
# use_abbreviated = True will use 'agency_responsible_abr_', else it uses agency_responsible

def get_agencies_responsible(fe, mpv, wp, use_abbreviated = True):

    # Removes None and nans from a set
    def clean_set(input_set):
        return {item for item in input_set if item is not None and not (isinstance(item, float) and math.isnan(item)) and (not isinstance(item, str) or item.lower() != 'none') }

    # Inits the 3 sets
    fe_agencies, mpv_agencies, wp_agencies = [], [], []

    # Initializes them
    for x in range (1, 7):
        agency = f"agency_responsible{'_abr' if use_abbreviated else ''}_{x}"
        if (fe is not None) and agency in fe:
            fe_agencies.append(fe[agency] )
        if (mpv is not None) and agency in mpv:
            mpv_agencies.append(mpv[agency] )
        if (wp is not None) and agency in wp:
            wp_agencies.append(wp[agency] )

    # Cleans them
    fe_agencies= clean_set( set(fe_agencies) )
    mpv_agencies = clean_set( set(mpv_agencies) )
    wp_agencies = clean_set( set(wp_agencies) )

    # Returns
    return fe_agencies, mpv_agencies, wp_agencies

# %%
def check_for_agency_discrepency(master_df, i, fe, mpv, wp):

    # (i) flags disagreement and (ii) records the disagreeing agencies
    def identify_and_record_problematic_agencies(error_text = "ERROR - 2 Databases Disagree"):

        # Deletes the responsible LEAs from master_df
        for x in range (1, 7):
            master_df.loc[i, f"agency_responsible_{x}"] = ""
            master_df.loc[i, f"agency_responsible_abr_{x}"] = ""

        # Now, we need to record the disagreement
        master_df.loc[i, "agency_responsible_1"] = error_text

        # Lists the disagreement
        fe_agencies_unabridged, mpv_agencies_unabridged, wp_agencies_unabridged = get_agencies_responsible(fe, mpv, wp, False)
        if fe is not None:
            master_df.loc[i, f"agency_responsible_fe"] =  f"{fe_agencies_unabridged}".replace("{", "").replace("}", "").replace("\"", "").replace("'","")
        if mpv is not None:
            master_df.loc[i, f"agency_responsible_mpv"] =  f"{mpv_agencies_unabridged}".replace("{", "").replace("}", "").replace("\"", "").replace("'","")
        if wp is not None:
            master_df.loc[i, f"agency_responsible_wp"] =  f"{wp_agencies_unabridged}".replace("{", "").replace("}", "").replace("\"", "").replace("'","")
            
    # Gets a list of responsible agencies for both databases
    fe_agencies, mpv_agencies, wp_agencies = get_agencies_responsible(fe, mpv, wp, True)
    
    # If we only ahve 2 of the 3 databases, do a special check
    if mpv is None or wp is None or fe is None:

        # If the 2 databases match, great. No need to flag for a discrepency
        if ( fe_agencies == mpv_agencies and wp is None ) or ( fe_agencies == wp_agencies and mpv is None ) or ( wp_agencies == mpv_agencies and fe is None ) :
            return

        # If the 2 databases don't match, flag as a discrepency
        if fe is None:
            if verify_agency_discrepency(mpv_agencies, wp_agencies):
                identify_and_record_problematic_agencies("ERROR - 2 Databases Disagree")
        elif mpv is None or wp is None:    
            if verify_agency_discrepency(fe_agencies, mpv_agencies if mpv is not None else wp_agencies):
                identify_and_record_problematic_agencies("ERROR - 2 Databases Disagree")
            
        # Discrepencies marked; no need to pursue them further
        return
    
    # We have all 3 databases
    # If all 3 databases contain same agencies, that's great! No discrepency found; do nothing
    assert(mpv_agencies is not None and wp_agencies is not None and fe_agencies is not None)
    if fe_agencies == mpv_agencies == wp_agencies:
        return

        
    # If they don't, identify the source of that discrepency & correct it
    if fe_agencies == mpv_agencies and fe_agencies != wp_agencies: # WP Wrong
        
        if verify_agency_discrepency(fe_agencies, wp_agencies):
            master_df.loc[i, f"agency_responsible_wp"] =  True

    elif fe_agencies == wp_agencies and fe_agencies != mpv_agencies: # MPV Wrong
        
        if verify_agency_discrepency(fe_agencies, mpv_agencies):
            master_df.loc[i, f"agency_responsible_mpv"] =  True

    elif mpv_agencies == wp_agencies and fe_agencies != mpv_agencies: # FE Wrong
        if verify_agency_discrepency(mpv_agencies, fe_agencies):
            master_df.loc[i, f"agency_responsible_fe"] =  True
            
            # If FE was incorrect, we need to fix master_df so it now records the correct agencies responsible
            for x in range (1, 7):
                master_df.loc[i, f"agency_responsible_{x}"] = mpv[f"agency_responsible_{x}"] 
                master_df.loc[i, f"agency_responsible_abr_{x}"] = mpv[f"agency_responsible_abr_{x}"] 
    
    # If all 3 databases disagree, flag for manual correction
    else:
        identify_and_record_problematic_agencies("ERROR - 3 Databases Disagree")

# %%
# Takes in a row from each of the 3 databases and checks to see if there's a discrepency in for a specific var in that row (e.g., victim_age).
# First, it extracts the value from each of the 3 databases and stores it in the list_of_vals. E.g., it takes age from FE, MPV, and WP.
# Second, it asks ho w many unique values there are in this list? 
# If there are 3 unique values, none of the databases agree, so do a procedure that'll enable manual correction later
# If there are 2 unique values, 2 of the 3 databases agree, so uses a simple majority-voting system to correct abnormality
# Finally, if there is 1only 1 unique val, then there are NO DISCREPENCIEES, hence nothign needs to be corrected
# 'master_df' is the databases that (i) stores the discrepencies and (ii) corrects them
# Thus, if there is only 1 unique value, that database isn't modified; whereas if there's 2 or more, the discrepency is recorded in that database

def check_for_discrepency(master_df, i, fe_row, mpv_row, wp_row,
                         discrepency_name_dfs = "victim_age", discrepency_name_master_df = "age"):
    
        # Gets a list of relevant vars
        if mpv_row is None: 
            list_of_vals = [fe_row[discrepency_name_dfs], wp_row[discrepency_name_dfs] ]
        elif wp_row is None:
            list_of_vals = [fe_row[discrepency_name_dfs], mpv_row[discrepency_name_dfs] ]
        elif fe_row is None:
            list_of_vals = [mpv_row[discrepency_name_dfs], wp_row[discrepency_name_dfs] ]
        else: # if there's no None values, i.e., if all 3 databases returned a hit
            list_of_vals = [fe_row[discrepency_name_dfs], mpv_row[discrepency_name_dfs],wp_row[discrepency_name_dfs] ]

        # If there's a discrpeency
        if len( np.unique( list_of_vals ) ) > 1: 
            
            # If all 3 databases list a different age...
            # Initialize the age_fe values with the purported age values so it can be manually corrected
            if len( np.unique(list_of_vals) ) == 3:

                # Each of the 3 databases have a unique value, so record that in the master dataframe
                master_df.loc[i, f"{discrepency_name_master_df}_fe"] = fe_row[discrepency_name_dfs]
                master_df.loc[i, f"{discrepency_name_master_df}_mpv"] = mpv_row[discrepency_name_dfs]
                master_df.loc[i, f"{discrepency_name_master_df}_wp"] = wp_row[discrepency_name_dfs]

                # We don't know the true value anymore, so let's replace it with 'ERROR" so it can be manually corrected
                master_df.loc[i, discrepency_name_dfs] = "ERROR - 3 Databases Disagree"

            # If only one database lists a different age...
            if len( np.unique(list_of_vals) ) == 2:    

                # If all 3 databases returned a hit, go with the majority
                if (mpv_row is not None) and (wp_row is not None) and (fe_row is not None) :
                    # WP is the odd oen out
                    if fe_row[discrepency_name_dfs] == mpv_row[discrepency_name_dfs]:
                        master_df.loc[i, f"{discrepency_name_master_df}_wp"] = True # Identify the discrepency...
                        master_df.loc[i, discrepency_name_dfs] = fe_row[discrepency_name_dfs] # And make sure it's right

                    # MPV is the odd one out
                    elif fe_row[discrepency_name_dfs] == wp_row[discrepency_name_dfs]:
                        master_df.loc[i, f"{discrepency_name_master_df}_mpv"] = True 
                        master_df.loc[i, discrepency_name_dfs] = fe_row[discrepency_name_dfs] 

                    # FE is the odd one out
                    elif mpv_row[discrepency_name_dfs] == wp_row[discrepency_name_dfs]:
                        master_df.loc[i, f"{discrepency_name_master_df}_fe"] = True 
                        master_df.loc[i, discrepency_name_dfs] = mpv_row[discrepency_name_dfs]
    
                # If only two databases returned a hit, then don't resolve it... flag it for manual inspection
                else:
                    if fe_row is not None:
                        master_df.loc[i, f"{discrepency_name_master_df}_fe"] = fe_row[discrepency_name_dfs]
                    if mpv_row is not None:
                        master_df.loc[i, f"{discrepency_name_master_df}_mpv"] = mpv_row[discrepency_name_dfs]
                    elif wp_row is not None:
                        master_df.loc[i, f"{discrepency_name_master_df}_wp"] = wp_row[discrepency_name_dfs]

                    # We don't know the true value anymore, so let's replace it with 'ERROR" so it can be manually corrected
                    master_df.loc[i, discrepency_name_dfs] = "ERROR - 2 Databases Disagree"

# %%
# Burns through all 3 of the above check_for_discrepency methods
def check_for_all_discrepencies(master_df, i, fe_row, mpv_row, wp_row):

        # City
        check_for_discrepency(master_df, i, fe_row, mpv_row, wp_row,
                              discrepency_name_dfs = "city_of_death", discrepency_name_master_df = "city")
        # Age
        check_for_discrepency(master_df, i, fe_row, mpv_row, wp_row,
                             discrepency_name_dfs = "victim_age", discrepency_name_master_df = "age")

        # Gender
        check_for_discrepency(master_df, i, fe_row, mpv_row, wp_row,
                             discrepency_name_dfs = "victim_gender", discrepency_name_master_df = "gender")

        # Race
        check_for_discrepency(master_df, i, fe_row, mpv_row, wp_row,
                             discrepency_name_dfs = "victim_race", discrepency_name_master_df = "race")
        
        # Agency
        check_for_agency_discrepency(master_df, i, fe_row, mpv_row, wp_row)

        # Date (minor) (if it was major, a match wouldn't be found)
        check_for_date_discrepency(master_df, i, fe_row, mpv_row, wp_row)

# %% [markdown]
# ### 4.4 | Other Functions

# %%
# Flags for manual review when there are multiple people (i) with similar names who (ii) died on similar dates (less than 3 days apart) (iii) in the same state 
# OR this occurs when the date_delta between the proposed match is more than 3 days apart
# In short, prints out the proposed match in DB1 and DB2, and the author manually flags as a match or not
# Output: (i) records decision in dataframe and (ii) records the candidate row (if match) or None (if no match)
 
def manually_verify_match(candidate_row, db2_index, date_delta, db1_name, db2_name):

    # Ensures user only inputs a 'Y' or an 'N'
    def get_and_verify_user_input():
        while True:
            user_input = input("Do these match? Type 'Y' for Yes or 'N' for No: ").strip().upper()
            if user_input in ['Y', 'N']:
                return user_input
            else:
                print("Invalid input. Please enter 'Y' for Yes or 'N' for No.")
                
    
    print(f"DB = {db1_name} & {db2_name} | Date Delta = {date_delta} | Names = {name} & {candidate_row['name_abr']} | City = {city} & {candidate_row['city_of_death']} | State = {state} | Death Date = {date.strftime('%Y-%m-%d')} & {candidate_row['date'].strftime('%Y-%m-%d')}")
    user_input = get_and_verify_user_input()
    
    # Adds our decision to our manual_match_verificatoin_df
    next_index = len(manual_match_verification_df)
    print(f"Adding result to manual_match_verification_df @ index [{next_index}]")
    manual_match_verification_df.loc[next_index] = {"db1" : db1_name, "db2" : db2_name, "date_delta" : date_delta, 
                                                    "date_db1" : date, "date_db2" : candidate_row['date'], "name_db1" : name, "name_db2" : candidate_row['name_abr'], 
                                                    "city_db1" : city, "city_db2" : candidate_row['city_of_death'], "state_db1" : state, "state_db2" : state, 
                                                    "db1_index" : i, "db2_index" : db2_index, "match_verified" : (not user_input == "N")}
    # If no match, return None
    if user_input == "N":
        return None
    else:
        return candidate_row

# %%
# Called from initialize_row_to_search
# 

def init_candidate_row_from_multiple_viable_candidates(rows, low_date_delta_indices, low_date_delta_deltas, db1_name, db2_name):
    # Displays all possible candidates
    print("Multiple candidates detected. First, we will display all possible candidate matches below: " )
    for row_index, candidate_row in rows.loc[low_date_delta_indices].iterrows():
        print(f"{row_index} | Delta Date = {low_date_delta_deltas[row_index]} | Names = {name} & {candidate_row['name_abr']} | City = {city} & {candidate_row['city_of_death']} | State = {state} |  Death Date = {date.strftime('%Y-%m-%d')} & {candidate_row['date'].strftime('%Y-%m-%d')}")

    # Loop thorugh each candidate, and the user decides whether they want to keep it
    print(f"{'*'*50}")
    print("Second, we will go through the candidates one by one. Select which one (if any) you'd like to match, but only select ZERO or ONE")
    candidate_rows = []
    for row_index, candidate_row in rows.loc[low_date_delta_indices].iterrows():
        candidate_rows.append( manually_verify_match(candidate_row, row_index, low_date_delta_deltas[row_index], db1_name, db2_name) )

    # Selects the one candidate that the user deemed as valid
    candidate_rows = [row for row in candidate_rows if row is not None]
    if len( candidate_rows ) > 1:
        print("ERROR. Candidate_rows > 1. However only 0 or 1 candidate rows should be selected.")
        assert ( False )
    elif len (candidate_rows) == 1:
        return candidate_rows[0]
    else:
        return None

# %%
# Called from main loop. Converts mpv_rows & wp_rows into a single row that can be compared to FE via the iloc function
# If there's only 0 or 1 rows, the function returns nothing fancy
# However, if there are 2 or more rows (i.e., 2 or more possible 'hits'), then select the hit with the closets date
# Keep in mind that each hit already matches the (i) state, (ii) city, and (iii) name of the fatal shooting victim, so all hits are viable candidates.

def initialize_row_to_search(rows, fe_date, db1_name, db2_name):

    # *********************************************
    # HANDLES A SIMPLE ROW RESARCH (0 OR 1 POSSIBLE MATCHES)
    # *********************************************
    if rows.empty:
        search_results_dict["no_results_counter"] += 1
        return None
    elif len(rows) == 1:
        search_results_dict["1_result_counter"] += 1
        return rows.iloc[0]

    # *************************************************************************************
    # HANDLES MULTIPLE ROW SEARCHES (>=2 MATCHES) BY FINDING MATCHES WITH CLOSEST DATE
    # *************************************************************************************

    # Init variables
    search_results_dict["2_or_more_result_counter"] += 1
    min_date_delta_days, min_date_index = 999_999_999, -1
    low_date_delta_indices = [] # Counts number of times there's little difference in the two dates because, if there are, there are multiple matches
    low_date_delta_deltas = {} # Gets the date_deltas of any low dates. Stores as a dict where each key is the index
    
    # GO through each possible hit & find the hit with the closets date match (i.e., min(date_delta) )
    for row_index, ind_row in rows.iterrows():
        current_date = ind_row["date"]
        date_delta = abs((fe_date - current_date).days)
        #print(f"{row_index} : {date_delta}")

        # If there are multiple similar hits - i.e., multiple people with (i) similar names who died (ii) in the same state (iii) under similar dates, 
        # flag them by recording thier index
        if date_delta <= 3:
            low_date_delta_indices.append(row_index)
            low_date_delta_deltas[row_index] = date_delta

        # Records the hit who's death date is closest to the target, i..e, when date_delta is at th eminimum
        if date_delta < min_date_delta_days:
            min_date_delta_days = date_delta
            min_date_index = row_index

    # *****************************************************************************************************************
    # MANUALLY CORRECT ODD RESULTS: (I) IF MANY SIMILAR DEATHS ON SIMILAR DAYS OR (II) IF DEATH DATES > 3 DAYS APART
    # ******************************************************************************************************************

    # If using manual matching && there was a manual match
    if USE_MANUAL_MATCHING_DATAFRAME:
        if len( low_date_delta_indices ) > 1 or min_date_delta_days > MIN_DATE_DELTA_TOLLERANCE:
            manual_verification_record = manual_match_verification_df.query(f"db1 == '{db1_name}' & db2 == '{db2_name}' & db1_index == {i}")
            match_verified, match_index = manual_verification_record["match_verified"].iloc[0], manual_verification_record["db2_index"].iloc[0]
            
            return rows.loc[match_index] if match_verified else None
        
    # If there are multiple candidate rows, get user to select closest match (if any). If no match, returns 'None'
    if len( low_date_delta_indices ) > 1:
        candidate_row = init_candidate_row_from_multiple_viable_candidates(rows, low_date_delta_indices, low_date_delta_deltas, db1_name, db2_name)
    else:
        candidate_row = rows.loc[min_date_index]

    # Flags for manual review if the candidate match's death date is > 3 days away. If not a match, returns 'None'
    if min_date_delta_days > MIN_DATE_DELTA_TOLLERANCE and len( low_date_delta_indices ) <= 1: # the len( low_date_delta_indices) ensures no duplicate manual review
        return manually_verify_match(candidate_row, min_date_index, min_date_delta_days, db1_name, db2_name)

    # Prints output & returns candidate match
    return candidate_row

# %%
# Enumerates all the different discrepencies
# There are 2 reasons why agency_responsible could be wrong. Either an extra agency was present, or a database missed an agency. We'll record which one it is
DISCREPENCY_LIST = ["omission", "erroneous_inclusion","date", "city", "gender", "age", "race", "agency_responsible", ]
DB_NAMES = ["fe", "mpv", "wp"]

# Adds discrepencies to a dataframe. Modification is in-place: no need to return anything
def add_discrepencies_to_df(df, filler_value = None):
    for ind_discrepency in DISCREPENCY_LIST:
        for db_name in DB_NAMES:
            df[f"{ind_discrepency}_{db_name}"] = filler_value

# %% [markdown]
# # 5 | DM-FS Loop

# %% [markdown]
# This is the loop that merges all three databases together to create DM-FS. It works via the following logic.
#
# First, DM-FS is a copy of Fatal Encounters because it's the most extensive of the three databases (see section 4.1). It then goes row-by-row and checks to see if each FE fatal shooting victim appears in MPV and WP. If it does appear, it checks for discrepancies.
#
# Second, the remaining rows in MPV - those that were NOT matched to a FE row - are added one-at-a-time to DM-FS. Each time an MPV row is added, it's checked with WP, and if a match is found, it also checks that row for discrepancies between the two databases. In addition to checking for a match in WP, it also checks for a match in FE_Suicides to see if this fatal shooting was actually a suicide, which we flag as an erroneous inclusion.
#
# Third, the only rows that are not matched / added to DM-FS at this point are those unmatched rows in Washington Post. We'll add each row to DM-FS. Just like MPV, however, we'll also check to see if each victim was a suicide by looking at FE_Suicides. If a suicide (match) was found, then we'll flag it as an erroneous inclusion.
#
# Thus, in doing so, we'll include data from all three databases - FE, MPV, and WP - into DM-FS, checking each database against eachother when possiblem.

# %% [markdown]
# ### 5.1 | Initialize Key Variables

# %%
# USE_MANUAL_MATCHING_DATAFRAME will replicate all the manual matching that the author did, using the 'manual_matching.csv' file
# If set to false, a new manual_matching dataframe will be made, and the user will have to manually match all conflicts himself/herself using the program
USE_MANUAL_MATCHING_DATAFRAME = True 
MATCH_DIR = "res/1.1 - DM-FS Loop Manual Matches/"

if USE_MANUAL_MATCHING_DATAFRAME:
    print("Using the manual_matches CSV file to re-create how the author matched conflicting databases. All matching will be automated.")
    manual_match_verification_df = pd.read_csv(f"{MATCH_DIR}manual_matches.csv")
    manual_fuzzy_match_verification_df = pd.read_csv(f"{MATCH_DIR}fuzzy_search_name_matches.csv")
else:
    print("Creating a new manual_matches CSV file. This means that, every time there is a match conflict, the user will need to manually specify whether there's a match.")
    manual_match_verification_df =  pd.DataFrame(columns=["db1", "db2", "date_delta", "date_db1", "date_db2", "name_db1", "name_db2", "city_db1", "city_db2", "state_db1", "state_db2", 
                                                          "db1_index", "db2_index", "match_verified"])
    manual_fuzzy_match_verification_df =  pd.DataFrame(columns=["db1", "db2", "db1_index", "db2_index", "db1_name", "db2_name", "match_verified"])
# Out:
# Using the manual_matches CSV file to re-create how the author matched conflicting databases. All matching will be automated.

# %%
# Var to record search statistics
search_results_dict = {"no_results_counter" : 0 , "1_result_counter" : 0, "2_or_more_result_counter" : 0}

# Date Search Vars
MIN_DATE_DELTA_TOLLERANCE = 3 # If a row is more than X days apart, flags it for manual review. Do not change this if USE_MANUAL_MATCHING_DATAFRAME is set to True.

# Makes FE & MPV consistent with master DF, i.e., DM-FS
fe = fe.rename(columns={"URL": "URL_FE"})
mpv = mpv.rename(columns={"URL": "URL_MPV"})

# Creates master DF, which is synonymous with DM-FS
master_df = pd.DataFrame( columns= list(fe.columns) + ["URL_MPV"] ).rename(columns={"URL": "URL_FE"})
add_discrepencies_to_df(master_df)
master_df["date_discrepancy_days"] = None
master_df = master_df[ [col for col in master_df.columns if col not in ["URL_FE", "URL_MPV"]]  + ["URL_FE", "URL_MPV"] ] # Re-orders DF so URLs are last two columns
master_df.head(1)
# Out:
# Empty DataFrame
# Columns: [date, victim_name, victim_age, victim_gender, victim_race, city_of_death, state_of_death, agency_responsible_1, agency_responsible_2, agency_responsible_3, agency_responsible_4, agency_responsible_5, agency_responsible_6, name_abr, agency_responsible_abr_1, agency_responsible_abr_2, agency_responsible_abr_3, agency_responsible_abr_4, agency_responsible_abr_5, agency_responsible_abr_6, city_of_death_abr, omission_fe, omission_mpv, omission_wp, erroneous_inclusion_fe, erroneous_inclusion_mpv, erroneous_inclusion_wp, date_fe, date_mpv, date_wp, city_fe, city_mpv, city_wp, gender_fe, gender_mpv, gender_wp, age_fe, age_mpv, age_wp, race_fe, race_mpv, race_wp, agency_responsible_fe, agency_responsible_mpv, agency_responsible_wp, date_discrepancy_days, URL_FE, URL_MPV]
# Index: []

# %% [markdown]
# ### 5.2 | Loop I: Add FE to DM-FS, Checking Against MPV and WP

# %%
# Gets Pre-Loop Stats
original_mpv_size = mpv.shape[0]
original_wp_size = wp.shape[0]

# %%
for i in range(0, len(fe) ) :
    print(f"Processing index {i} out of {len(fe)} ({round(i/len(fe) * 100, 2)}%)")
    fe_row = fe.iloc[i].copy()
    name, state, city, date = fe_row["name_abr"], fe_row["state_of_death"], fe_row["city_of_death_abr"], fe_row["date"]

    # Adds discrpeencies to our FE_row before addign it to Master DF
    add_discrepencies_to_df(fe_row, filler_value = False)
    master_df = pd.concat([master_df,  pd.DataFrame([fe_row]) ], ignore_index=True) # Note that only dataframes (fe_row), not series, can be concated 

    # *************************************
    # Checks for a match in other DBs
    # *************************************

    # Name, City, & State match
    mpv_rows = mpv.query(f"name_abr == '{name}' & state_of_death == '{state}'")# & city_of_death_abr == '{city}'")
    wp_rows = wp.query(f"name_abr == '{name}' & state_of_death == '{state}'")# & city_of_death_abr == '{city}'")

    # If no match, then salavage it with a fuzzy search
    if wp_rows.empty:      
        wp_rows = get_candidate_rows_via_fuzzzy_name_search (wp[ (wp['state_of_death'] == state) ], "fe", "wp")
    if mpv_rows.empty:      
        mpv_rows = get_candidate_rows_via_fuzzzy_name_search (mpv[ (mpv['state_of_death'] == state) ], "fe", "mpv")

    # *************************************
    # Prepares match & lack of match
    # *************************************

    # Initialize the row to search for mpv and wp. If empty, return 'None'.
    mpv_row = initialize_row_to_search(mpv_rows, fe_row["date"], "fe", "mpv")
    wp_row = initialize_row_to_search(wp_rows, fe_row["date"], "fe", "wp")
    
    # Compiles a list of the databases with matches (i.e., WP & MPV). If no match, flag as ommission
    if mpv_row is None:
        master_df.loc[i, "omission_mpv"] = True
    if wp_row is None:
        master_df.loc[i, "omission_wp"] = True

    # Exiits iteration if no matches were found
    if mpv_row is None and wp_row is None: 
        master_df.loc[i, "date_discrepancy_days"] = 0
        continue

    # Now that mpv_row is initialized, saves MPV URL
    if mpv_row is not None:
        master_df.loc[i, "URL_MPV"] = mpv_row["URL_MPV"]
        
    # *************************************************************************
    # Handles Match for either (i) all 3 databases or (ii) just 2 databases
    # *************************************************************************
    
    # If a match was found in all 3 databases...
    if not master_df.loc[i, "omission_mpv"] and not master_df.loc[i, "omission_wp"]:

        # Check for discrepencies in all columns
        check_for_all_discrepencies(master_df, i, fe_row, mpv_row, wp_row)

        # Drops the used rows from mpv and wp by index (i.e., '.name')
        mpv = mpv.drop(mpv_row.name)
        wp = wp.drop(wp_row.name)

    # If a match was found in 2 of the 3 databases
    elif not master_df.loc[i, "omission_mpv"] or not master_df.loc[i, "omission_wp"]:
        
        # If MPV has a hit
        if not master_df.loc[i, "omission_mpv"]:
            check_for_all_discrepencies(master_df, i, fe_row, mpv_row, None)
            mpv = mpv.drop(mpv_row.name)
            
        # If WP has a hit
        elif not master_df.loc[i, "omission_wp"]:
            check_for_all_discrepencies(master_df, i, fe_row, None, wp_row)
            wp = wp.drop(wp_row.name)
# Out:
# Processing index 0 out of 6590 (0.0%)
# Processing index 1 out of 6590 (0.02%)
# Processing index 2 out of 6590 (0.03%)
# Processing index 3 out of 6590 (0.05%)
# Processing index 4 out of 6590 (0.06%)
# Processing index 5 out of 6590 (0.08%)
# Processing index 6 out of 6590 (0.09%)
# Processing index 7 out of 6590 (0.11%)
# Processing index 8 out of 6590 (0.12%)
# Processing index 9 out of 6590 (0.14%)
# Processing index 10 out of 6590 (0.15%)
# Processing index 11 out of 6590 (0.17%)
# Processing index 12 out of 6590 (0.18%)
# Processing index 13 out of 6590 (0.2%)
# Processing index 14 out of 6590 (0.21%)
# Processing index 15 out of 6590 (0.23%)
# Processing index 16 out of 6590 (0.24%)
# Processing index 17 out of 6590 (0.26%)
# Processing index 18 out of 6590 (0.27%)
# Processing index 19 out of 6590 (0.29%)
# Processing index 20 out of 6590 (0.3%)
# Processing index 21 out of 6590 (0.32%)
# Processing index 22 out of 6590 (0.33%)
# Processing index 23 out of 6590 (0.35%)
# Processing index 24 out of 6590 (0.36%)
# Processing index 25 out of 6590 (0.38%)
# Processing index 26 out of 6590 (0.39%)
# Processing index 27 out of 6590 (0.41%)
# Processing index 28 out of 6590 (0.42%)
# Processing index 29 out of 6590 (0.44%)
# Processing index 30 out of 6590 (0.46%)
# Processing index 31 out of 6590 (0.47%)
# Processing index 32 out of 6590 (0.49%)
# Processing index 33 out of 6590 (0.5%)
# Processing index 34 out of 6590 (0.52%)
# Processing index 35 out of 6590 (0.53%)
# Processing index 36 out of 6590 (0.55%)
# Processing index 37 out of 6590 (0.56%)
# Processing index 38 out of 6590 (0.58%)
# Processing index 39 out of 6590 (0.59%)
# Processing index 40 out of 6590 (0.61%)
# Processing index 41 out of 6590 (0.62%)
# Processing index 42 out of 6590 (0.64%)
# Processing index 43 out of 6590 (0.65%)
# Processing index 44 out of 6590 (0.67%)
# Processing index 45 out of 6590 (0.68%)
# Processing index 46 out of 6590 (0.7%)
# Processing index 47 out of 6590 (0.71%)
# Processing index 48 out of 6590 (0.73%)
# Processing index 49 out of 6590 (0.74%)
# Processing index 50 out of 6590 (0.76%)
# Processing index 51 out of 6590 (0.77%)
# Processing index 52 out of 6590 (0.79%)
# Processing index 53 out of 6590 (0.8%)
# Processing index 54 out of 6590 (0.82%)
# Processing index 55 out of 6590 (0.83%)
# Processing index 56 out of 6590 (0.85%)
# Processing index 57 out of 6590 (0.86%)
# Processing index 58 out of 6590 (0.88%)
# Processing index 59 out of 6590 (0.9%)
# Processing index 60 out of 6590 (0.91%)
# Processing index 61 out of 6590 (0.93%)
# Processing index 62 out of 6590 (0.94%)
# Processing index 63 out of 6590 (0.96%)
# Processing index 64 out of 6590 (0.97%)
# Processing index 65 out of 6590 (0.99%)
# Processing index 66 out of 6590 (1.0%)
# Processing index 67 out of 6590 (1.02%)
# Processing index 68 out of 6590 (1.03%)
# Processing index 69 out of 6590 (1.05%)
# Processing index 70 out of 6590 (1.06%)
# Processing index 71 out of 6590 (1.08%)
# Processing index 72 out of 6590 (1.09%)
# Processing index 73 out of 6590 (1.11%)
# Processing index 74 out of 6590 (1.12%)
# Processing index 75 out of 6590 (1.14%)
# Processing index 76 out of 6590 (1.15%)
# Processing index 77 out of 6590 (1.17%)
# Processing index 78 out of 6590 (1.18%)
# Processing index 79 out of 6590 (1.2%)
# Processing index 80 out of 6590 (1.21%)
# Processing index 81 out of 6590 (1.23%)
# Processing index 82 out of 6590 (1.24%)
# Processing index 83 out of 6590 (1.26%)
# Processing index 84 out of 6590 (1.27%)
# Processing index 85 out of 6590 (1.29%)
# Processing index 86 out of 6590 (1.31%)
# Processing index 87 out of 6590 (1.32%)
# Processing index 88 out of 6590 (1.34%)
# Processing index 89 out of 6590 (1.35%)
# Processing index 90 out of 6590 (1.37%)
# Processing index 91 out of 6590 (1.38%)
# Processing index 92 out of 6590 (1.4%)
# Processing index 93 out of 6590 (1.41%)
# Processing index 94 out of 6590 (1.43%)
# Processing index 95 out of 6590 (1.44%)
# Processing index 96 out of 6590 (1.46%)
# Processing index 97 out of 6590 (1.47%)
# Processing index 98 out of 6590 (1.49%)
# Processing index 99 out of 6590 (1.5%)
# Processing index 100 out of 6590 (1.52%)
# Processing index 101 out of 6590 (1.53%)
# Processing index 102 out of 6590 (1.55%)
# Processing index 103 out of 6590 (1.56%)
# Processing index 104 out of 6590 (1.58%)
# Processing index 105 out of 6590 (1.59%)
# Processing index 106 out of 6590 (1.61%)
# Processing index 107 out of 6590 (1.62%)
# Processing index 108 out of 6590 (1.64%)
# Processing index 109 out of 6590 (1.65%)
# Processing index 110 out of 6590 (1.67%)
# Processing index 111 out of 6590 (1.68%)
# Processing index 112 out of 6590 (1.7%)
# Processing index 113 out of 6590 (1.71%)
# Processing index 114 out of 6590 (1.73%)
# Processing index 115 out of 6590 (1.75%)
# Processing index 116 out of 6590 (1.76%)
# Processing index 117 out of 6590 (1.78%)
# Processing index 118 out of 6590 (1.79%)
# Processing index 119 out of 6590 (1.81%)
# Processing index 120 out of 6590 (1.82%)
# Processing index 121 out of 6590 (1.84%)
# Processing index 122 out of 6590 (1.85%)
# Processing index 123 out of 6590 (1.87%)
# Processing index 124 out of 6590 (1.88%)
# Processing index 125 out of 6590 (1.9%)
# Processing index 126 out of 6590 (1.91%)
# Processing index 127 out of 6590 (1.93%)
# Processing index 128 out of 6590 (1.94%)
# Processing index 129 out of 6590 (1.96%)
# Processing index 130 out of 6590 (1.97%)
# Processing index 131 out of 6590 (1.99%)
# Processing index 132 out of 6590 (2.0%)
# Processing index 133 out of 6590 (2.02%)
# Processing index 134 out of 6590 (2.03%)
# Processing index 135 out of 6590 (2.05%)
# Processing index 136 out of 6590 (2.06%)
# Processing index 137 out of 6590 (2.08%)
# Processing index 138 out of 6590 (2.09%)
# Processing index 139 out of 6590 (2.11%)
# Processing index 140 out of 6590 (2.12%)
# Processing index 141 out of 6590 (2.14%)
# Processing index 142 out of 6590 (2.15%)
# Processing index 143 out of 6590 (2.17%)
# Processing index 144 out of 6590 (2.19%)
# Processing index 145 out of 6590 (2.2%)
# Processing index 146 out of 6590 (2.22%)
# Processing index 147 out of 6590 (2.23%)
# Processing index 148 out of 6590 (2.25%)
# Processing index 149 out of 6590 (2.26%)
# Processing index 150 out of 6590 (2.28%)
# Processing index 151 out of 6590 (2.29%)
# Processing index 152 out of 6590 (2.31%)
# Processing index 153 out of 6590 (2.32%)
# Processing index 154 out of 6590 (2.34%)
# Processing index 155 out of 6590 (2.35%)
# Processing index 156 out of 6590 (2.37%)
# Processing index 157 out of 6590 (2.38%)
# Processing index 158 out of 6590 (2.4%)
# Processing index 159 out of 6590 (2.41%)
# Processing index 160 out of 6590 (2.43%)
# Processing index 161 out of 6590 (2.44%)
# Processing index 162 out of 6590 (2.46%)
# Processing index 163 out of 6590 (2.47%)
# Processing index 164 out of 6590 (2.49%)
# Processing index 165 out of 6590 (2.5%)
# Processing index 166 out of 6590 (2.52%)
# Processing index 167 out of 6590 (2.53%)
# Processing index 168 out of 6590 (2.55%)
# Processing index 169 out of 6590 (2.56%)
# Processing index 170 out of 6590 (2.58%)
# Processing index 171 out of 6590 (2.59%)
# Processing index 172 out of 6590 (2.61%)
# Processing index 173 out of 6590 (2.63%)
# Processing index 174 out of 6590 (2.64%)
# Processing index 175 out of 6590 (2.66%)
# Processing index 176 out of 6590 (2.67%)
# Processing index 177 out of 6590 (2.69%)
# Processing index 178 out of 6590 (2.7%)
# Processing index 179 out of 6590 (2.72%)
# Processing index 180 out of 6590 (2.73%)
# Processing index 181 out of 6590 (2.75%)
# Processing index 182 out of 6590 (2.76%)
# Processing index 183 out of 6590 (2.78%)
# Processing index 184 out of 6590 (2.79%)
# Processing index 185 out of 6590 (2.81%)
# Processing index 186 out of 6590 (2.82%)
# Processing index 187 out of 6590 (2.84%)
# Processing index 188 out of 6590 (2.85%)
# Processing index 189 out of 6590 (2.87%)
# Processing index 190 out of 6590 (2.88%)
# Processing index 191 out of 6590 (2.9%)
# Processing index 192 out of 6590 (2.91%)
# Processing index 193 out of 6590 (2.93%)
# Processing index 194 out of 6590 (2.94%)
# Processing index 195 out of 6590 (2.96%)
# Processing index 196 out of 6590 (2.97%)
# Processing index 197 out of 6590 (2.99%)
# Processing index 198 out of 6590 (3.0%)
# Processing index 199 out of 6590 (3.02%)
# Processing index 200 out of 6590 (3.03%)
# Processing index 201 out of 6590 (3.05%)
# Processing index 202 out of 6590 (3.07%)
# Processing index 203 out of 6590 (3.08%)
# Processing index 204 out of 6590 (3.1%)
# Processing index 205 out of 6590 (3.11%)
# Processing index 206 out of 6590 (3.13%)
# Processing index 207 out of 6590 (3.14%)
# Processing index 208 out of 6590 (3.16%)
# Processing index 209 out of 6590 (3.17%)
# Processing index 210 out of 6590 (3.19%)
# Processing index 211 out of 6590 (3.2%)
# Processing index 212 out of 6590 (3.22%)
# Processing index 213 out of 6590 (3.23%)
# Processing index 214 out of 6590 (3.25%)
# Processing index 215 out of 6590 (3.26%)
# Processing index 216 out of 6590 (3.28%)
# Processing index 217 out of 6590 (3.29%)
# Processing index 218 out of 6590 (3.31%)
# Processing index 219 out of 6590 (3.32%)
# Processing index 220 out of 6590 (3.34%)
# Processing index 221 out of 6590 (3.35%)
# Processing index 222 out of 6590 (3.37%)
# Processing index 223 out of 6590 (3.38%)
# Processing index 224 out of 6590 (3.4%)
# Processing index 225 out of 6590 (3.41%)
# Processing index 226 out of 6590 (3.43%)
# Processing index 227 out of 6590 (3.44%)
# Processing index 228 out of 6590 (3.46%)
# Processing index 229 out of 6590 (3.47%)
# Processing index 230 out of 6590 (3.49%)
# Processing index 231 out of 6590 (3.51%)
# Processing index 232 out of 6590 (3.52%)
# Processing index 233 out of 6590 (3.54%)
# Processing index 234 out of 6590 (3.55%)
# Processing index 235 out of 6590 (3.57%)
# Processing index 236 out of 6590 (3.58%)
# Processing index 237 out of 6590 (3.6%)
# Processing index 238 out of 6590 (3.61%)
# Processing index 239 out of 6590 (3.63%)
# Processing index 240 out of 6590 (3.64%)
# Processing index 241 out of 6590 (3.66%)
# Processing index 242 out of 6590 (3.67%)
# Processing index 243 out of 6590 (3.69%)
# Processing index 244 out of 6590 (3.7%)
# Processing index 245 out of 6590 (3.72%)
# Processing index 246 out of 6590 (3.73%)
# Processing index 247 out of 6590 (3.75%)
# Processing index 248 out of 6590 (3.76%)
# Processing index 249 out of 6590 (3.78%)
# Processing index 250 out of 6590 (3.79%)
# Processing index 251 out of 6590 (3.81%)
# Processing index 252 out of 6590 (3.82%)
# Processing index 253 out of 6590 (3.84%)
# Processing index 254 out of 6590 (3.85%)
# Processing index 255 out of 6590 (3.87%)
# Processing index 256 out of 6590 (3.88%)
# Processing index 257 out of 6590 (3.9%)
# Processing index 258 out of 6590 (3.92%)
# Processing index 259 out of 6590 (3.93%)
# Processing index 260 out of 6590 (3.95%)
# Processing index 261 out of 6590 (3.96%)
# Processing index 262 out of 6590 (3.98%)
# Processing index 263 out of 6590 (3.99%)
# Processing index 264 out of 6590 (4.01%)
# Processing index 265 out of 6590 (4.02%)
# Processing index 266 out of 6590 (4.04%)
# Processing index 267 out of 6590 (4.05%)
# Processing index 268 out of 6590 (4.07%)
# Processing index 269 out of 6590 (4.08%)
# Processing index 270 out of 6590 (4.1%)
# Processing index 271 out of 6590 (4.11%)
# Processing index 272 out of 6590 (4.13%)
# Processing index 273 out of 6590 (4.14%)
# Processing index 274 out of 6590 (4.16%)
# Processing index 275 out of 6590 (4.17%)
# Processing index 276 out of 6590 (4.19%)
# Processing index 277 out of 6590 (4.2%)
# Processing index 278 out of 6590 (4.22%)
# Processing index 279 out of 6590 (4.23%)
# Processing index 280 out of 6590 (4.25%)
# Processing index 281 out of 6590 (4.26%)
# Processing index 282 out of 6590 (4.28%)
# Processing index 283 out of 6590 (4.29%)
# Processing index 284 out of 6590 (4.31%)
# Processing index 285 out of 6590 (4.32%)
# Processing index 286 out of 6590 (4.34%)
# Processing index 287 out of 6590 (4.36%)
# Processing index 288 out of 6590 (4.37%)
# Processing index 289 out of 6590 (4.39%)
# Processing index 290 out of 6590 (4.4%)
# Processing index 291 out of 6590 (4.42%)
# Processing index 292 out of 6590 (4.43%)
# Processing index 293 out of 6590 (4.45%)
# Processing index 294 out of 6590 (4.46%)
# Processing index 295 out of 6590 (4.48%)
# Processing index 296 out of 6590 (4.49%)
# Processing index 297 out of 6590 (4.51%)
# Processing index 298 out of 6590 (4.52%)
# Processing index 299 out of 6590 (4.54%)
# Processing index 300 out of 6590 (4.55%)
# Processing index 301 out of 6590 (4.57%)
# Processing index 302 out of 6590 (4.58%)
# Processing index 303 out of 6590 (4.6%)
# Processing index 304 out of 6590 (4.61%)
# Processing index 305 out of 6590 (4.63%)
# Processing index 306 out of 6590 (4.64%)
# Processing index 307 out of 6590 (4.66%)
# Processing index 308 out of 6590 (4.67%)
# Processing index 309 out of 6590 (4.69%)
# Processing index 310 out of 6590 (4.7%)
# Processing index 311 out of 6590 (4.72%)
# Processing index 312 out of 6590 (4.73%)
# Processing index 313 out of 6590 (4.75%)
# Processing index 314 out of 6590 (4.76%)
# Processing index 315 out of 6590 (4.78%)
# Processing index 316 out of 6590 (4.8%)
# Processing index 317 out of 6590 (4.81%)
# Processing index 318 out of 6590 (4.83%)
# Processing index 319 out of 6590 (4.84%)
# Processing index 320 out of 6590 (4.86%)
# Processing index 321 out of 6590 (4.87%)
# Processing index 322 out of 6590 (4.89%)
# Processing index 323 out of 6590 (4.9%)
# Processing index 324 out of 6590 (4.92%)
# Processing index 325 out of 6590 (4.93%)
# Processing index 326 out of 6590 (4.95%)
# Processing index 327 out of 6590 (4.96%)
# Processing index 328 out of 6590 (4.98%)
# Processing index 329 out of 6590 (4.99%)
# Processing index 330 out of 6590 (5.01%)
# Processing index 331 out of 6590 (5.02%)
# Processing index 332 out of 6590 (5.04%)
# Processing index 333 out of 6590 (5.05%)
# Processing index 334 out of 6590 (5.07%)
# Processing index 335 out of 6590 (5.08%)
# Processing index 336 out of 6590 (5.1%)
# Processing index 337 out of 6590 (5.11%)
# Processing index 338 out of 6590 (5.13%)
# Processing index 339 out of 6590 (5.14%)
# Processing index 340 out of 6590 (5.16%)
# Processing index 341 out of 6590 (5.17%)
# Processing index 342 out of 6590 (5.19%)
# Processing index 343 out of 6590 (5.2%)
# Processing index 344 out of 6590 (5.22%)
# Processing index 345 out of 6590 (5.24%)
# Processing index 346 out of 6590 (5.25%)
# Processing index 347 out of 6590 (5.27%)
# Processing index 348 out of 6590 (5.28%)
# Processing index 349 out of 6590 (5.3%)
# Processing index 350 out of 6590 (5.31%)
# Processing index 351 out of 6590 (5.33%)
# Processing index 352 out of 6590 (5.34%)
# Processing index 353 out of 6590 (5.36%)
# Processing index 354 out of 6590 (5.37%)
# Processing index 355 out of 6590 (5.39%)
# Processing index 356 out of 6590 (5.4%)
# Processing index 357 out of 6590 (5.42%)
# Processing index 358 out of 6590 (5.43%)
# Processing index 359 out of 6590 (5.45%)
# Processing index 360 out of 6590 (5.46%)
# Processing index 361 out of 6590 (5.48%)
# Processing index 362 out of 6590 (5.49%)
# Processing index 363 out of 6590 (5.51%)
# Processing index 364 out of 6590 (5.52%)
# Processing index 365 out of 6590 (5.54%)
# Processing index 366 out of 6590 (5.55%)
# Processing index 367 out of 6590 (5.57%)
# Processing index 368 out of 6590 (5.58%)
# Processing index 369 out of 6590 (5.6%)
# Processing index 370 out of 6590 (5.61%)
# Processing index 371 out of 6590 (5.63%)
# Processing index 372 out of 6590 (5.64%)
# Processing index 373 out of 6590 (5.66%)
# Processing index 374 out of 6590 (5.68%)
# Processing index 375 out of 6590 (5.69%)
# Processing index 376 out of 6590 (5.71%)
# Processing index 377 out of 6590 (5.72%)
# Processing index 378 out of 6590 (5.74%)
# Processing index 379 out of 6590 (5.75%)
# Processing index 380 out of 6590 (5.77%)
# Processing index 381 out of 6590 (5.78%)
# Processing index 382 out of 6590 (5.8%)
# Processing index 383 out of 6590 (5.81%)
# Processing index 384 out of 6590 (5.83%)
# Processing index 385 out of 6590 (5.84%)
# Processing index 386 out of 6590 (5.86%)
# Processing index 387 out of 6590 (5.87%)
# Processing index 388 out of 6590 (5.89%)
# Processing index 389 out of 6590 (5.9%)
# Processing index 390 out of 6590 (5.92%)
# Processing index 391 out of 6590 (5.93%)
# Processing index 392 out of 6590 (5.95%)
# Processing index 393 out of 6590 (5.96%)
# Processing index 394 out of 6590 (5.98%)
# Processing index 395 out of 6590 (5.99%)
# Processing index 396 out of 6590 (6.01%)
# Processing index 397 out of 6590 (6.02%)
# Processing index 398 out of 6590 (6.04%)
# Processing index 399 out of 6590 (6.05%)
# Processing index 400 out of 6590 (6.07%)
# Processing index 401 out of 6590 (6.08%)
# Processing index 402 out of 6590 (6.1%)
# Processing index 403 out of 6590 (6.12%)
# Processing index 404 out of 6590 (6.13%)
# Processing index 405 out of 6590 (6.15%)
# Processing index 406 out of 6590 (6.16%)
# Processing index 407 out of 6590 (6.18%)
# Processing index 408 out of 6590 (6.19%)
# Processing index 409 out of 6590 (6.21%)
# Processing index 410 out of 6590 (6.22%)
# Processing index 411 out of 6590 (6.24%)
# Processing index 412 out of 6590 (6.25%)
# Processing index 413 out of 6590 (6.27%)
# Processing index 414 out of 6590 (6.28%)
# Processing index 415 out of 6590 (6.3%)
# Processing index 416 out of 6590 (6.31%)
# Processing index 417 out of 6590 (6.33%)
# Processing index 418 out of 6590 (6.34%)
# Processing index 419 out of 6590 (6.36%)
# Processing index 420 out of 6590 (6.37%)
# Processing index 421 out of 6590 (6.39%)
# Processing index 422 out of 6590 (6.4%)
# Processing index 423 out of 6590 (6.42%)
# Processing index 424 out of 6590 (6.43%)
# Processing index 425 out of 6590 (6.45%)
# Processing index 426 out of 6590 (6.46%)
# Processing index 427 out of 6590 (6.48%)
# Processing index 428 out of 6590 (6.49%)
# Processing index 429 out of 6590 (6.51%)
# Processing index 430 out of 6590 (6.53%)
# Processing index 431 out of 6590 (6.54%)
# Processing index 432 out of 6590 (6.56%)
# Processing index 433 out of 6590 (6.57%)
# Processing index 434 out of 6590 (6.59%)
# Processing index 435 out of 6590 (6.6%)
# Processing index 436 out of 6590 (6.62%)
# Processing index 437 out of 6590 (6.63%)
# Processing index 438 out of 6590 (6.65%)
# Processing index 439 out of 6590 (6.66%)
# Processing index 440 out of 6590 (6.68%)
# Processing index 441 out of 6590 (6.69%)
# Processing index 442 out of 6590 (6.71%)
# Processing index 443 out of 6590 (6.72%)
# Processing index 444 out of 6590 (6.74%)
# Processing index 445 out of 6590 (6.75%)
# Processing index 446 out of 6590 (6.77%)
# Processing index 447 out of 6590 (6.78%)
# Processing index 448 out of 6590 (6.8%)
# Processing index 449 out of 6590 (6.81%)
# Processing index 450 out of 6590 (6.83%)
# Processing index 451 out of 6590 (6.84%)
# Processing index 452 out of 6590 (6.86%)
# Processing index 453 out of 6590 (6.87%)
# Processing index 454 out of 6590 (6.89%)
# Processing index 455 out of 6590 (6.9%)
# Processing index 456 out of 6590 (6.92%)
# Processing index 457 out of 6590 (6.93%)
# Processing index 458 out of 6590 (6.95%)
# Processing index 459 out of 6590 (6.97%)
# Processing index 460 out of 6590 (6.98%)
# Processing index 461 out of 6590 (7.0%)
# Processing index 462 out of 6590 (7.01%)
# Processing index 463 out of 6590 (7.03%)
# Processing index 464 out of 6590 (7.04%)
# Processing index 465 out of 6590 (7.06%)
# Processing index 466 out of 6590 (7.07%)
# Processing index 467 out of 6590 (7.09%)
# Processing index 468 out of 6590 (7.1%)
# Processing index 469 out of 6590 (7.12%)
# Processing index 470 out of 6590 (7.13%)
# Processing index 471 out of 6590 (7.15%)
# Processing index 472 out of 6590 (7.16%)
# Processing index 473 out of 6590 (7.18%)
# Processing index 474 out of 6590 (7.19%)
# Processing index 475 out of 6590 (7.21%)
# Processing index 476 out of 6590 (7.22%)
# Processing index 477 out of 6590 (7.24%)
# Processing index 478 out of 6590 (7.25%)
# Processing index 479 out of 6590 (7.27%)
# Processing index 480 out of 6590 (7.28%)
# Processing index 481 out of 6590 (7.3%)
# Processing index 482 out of 6590 (7.31%)
# Processing index 483 out of 6590 (7.33%)
# Processing index 484 out of 6590 (7.34%)
# Processing index 485 out of 6590 (7.36%)
# Processing index 486 out of 6590 (7.37%)
# Processing index 487 out of 6590 (7.39%)
# Processing index 488 out of 6590 (7.41%)
# Processing index 489 out of 6590 (7.42%)
# Processing index 490 out of 6590 (7.44%)
# Processing index 491 out of 6590 (7.45%)
# Processing index 492 out of 6590 (7.47%)
# Processing index 493 out of 6590 (7.48%)
# Processing index 494 out of 6590 (7.5%)
# Processing index 495 out of 6590 (7.51%)
# Processing index 496 out of 6590 (7.53%)
# Processing index 497 out of 6590 (7.54%)
# Processing index 498 out of 6590 (7.56%)
# Processing index 499 out of 6590 (7.57%)
# Processing index 500 out of 6590 (7.59%)
# Processing index 501 out of 6590 (7.6%)
# Processing index 502 out of 6590 (7.62%)
# Processing index 503 out of 6590 (7.63%)
# Processing index 504 out of 6590 (7.65%)
# Processing index 505 out of 6590 (7.66%)
# Processing index 506 out of 6590 (7.68%)
# Processing index 507 out of 6590 (7.69%)
# Processing index 508 out of 6590 (7.71%)
# Processing index 509 out of 6590 (7.72%)
# Processing index 510 out of 6590 (7.74%)
# Processing index 511 out of 6590 (7.75%)
# Processing index 512 out of 6590 (7.77%)
# Processing index 513 out of 6590 (7.78%)
# Processing index 514 out of 6590 (7.8%)
# Processing index 515 out of 6590 (7.81%)
# Processing index 516 out of 6590 (7.83%)
# Processing index 517 out of 6590 (7.85%)
# Processing index 518 out of 6590 (7.86%)
# Processing index 519 out of 6590 (7.88%)
# Processing index 520 out of 6590 (7.89%)
# Processing index 521 out of 6590 (7.91%)
# Processing index 522 out of 6590 (7.92%)
# Processing index 523 out of 6590 (7.94%)
# Processing index 524 out of 6590 (7.95%)
# Processing index 525 out of 6590 (7.97%)
# Processing index 526 out of 6590 (7.98%)
# Processing index 527 out of 6590 (8.0%)
# Processing index 528 out of 6590 (8.01%)
# Processing index 529 out of 6590 (8.03%)
# Processing index 530 out of 6590 (8.04%)
# Processing index 531 out of 6590 (8.06%)
# Processing index 532 out of 6590 (8.07%)
# Processing index 533 out of 6590 (8.09%)
# Processing index 534 out of 6590 (8.1%)
# Processing index 535 out of 6590 (8.12%)
# Processing index 536 out of 6590 (8.13%)
# Processing index 537 out of 6590 (8.15%)
# Processing index 538 out of 6590 (8.16%)
# Processing index 539 out of 6590 (8.18%)
# Processing index 540 out of 6590 (8.19%)
# Processing index 541 out of 6590 (8.21%)
# Processing index 542 out of 6590 (8.22%)
# Processing index 543 out of 6590 (8.24%)
# Processing index 544 out of 6590 (8.25%)
# Processing index 545 out of 6590 (8.27%)
# Processing index 546 out of 6590 (8.29%)
# Processing index 547 out of 6590 (8.3%)
# Processing index 548 out of 6590 (8.32%)
# Processing index 549 out of 6590 (8.33%)
# Processing index 550 out of 6590 (8.35%)
# Processing index 551 out of 6590 (8.36%)
# Processing index 552 out of 6590 (8.38%)
# Processing index 553 out of 6590 (8.39%)
# Processing index 554 out of 6590 (8.41%)
# Processing index 555 out of 6590 (8.42%)
# Processing index 556 out of 6590 (8.44%)
# Processing index 557 out of 6590 (8.45%)
# Processing index 558 out of 6590 (8.47%)
# Processing index 559 out of 6590 (8.48%)
# Processing index 560 out of 6590 (8.5%)
# Processing index 561 out of 6590 (8.51%)
# Processing index 562 out of 6590 (8.53%)
# Processing index 563 out of 6590 (8.54%)
# Processing index 564 out of 6590 (8.56%)
# Processing index 565 out of 6590 (8.57%)
# Processing index 566 out of 6590 (8.59%)
# Processing index 567 out of 6590 (8.6%)
# Processing index 568 out of 6590 (8.62%)
# Processing index 569 out of 6590 (8.63%)
# Processing index 570 out of 6590 (8.65%)
# Processing index 571 out of 6590 (8.66%)
# Processing index 572 out of 6590 (8.68%)
# Processing index 573 out of 6590 (8.69%)
# Processing index 574 out of 6590 (8.71%)
# Processing index 575 out of 6590 (8.73%)
# Processing index 576 out of 6590 (8.74%)
# Processing index 577 out of 6590 (8.76%)
# Processing index 578 out of 6590 (8.77%)
# Processing index 579 out of 6590 (8.79%)
# Processing index 580 out of 6590 (8.8%)
# Processing index 581 out of 6590 (8.82%)
# Processing index 582 out of 6590 (8.83%)
# Processing index 583 out of 6590 (8.85%)
# Processing index 584 out of 6590 (8.86%)
# Processing index 585 out of 6590 (8.88%)
# Processing index 586 out of 6590 (8.89%)
# Processing index 587 out of 6590 (8.91%)
# Processing index 588 out of 6590 (8.92%)
# Processing index 589 out of 6590 (8.94%)
# Processing index 590 out of 6590 (8.95%)
# Processing index 591 out of 6590 (8.97%)
# Processing index 592 out of 6590 (8.98%)
# Processing index 593 out of 6590 (9.0%)
# Processing index 594 out of 6590 (9.01%)
# Processing index 595 out of 6590 (9.03%)
# Processing index 596 out of 6590 (9.04%)
# Processing index 597 out of 6590 (9.06%)
# Processing index 598 out of 6590 (9.07%)
# Processing index 599 out of 6590 (9.09%)
# Processing index 600 out of 6590 (9.1%)
# Processing index 601 out of 6590 (9.12%)
# Processing index 602 out of 6590 (9.14%)
# Processing index 603 out of 6590 (9.15%)
# Processing index 604 out of 6590 (9.17%)
# Processing index 605 out of 6590 (9.18%)
# Processing index 606 out of 6590 (9.2%)
# Processing index 607 out of 6590 (9.21%)
# Processing index 608 out of 6590 (9.23%)
# Processing index 609 out of 6590 (9.24%)
# Processing index 610 out of 6590 (9.26%)
# Processing index 611 out of 6590 (9.27%)
# Processing index 612 out of 6590 (9.29%)
# Processing index 613 out of 6590 (9.3%)
# Processing index 614 out of 6590 (9.32%)
# Processing index 615 out of 6590 (9.33%)
# Processing index 616 out of 6590 (9.35%)
# Processing index 617 out of 6590 (9.36%)
# Processing index 618 out of 6590 (9.38%)
# Processing index 619 out of 6590 (9.39%)
# Processing index 620 out of 6590 (9.41%)
# Processing index 621 out of 6590 (9.42%)
# Processing index 622 out of 6590 (9.44%)
# Processing index 623 out of 6590 (9.45%)
# Processing index 624 out of 6590 (9.47%)
# Processing index 625 out of 6590 (9.48%)
# Processing index 626 out of 6590 (9.5%)
# Processing index 627 out of 6590 (9.51%)
# Processing index 628 out of 6590 (9.53%)
# Processing index 629 out of 6590 (9.54%)
# Processing index 630 out of 6590 (9.56%)
# Processing index 631 out of 6590 (9.58%)
# Processing index 632 out of 6590 (9.59%)
# Processing index 633 out of 6590 (9.61%)
# Processing index 634 out of 6590 (9.62%)
# Processing index 635 out of 6590 (9.64%)
# Processing index 636 out of 6590 (9.65%)
# Processing index 637 out of 6590 (9.67%)
# Processing index 638 out of 6590 (9.68%)
# Processing index 639 out of 6590 (9.7%)
# Processing index 640 out of 6590 (9.71%)
# Processing index 641 out of 6590 (9.73%)
# Processing index 642 out of 6590 (9.74%)
# Processing index 643 out of 6590 (9.76%)
# Processing index 644 out of 6590 (9.77%)
# Processing index 645 out of 6590 (9.79%)
# Processing index 646 out of 6590 (9.8%)
# Processing index 647 out of 6590 (9.82%)
# Processing index 648 out of 6590 (9.83%)
# Processing index 649 out of 6590 (9.85%)
# Processing index 650 out of 6590 (9.86%)
# Processing index 651 out of 6590 (9.88%)
# Processing index 652 out of 6590 (9.89%)
# Processing index 653 out of 6590 (9.91%)
# Processing index 654 out of 6590 (9.92%)
# Processing index 655 out of 6590 (9.94%)
# Processing index 656 out of 6590 (9.95%)
# Processing index 657 out of 6590 (9.97%)
# Processing index 658 out of 6590 (9.98%)
# Processing index 659 out of 6590 (10.0%)
# Processing index 660 out of 6590 (10.02%)
# Processing index 661 out of 6590 (10.03%)
# Processing index 662 out of 6590 (10.05%)
# Processing index 663 out of 6590 (10.06%)
# Processing index 664 out of 6590 (10.08%)
# Processing index 665 out of 6590 (10.09%)
# Processing index 666 out of 6590 (10.11%)
# Processing index 667 out of 6590 (10.12%)
# Processing index 668 out of 6590 (10.14%)
# Processing index 669 out of 6590 (10.15%)
# Processing index 670 out of 6590 (10.17%)
# Processing index 671 out of 6590 (10.18%)
# Processing index 672 out of 6590 (10.2%)
# Processing index 673 out of 6590 (10.21%)
# Processing index 674 out of 6590 (10.23%)
# Processing index 675 out of 6590 (10.24%)
# Processing index 676 out of 6590 (10.26%)
# Processing index 677 out of 6590 (10.27%)
# Processing index 678 out of 6590 (10.29%)
# Processing index 679 out of 6590 (10.3%)
# Processing index 680 out of 6590 (10.32%)
# Processing index 681 out of 6590 (10.33%)
# Processing index 682 out of 6590 (10.35%)
# Processing index 683 out of 6590 (10.36%)
# Processing index 684 out of 6590 (10.38%)
# Processing index 685 out of 6590 (10.39%)
# Processing index 686 out of 6590 (10.41%)
# Processing index 687 out of 6590 (10.42%)
# Processing index 688 out of 6590 (10.44%)
# Processing index 689 out of 6590 (10.46%)
# Processing index 690 out of 6590 (10.47%)
# Processing index 691 out of 6590 (10.49%)
# Processing index 692 out of 6590 (10.5%)
# Processing index 693 out of 6590 (10.52%)
# Processing index 694 out of 6590 (10.53%)
# Processing index 695 out of 6590 (10.55%)
# Processing index 696 out of 6590 (10.56%)
# Processing index 697 out of 6590 (10.58%)
# Processing index 698 out of 6590 (10.59%)
# Processing index 699 out of 6590 (10.61%)
# Processing index 700 out of 6590 (10.62%)
# Processing index 701 out of 6590 (10.64%)
# Processing index 702 out of 6590 (10.65%)
# Processing index 703 out of 6590 (10.67%)
# Processing index 704 out of 6590 (10.68%)
# Processing index 705 out of 6590 (10.7%)
# Processing index 706 out of 6590 (10.71%)
# Processing index 707 out of 6590 (10.73%)
# Processing index 708 out of 6590 (10.74%)
# Processing index 709 out of 6590 (10.76%)
# Processing index 710 out of 6590 (10.77%)
# Processing index 711 out of 6590 (10.79%)
# Processing index 712 out of 6590 (10.8%)
# Processing index 713 out of 6590 (10.82%)
# Processing index 714 out of 6590 (10.83%)
# Processing index 715 out of 6590 (10.85%)
# Processing index 716 out of 6590 (10.86%)
# Processing index 717 out of 6590 (10.88%)
# Processing index 718 out of 6590 (10.9%)
# Processing index 719 out of 6590 (10.91%)
# Processing index 720 out of 6590 (10.93%)
# Processing index 721 out of 6590 (10.94%)
# Processing index 722 out of 6590 (10.96%)
# Processing index 723 out of 6590 (10.97%)
# Processing index 724 out of 6590 (10.99%)
# Processing index 725 out of 6590 (11.0%)
# Processing index 726 out of 6590 (11.02%)
# Processing index 727 out of 6590 (11.03%)
# Processing index 728 out of 6590 (11.05%)
# Processing index 729 out of 6590 (11.06%)
# Processing index 730 out of 6590 (11.08%)
# Processing index 731 out of 6590 (11.09%)
# Processing index 732 out of 6590 (11.11%)
# Processing index 733 out of 6590 (11.12%)
# Processing index 734 out of 6590 (11.14%)
# Processing index 735 out of 6590 (11.15%)
# Processing index 736 out of 6590 (11.17%)
# Processing index 737 out of 6590 (11.18%)
# Processing index 738 out of 6590 (11.2%)
# Processing index 739 out of 6590 (11.21%)
# Processing index 740 out of 6590 (11.23%)
# Processing index 741 out of 6590 (11.24%)
# Processing index 742 out of 6590 (11.26%)
# Processing index 743 out of 6590 (11.27%)
# Processing index 744 out of 6590 (11.29%)
# Processing index 745 out of 6590 (11.31%)
# Processing index 746 out of 6590 (11.32%)
# Processing index 747 out of 6590 (11.34%)
# Processing index 748 out of 6590 (11.35%)
# Processing index 749 out of 6590 (11.37%)
# Processing index 750 out of 6590 (11.38%)
# Processing index 751 out of 6590 (11.4%)
# Processing index 752 out of 6590 (11.41%)
# Processing index 753 out of 6590 (11.43%)
# Processing index 754 out of 6590 (11.44%)
# Processing index 755 out of 6590 (11.46%)
# Processing index 756 out of 6590 (11.47%)
# Processing index 757 out of 6590 (11.49%)
# Processing index 758 out of 6590 (11.5%)
# Processing index 759 out of 6590 (11.52%)
# Processing index 760 out of 6590 (11.53%)
# Processing index 761 out of 6590 (11.55%)
# Processing index 762 out of 6590 (11.56%)
# Processing index 763 out of 6590 (11.58%)
# Processing index 764 out of 6590 (11.59%)
# Processing index 765 out of 6590 (11.61%)
# Processing index 766 out of 6590 (11.62%)
# Processing index 767 out of 6590 (11.64%)
# Processing index 768 out of 6590 (11.65%)
# Processing index 769 out of 6590 (11.67%)
# Processing index 770 out of 6590 (11.68%)
# Processing index 771 out of 6590 (11.7%)
# Processing index 772 out of 6590 (11.71%)
# Processing index 773 out of 6590 (11.73%)
# Processing index 774 out of 6590 (11.75%)
# Processing index 775 out of 6590 (11.76%)
# Processing index 776 out of 6590 (11.78%)
# Processing index 777 out of 6590 (11.79%)
# Processing index 778 out of 6590 (11.81%)
# Processing index 779 out of 6590 (11.82%)
# Processing index 780 out of 6590 (11.84%)
# Processing index 781 out of 6590 (11.85%)
# Processing index 782 out of 6590 (11.87%)
# Processing index 783 out of 6590 (11.88%)
# Processing index 784 out of 6590 (11.9%)
# Processing index 785 out of 6590 (11.91%)
# Processing index 786 out of 6590 (11.93%)
# Processing index 787 out of 6590 (11.94%)
# Processing index 788 out of 6590 (11.96%)
# Processing index 789 out of 6590 (11.97%)
# Processing index 790 out of 6590 (11.99%)
# Processing index 791 out of 6590 (12.0%)
# Processing index 792 out of 6590 (12.02%)
# Processing index 793 out of 6590 (12.03%)
# Processing index 794 out of 6590 (12.05%)
# Processing index 795 out of 6590 (12.06%)
# Processing index 796 out of 6590 (12.08%)
# Processing index 797 out of 6590 (12.09%)
# Processing index 798 out of 6590 (12.11%)
# Processing index 799 out of 6590 (12.12%)
# Processing index 800 out of 6590 (12.14%)
# Processing index 801 out of 6590 (12.15%)
# Processing index 802 out of 6590 (12.17%)
# Processing index 803 out of 6590 (12.19%)
# Processing index 804 out of 6590 (12.2%)
# Processing index 805 out of 6590 (12.22%)
# Processing index 806 out of 6590 (12.23%)
# Processing index 807 out of 6590 (12.25%)
# Processing index 808 out of 6590 (12.26%)
# Processing index 809 out of 6590 (12.28%)
# Processing index 810 out of 6590 (12.29%)
# Processing index 811 out of 6590 (12.31%)
# Processing index 812 out of 6590 (12.32%)
# Processing index 813 out of 6590 (12.34%)
# Processing index 814 out of 6590 (12.35%)
# Processing index 815 out of 6590 (12.37%)
# Processing index 816 out of 6590 (12.38%)
# Processing index 817 out of 6590 (12.4%)
# Processing index 818 out of 6590 (12.41%)
# Processing index 819 out of 6590 (12.43%)
# Processing index 820 out of 6590 (12.44%)
# Processing index 821 out of 6590 (12.46%)
# Processing index 822 out of 6590 (12.47%)
# Processing index 823 out of 6590 (12.49%)
# Processing index 824 out of 6590 (12.5%)
# Processing index 825 out of 6590 (12.52%)
# Processing index 826 out of 6590 (12.53%)
# Processing index 827 out of 6590 (12.55%)
# Processing index 828 out of 6590 (12.56%)
# Processing index 829 out of 6590 (12.58%)
# Processing index 830 out of 6590 (12.59%)
# Processing index 831 out of 6590 (12.61%)
# Processing index 832 out of 6590 (12.63%)
# Processing index 833 out of 6590 (12.64%)
# Processing index 834 out of 6590 (12.66%)
# Processing index 835 out of 6590 (12.67%)
# Processing index 836 out of 6590 (12.69%)
# Processing index 837 out of 6590 (12.7%)
# Processing index 838 out of 6590 (12.72%)
# Processing index 839 out of 6590 (12.73%)
# Processing index 840 out of 6590 (12.75%)
# Processing index 841 out of 6590 (12.76%)
# Processing index 842 out of 6590 (12.78%)
# Processing index 843 out of 6590 (12.79%)
# Processing index 844 out of 6590 (12.81%)
# Processing index 845 out of 6590 (12.82%)
# Processing index 846 out of 6590 (12.84%)
# Processing index 847 out of 6590 (12.85%)
# Processing index 848 out of 6590 (12.87%)
# Processing index 849 out of 6590 (12.88%)
# Processing index 850 out of 6590 (12.9%)
# Processing index 851 out of 6590 (12.91%)
# Processing index 852 out of 6590 (12.93%)
# Processing index 853 out of 6590 (12.94%)
# Processing index 854 out of 6590 (12.96%)
# Processing index 855 out of 6590 (12.97%)
# Processing index 856 out of 6590 (12.99%)
# Processing index 857 out of 6590 (13.0%)
# Processing index 858 out of 6590 (13.02%)
# Processing index 859 out of 6590 (13.03%)
# Processing index 860 out of 6590 (13.05%)
# Processing index 861 out of 6590 (13.07%)
# Processing index 862 out of 6590 (13.08%)
# Processing index 863 out of 6590 (13.1%)
# Processing index 864 out of 6590 (13.11%)
# Processing index 865 out of 6590 (13.13%)
# Processing index 866 out of 6590 (13.14%)
# Processing index 867 out of 6590 (13.16%)
# Processing index 868 out of 6590 (13.17%)
# Processing index 869 out of 6590 (13.19%)
# Processing index 870 out of 6590 (13.2%)
# Processing index 871 out of 6590 (13.22%)
# Processing index 872 out of 6590 (13.23%)
# Processing index 873 out of 6590 (13.25%)
# Processing index 874 out of 6590 (13.26%)
# Processing index 875 out of 6590 (13.28%)
# Processing index 876 out of 6590 (13.29%)
# Processing index 877 out of 6590 (13.31%)
# Processing index 878 out of 6590 (13.32%)
# Processing index 879 out of 6590 (13.34%)
# Processing index 880 out of 6590 (13.35%)
# Processing index 881 out of 6590 (13.37%)
# Processing index 882 out of 6590 (13.38%)
# Processing index 883 out of 6590 (13.4%)
# Processing index 884 out of 6590 (13.41%)
# Processing index 885 out of 6590 (13.43%)
# Processing index 886 out of 6590 (13.44%)
# Processing index 887 out of 6590 (13.46%)
# Processing index 888 out of 6590 (13.47%)
# Processing index 889 out of 6590 (13.49%)
# Processing index 890 out of 6590 (13.51%)
# Processing index 891 out of 6590 (13.52%)
# Processing index 892 out of 6590 (13.54%)
# Processing index 893 out of 6590 (13.55%)
# Processing index 894 out of 6590 (13.57%)
# Processing index 895 out of 6590 (13.58%)
# Processing index 896 out of 6590 (13.6%)
# Processing index 897 out of 6590 (13.61%)
# Processing index 898 out of 6590 (13.63%)
# Processing index 899 out of 6590 (13.64%)
# Processing index 900 out of 6590 (13.66%)
# Processing index 901 out of 6590 (13.67%)
# Processing index 902 out of 6590 (13.69%)
# Processing index 903 out of 6590 (13.7%)
# Processing index 904 out of 6590 (13.72%)
# Processing index 905 out of 6590 (13.73%)
# Processing index 906 out of 6590 (13.75%)
# Processing index 907 out of 6590 (13.76%)
# Processing index 908 out of 6590 (13.78%)
# Processing index 909 out of 6590 (13.79%)
# Processing index 910 out of 6590 (13.81%)
# Processing index 911 out of 6590 (13.82%)
# Processing index 912 out of 6590 (13.84%)
# Processing index 913 out of 6590 (13.85%)
# Processing index 914 out of 6590 (13.87%)
# Processing index 915 out of 6590 (13.88%)
# Processing index 916 out of 6590 (13.9%)
# Processing index 917 out of 6590 (13.92%)
# Processing index 918 out of 6590 (13.93%)
# Processing index 919 out of 6590 (13.95%)
# Processing index 920 out of 6590 (13.96%)
# Processing index 921 out of 6590 (13.98%)
# Processing index 922 out of 6590 (13.99%)
# Processing index 923 out of 6590 (14.01%)
# Processing index 924 out of 6590 (14.02%)
# Processing index 925 out of 6590 (14.04%)
# Processing index 926 out of 6590 (14.05%)
# Processing index 927 out of 6590 (14.07%)
# Processing index 928 out of 6590 (14.08%)
# Processing index 929 out of 6590 (14.1%)
# Processing index 930 out of 6590 (14.11%)
# Processing index 931 out of 6590 (14.13%)
# Processing index 932 out of 6590 (14.14%)
# Processing index 933 out of 6590 (14.16%)
# Processing index 934 out of 6590 (14.17%)
# Processing index 935 out of 6590 (14.19%)
# Processing index 936 out of 6590 (14.2%)
# Processing index 937 out of 6590 (14.22%)
# Processing index 938 out of 6590 (14.23%)
# Processing index 939 out of 6590 (14.25%)
# Processing index 940 out of 6590 (14.26%)
# Processing index 941 out of 6590 (14.28%)
# Processing index 942 out of 6590 (14.29%)
# Processing index 943 out of 6590 (14.31%)
# Processing index 944 out of 6590 (14.32%)
# Processing index 945 out of 6590 (14.34%)
# Processing index 946 out of 6590 (14.36%)
# Processing index 947 out of 6590 (14.37%)
# Processing index 948 out of 6590 (14.39%)
# Processing index 949 out of 6590 (14.4%)
# Processing index 950 out of 6590 (14.42%)
# Processing index 951 out of 6590 (14.43%)
# Processing index 952 out of 6590 (14.45%)
# Processing index 953 out of 6590 (14.46%)
# Processing index 954 out of 6590 (14.48%)
# Processing index 955 out of 6590 (14.49%)
# Processing index 956 out of 6590 (14.51%)
# Processing index 957 out of 6590 (14.52%)
# Processing index 958 out of 6590 (14.54%)
# Processing index 959 out of 6590 (14.55%)
# Processing index 960 out of 6590 (14.57%)
# Processing index 961 out of 6590 (14.58%)
# Processing index 962 out of 6590 (14.6%)
# Processing index 963 out of 6590 (14.61%)
# Processing index 964 out of 6590 (14.63%)
# Processing index 965 out of 6590 (14.64%)
# Processing index 966 out of 6590 (14.66%)
# Processing index 967 out of 6590 (14.67%)
# Processing index 968 out of 6590 (14.69%)
# Processing index 969 out of 6590 (14.7%)
# Processing index 970 out of 6590 (14.72%)
# Processing index 971 out of 6590 (14.73%)
# Processing index 972 out of 6590 (14.75%)
# Processing index 973 out of 6590 (14.76%)
# Processing index 974 out of 6590 (14.78%)
# Processing index 975 out of 6590 (14.8%)
# Processing index 976 out of 6590 (14.81%)
# Processing index 977 out of 6590 (14.83%)
# Processing index 978 out of 6590 (14.84%)
# Processing index 979 out of 6590 (14.86%)
# Processing index 980 out of 6590 (14.87%)
# Processing index 981 out of 6590 (14.89%)
# Processing index 982 out of 6590 (14.9%)
# Processing index 983 out of 6590 (14.92%)
# Processing index 984 out of 6590 (14.93%)
# Processing index 985 out of 6590 (14.95%)
# Processing index 986 out of 6590 (14.96%)
# Processing index 987 out of 6590 (14.98%)
# Processing index 988 out of 6590 (14.99%)
# Processing index 989 out of 6590 (15.01%)
# Processing index 990 out of 6590 (15.02%)
# Processing index 991 out of 6590 (15.04%)
# Processing index 992 out of 6590 (15.05%)
# Processing index 993 out of 6590 (15.07%)
# Processing index 994 out of 6590 (15.08%)
# Processing index 995 out of 6590 (15.1%)
# Processing index 996 out of 6590 (15.11%)
# Processing index 997 out of 6590 (15.13%)
# Processing index 998 out of 6590 (15.14%)
# Processing index 999 out of 6590 (15.16%)
# Processing index 1000 out of 6590 (15.17%)
# Processing index 1001 out of 6590 (15.19%)
# Processing index 1002 out of 6590 (15.2%)
# Processing index 1003 out of 6590 (15.22%)
# Processing index 1004 out of 6590 (15.24%)
# Processing index 1005 out of 6590 (15.25%)
# Processing index 1006 out of 6590 (15.27%)
# Processing index 1007 out of 6590 (15.28%)
# Processing index 1008 out of 6590 (15.3%)
# Processing index 1009 out of 6590 (15.31%)
# Processing index 1010 out of 6590 (15.33%)
# Processing index 1011 out of 6590 (15.34%)
# Processing index 1012 out of 6590 (15.36%)
# Processing index 1013 out of 6590 (15.37%)
# Processing index 1014 out of 6590 (15.39%)
# Processing index 1015 out of 6590 (15.4%)
# Processing index 1016 out of 6590 (15.42%)
# Processing index 1017 out of 6590 (15.43%)
# Processing index 1018 out of 6590 (15.45%)
# Processing index 1019 out of 6590 (15.46%)
# Processing index 1020 out of 6590 (15.48%)
# Processing index 1021 out of 6590 (15.49%)
# Processing index 1022 out of 6590 (15.51%)
# Processing index 1023 out of 6590 (15.52%)
# Processing index 1024 out of 6590 (15.54%)
# Processing index 1025 out of 6590 (15.55%)
# Processing index 1026 out of 6590 (15.57%)
# Processing index 1027 out of 6590 (15.58%)
# Processing index 1028 out of 6590 (15.6%)
# Processing index 1029 out of 6590 (15.61%)
# Processing index 1030 out of 6590 (15.63%)
# Processing index 1031 out of 6590 (15.64%)
# Processing index 1032 out of 6590 (15.66%)
# Processing index 1033 out of 6590 (15.68%)
# Processing index 1034 out of 6590 (15.69%)
# Processing index 1035 out of 6590 (15.71%)
# Processing index 1036 out of 6590 (15.72%)
# Processing index 1037 out of 6590 (15.74%)
# Processing index 1038 out of 6590 (15.75%)
# Processing index 1039 out of 6590 (15.77%)
# Processing index 1040 out of 6590 (15.78%)
# Processing index 1041 out of 6590 (15.8%)
# Processing index 1042 out of 6590 (15.81%)
# Processing index 1043 out of 6590 (15.83%)
# Processing index 1044 out of 6590 (15.84%)
# Processing index 1045 out of 6590 (15.86%)
# Processing index 1046 out of 6590 (15.87%)
# Processing index 1047 out of 6590 (15.89%)
# Processing index 1048 out of 6590 (15.9%)
# Processing index 1049 out of 6590 (15.92%)
# Processing index 1050 out of 6590 (15.93%)
# Processing index 1051 out of 6590 (15.95%)
# Processing index 1052 out of 6590 (15.96%)
# Processing index 1053 out of 6590 (15.98%)
# Processing index 1054 out of 6590 (15.99%)
# Processing index 1055 out of 6590 (16.01%)
# Processing index 1056 out of 6590 (16.02%)
# Processing index 1057 out of 6590 (16.04%)
# Processing index 1058 out of 6590 (16.05%)
# Processing index 1059 out of 6590 (16.07%)
# Processing index 1060 out of 6590 (16.08%)
# Processing index 1061 out of 6590 (16.1%)
# Processing index 1062 out of 6590 (16.12%)
# Processing index 1063 out of 6590 (16.13%)
# Processing index 1064 out of 6590 (16.15%)
# Processing index 1065 out of 6590 (16.16%)
# Processing index 1066 out of 6590 (16.18%)
# Processing index 1067 out of 6590 (16.19%)
# Processing index 1068 out of 6590 (16.21%)
# Processing index 1069 out of 6590 (16.22%)
# Processing index 1070 out of 6590 (16.24%)
# Processing index 1071 out of 6590 (16.25%)
# Processing index 1072 out of 6590 (16.27%)
# Processing index 1073 out of 6590 (16.28%)
# Processing index 1074 out of 6590 (16.3%)
# Processing index 1075 out of 6590 (16.31%)
# Processing index 1076 out of 6590 (16.33%)
# Processing index 1077 out of 6590 (16.34%)
# Processing index 1078 out of 6590 (16.36%)
# Processing index 1079 out of 6590 (16.37%)
# Processing index 1080 out of 6590 (16.39%)
# Processing index 1081 out of 6590 (16.4%)
# Processing index 1082 out of 6590 (16.42%)
# Processing index 1083 out of 6590 (16.43%)
# Processing index 1084 out of 6590 (16.45%)
# Processing index 1085 out of 6590 (16.46%)
# Processing index 1086 out of 6590 (16.48%)
# Processing index 1087 out of 6590 (16.49%)
# Processing index 1088 out of 6590 (16.51%)
# Processing index 1089 out of 6590 (16.53%)
# Processing index 1090 out of 6590 (16.54%)
# Processing index 1091 out of 6590 (16.56%)
# Processing index 1092 out of 6590 (16.57%)
# Processing index 1093 out of 6590 (16.59%)
# Processing index 1094 out of 6590 (16.6%)
# Processing index 1095 out of 6590 (16.62%)
# Processing index 1096 out of 6590 (16.63%)
# Processing index 1097 out of 6590 (16.65%)
# Processing index 1098 out of 6590 (16.66%)
# Processing index 1099 out of 6590 (16.68%)
# Processing index 1100 out of 6590 (16.69%)
# Processing index 1101 out of 6590 (16.71%)
# Processing index 1102 out of 6590 (16.72%)
# Processing index 1103 out of 6590 (16.74%)
# Processing index 1104 out of 6590 (16.75%)
# Processing index 1105 out of 6590 (16.77%)
# Processing index 1106 out of 6590 (16.78%)
# Processing index 1107 out of 6590 (16.8%)
# Processing index 1108 out of 6590 (16.81%)
# Processing index 1109 out of 6590 (16.83%)
# Processing index 1110 out of 6590 (16.84%)
# Processing index 1111 out of 6590 (16.86%)
# Processing index 1112 out of 6590 (16.87%)
# Processing index 1113 out of 6590 (16.89%)
# Processing index 1114 out of 6590 (16.9%)
# Processing index 1115 out of 6590 (16.92%)
# Processing index 1116 out of 6590 (16.93%)
# Processing index 1117 out of 6590 (16.95%)
# Processing index 1118 out of 6590 (16.97%)
# Processing index 1119 out of 6590 (16.98%)
# Processing index 1120 out of 6590 (17.0%)
# Processing index 1121 out of 6590 (17.01%)
# Processing index 1122 out of 6590 (17.03%)
# Processing index 1123 out of 6590 (17.04%)
# Processing index 1124 out of 6590 (17.06%)
# Processing index 1125 out of 6590 (17.07%)
# Processing index 1126 out of 6590 (17.09%)
# Processing index 1127 out of 6590 (17.1%)
# Processing index 1128 out of 6590 (17.12%)
# Processing index 1129 out of 6590 (17.13%)
# Processing index 1130 out of 6590 (17.15%)
# Processing index 1131 out of 6590 (17.16%)
# Processing index 1132 out of 6590 (17.18%)
# Processing index 1133 out of 6590 (17.19%)
# Processing index 1134 out of 6590 (17.21%)
# Processing index 1135 out of 6590 (17.22%)
# Processing index 1136 out of 6590 (17.24%)
# Processing index 1137 out of 6590 (17.25%)
# Processing index 1138 out of 6590 (17.27%)
# Processing index 1139 out of 6590 (17.28%)
# Processing index 1140 out of 6590 (17.3%)
# Processing index 1141 out of 6590 (17.31%)
# Processing index 1142 out of 6590 (17.33%)
# Processing index 1143 out of 6590 (17.34%)
# Processing index 1144 out of 6590 (17.36%)
# Processing index 1145 out of 6590 (17.37%)
# Processing index 1146 out of 6590 (17.39%)
# Processing index 1147 out of 6590 (17.41%)
# Processing index 1148 out of 6590 (17.42%)
# Processing index 1149 out of 6590 (17.44%)
# Processing index 1150 out of 6590 (17.45%)
# Processing index 1151 out of 6590 (17.47%)
# Processing index 1152 out of 6590 (17.48%)
# Processing index 1153 out of 6590 (17.5%)
# Processing index 1154 out of 6590 (17.51%)
# Processing index 1155 out of 6590 (17.53%)
# Processing index 1156 out of 6590 (17.54%)
# Processing index 1157 out of 6590 (17.56%)
# Processing index 1158 out of 6590 (17.57%)
# Processing index 1159 out of 6590 (17.59%)
# ...
# Processing index 6218 out of 6590 (94.36%)
# Processing index 6219 out of 6590 (94.37%)
# Processing index 6220 out of 6590 (94.39%)
# Processing index 6221 out of 6590 (94.4%)
# Processing index 6222 out of 6590 (94.42%)
# Processing index 6223 out of 6590 (94.43%)
# Processing index 6224 out of 6590 (94.45%)
# Processing index 6225 out of 6590 (94.46%)
# Processing index 6226 out of 6590 (94.48%)
# Processing index 6227 out of 6590 (94.49%)
# Processing index 6228 out of 6590 (94.51%)
# Processing index 6229 out of 6590 (94.52%)
# Processing index 6230 out of 6590 (94.54%)
# Processing index 6231 out of 6590 (94.55%)
# Processing index 6232 out of 6590 (94.57%)
# Processing index 6233 out of 6590 (94.58%)
# Processing index 6234 out of 6590 (94.6%)
# Processing index 6235 out of 6590 (94.61%)
# Processing index 6236 out of 6590 (94.63%)
# Processing index 6237 out of 6590 (94.64%)
# Processing index 6238 out of 6590 (94.66%)
# Processing index 6239 out of 6590 (94.67%)
# Processing index 6240 out of 6590 (94.69%)
# Processing index 6241 out of 6590 (94.7%)
# Processing index 6242 out of 6590 (94.72%)
# Processing index 6243 out of 6590 (94.73%)
# Processing index 6244 out of 6590 (94.75%)
# Processing index 6245 out of 6590 (94.76%)
# Processing index 6246 out of 6590 (94.78%)
# Processing index 6247 out of 6590 (94.8%)
# Processing index 6248 out of 6590 (94.81%)
# Processing index 6249 out of 6590 (94.83%)
# Processing index 6250 out of 6590 (94.84%)
# Processing index 6251 out of 6590 (94.86%)
# Processing index 6252 out of 6590 (94.87%)
# Processing index 6253 out of 6590 (94.89%)
# Processing index 6254 out of 6590 (94.9%)
# Processing index 6255 out of 6590 (94.92%)
# Processing index 6256 out of 6590 (94.93%)
# Processing index 6257 out of 6590 (94.95%)
# Processing index 6258 out of 6590 (94.96%)
# Processing index 6259 out of 6590 (94.98%)
# Processing index 6260 out of 6590 (94.99%)
# Processing index 6261 out of 6590 (95.01%)
# Processing index 6262 out of 6590 (95.02%)
# Processing index 6263 out of 6590 (95.04%)
# Processing index 6264 out of 6590 (95.05%)
# Processing index 6265 out of 6590 (95.07%)
# Processing index 6266 out of 6590 (95.08%)
# Processing index 6267 out of 6590 (95.1%)
# Processing index 6268 out of 6590 (95.11%)
# Processing index 6269 out of 6590 (95.13%)
# Processing index 6270 out of 6590 (95.14%)
# Processing index 6271 out of 6590 (95.16%)
# Processing index 6272 out of 6590 (95.17%)
# Processing index 6273 out of 6590 (95.19%)
# Processing index 6274 out of 6590 (95.2%)
# Processing index 6275 out of 6590 (95.22%)
# Processing index 6276 out of 6590 (95.24%)
# Processing index 6277 out of 6590 (95.25%)
# Processing index 6278 out of 6590 (95.27%)
# Processing index 6279 out of 6590 (95.28%)
# Processing index 6280 out of 6590 (95.3%)
# Processing index 6281 out of 6590 (95.31%)
# Processing index 6282 out of 6590 (95.33%)
# Processing index 6283 out of 6590 (95.34%)
# Processing index 6284 out of 6590 (95.36%)
# Processing index 6285 out of 6590 (95.37%)
# Processing index 6286 out of 6590 (95.39%)
# Processing index 6287 out of 6590 (95.4%)
# Processing index 6288 out of 6590 (95.42%)
# Processing index 6289 out of 6590 (95.43%)
# Processing index 6290 out of 6590 (95.45%)
# Processing index 6291 out of 6590 (95.46%)
# Processing index 6292 out of 6590 (95.48%)
# Processing index 6293 out of 6590 (95.49%)
# Processing index 6294 out of 6590 (95.51%)
# Processing index 6295 out of 6590 (95.52%)
# Processing index 6296 out of 6590 (95.54%)
# Processing index 6297 out of 6590 (95.55%)
# Processing index 6298 out of 6590 (95.57%)
# Processing index 6299 out of 6590 (95.58%)
# Processing index 6300 out of 6590 (95.6%)
# Processing index 6301 out of 6590 (95.61%)
# Processing index 6302 out of 6590 (95.63%)
# Processing index 6303 out of 6590 (95.64%)
# Processing index 6304 out of 6590 (95.66%)
# Processing index 6305 out of 6590 (95.68%)
# Processing index 6306 out of 6590 (95.69%)
# Processing index 6307 out of 6590 (95.71%)
# Processing index 6308 out of 6590 (95.72%)
# Processing index 6309 out of 6590 (95.74%)
# Processing index 6310 out of 6590 (95.75%)
# Processing index 6311 out of 6590 (95.77%)
# Processing index 6312 out of 6590 (95.78%)
# Processing index 6313 out of 6590 (95.8%)
# Processing index 6314 out of 6590 (95.81%)
# Processing index 6315 out of 6590 (95.83%)
# Processing index 6316 out of 6590 (95.84%)
# Processing index 6317 out of 6590 (95.86%)
# Processing index 6318 out of 6590 (95.87%)
# Processing index 6319 out of 6590 (95.89%)
# Processing index 6320 out of 6590 (95.9%)
# Processing index 6321 out of 6590 (95.92%)
# Processing index 6322 out of 6590 (95.93%)
# Processing index 6323 out of 6590 (95.95%)
# Processing index 6324 out of 6590 (95.96%)
# Processing index 6325 out of 6590 (95.98%)
# Processing index 6326 out of 6590 (95.99%)
# Processing index 6327 out of 6590 (96.01%)
# Processing index 6328 out of 6590 (96.02%)
# Processing index 6329 out of 6590 (96.04%)
# Processing index 6330 out of 6590 (96.05%)
# Processing index 6331 out of 6590 (96.07%)
# Processing index 6332 out of 6590 (96.08%)
# Processing index 6333 out of 6590 (96.1%)
# Processing index 6334 out of 6590 (96.12%)
# Processing index 6335 out of 6590 (96.13%)
# Processing index 6336 out of 6590 (96.15%)
# Processing index 6337 out of 6590 (96.16%)
# Processing index 6338 out of 6590 (96.18%)
# Processing index 6339 out of 6590 (96.19%)
# Processing index 6340 out of 6590 (96.21%)
# Processing index 6341 out of 6590 (96.22%)
# Processing index 6342 out of 6590 (96.24%)
# Processing index 6343 out of 6590 (96.25%)
# Processing index 6344 out of 6590 (96.27%)
# Processing index 6345 out of 6590 (96.28%)
# Processing index 6346 out of 6590 (96.3%)
# Processing index 6347 out of 6590 (96.31%)
# Processing index 6348 out of 6590 (96.33%)
# Processing index 6349 out of 6590 (96.34%)
# Processing index 6350 out of 6590 (96.36%)
# Processing index 6351 out of 6590 (96.37%)
# Processing index 6352 out of 6590 (96.39%)
# Processing index 6353 out of 6590 (96.4%)
# Processing index 6354 out of 6590 (96.42%)
# Processing index 6355 out of 6590 (96.43%)
# Processing index 6356 out of 6590 (96.45%)
# Processing index 6357 out of 6590 (96.46%)
# Processing index 6358 out of 6590 (96.48%)
# Processing index 6359 out of 6590 (96.49%)
# Processing index 6360 out of 6590 (96.51%)
# Processing index 6361 out of 6590 (96.53%)
# Processing index 6362 out of 6590 (96.54%)
# Processing index 6363 out of 6590 (96.56%)
# Processing index 6364 out of 6590 (96.57%)
# Processing index 6365 out of 6590 (96.59%)
# Processing index 6366 out of 6590 (96.6%)
# Processing index 6367 out of 6590 (96.62%)
# Processing index 6368 out of 6590 (96.63%)
# Processing index 6369 out of 6590 (96.65%)
# Processing index 6370 out of 6590 (96.66%)
# Processing index 6371 out of 6590 (96.68%)
# Processing index 6372 out of 6590 (96.69%)
# Processing index 6373 out of 6590 (96.71%)
# Processing index 6374 out of 6590 (96.72%)
# Processing index 6375 out of 6590 (96.74%)
# Processing index 6376 out of 6590 (96.75%)
# Processing index 6377 out of 6590 (96.77%)
# Processing index 6378 out of 6590 (96.78%)
# Processing index 6379 out of 6590 (96.8%)
# Processing index 6380 out of 6590 (96.81%)
# Processing index 6381 out of 6590 (96.83%)
# Processing index 6382 out of 6590 (96.84%)
# Processing index 6383 out of 6590 (96.86%)
# Processing index 6384 out of 6590 (96.87%)
# Processing index 6385 out of 6590 (96.89%)
# Processing index 6386 out of 6590 (96.9%)
# Processing index 6387 out of 6590 (96.92%)
# Processing index 6388 out of 6590 (96.93%)
# Processing index 6389 out of 6590 (96.95%)
# Processing index 6390 out of 6590 (96.97%)
# Processing index 6391 out of 6590 (96.98%)
# Processing index 6392 out of 6590 (97.0%)
# Processing index 6393 out of 6590 (97.01%)
# Processing index 6394 out of 6590 (97.03%)
# Processing index 6395 out of 6590 (97.04%)
# Processing index 6396 out of 6590 (97.06%)
# Processing index 6397 out of 6590 (97.07%)
# Processing index 6398 out of 6590 (97.09%)
# Processing index 6399 out of 6590 (97.1%)
# Processing index 6400 out of 6590 (97.12%)
# Processing index 6401 out of 6590 (97.13%)
# Processing index 6402 out of 6590 (97.15%)
# Processing index 6403 out of 6590 (97.16%)
# Processing index 6404 out of 6590 (97.18%)
# Processing index 6405 out of 6590 (97.19%)
# Processing index 6406 out of 6590 (97.21%)
# Processing index 6407 out of 6590 (97.22%)
# Processing index 6408 out of 6590 (97.24%)
# Processing index 6409 out of 6590 (97.25%)
# Processing index 6410 out of 6590 (97.27%)
# Processing index 6411 out of 6590 (97.28%)
# Processing index 6412 out of 6590 (97.3%)
# Processing index 6413 out of 6590 (97.31%)
# Processing index 6414 out of 6590 (97.33%)
# Processing index 6415 out of 6590 (97.34%)
# Processing index 6416 out of 6590 (97.36%)
# Processing index 6417 out of 6590 (97.37%)
# Processing index 6418 out of 6590 (97.39%)
# Processing index 6419 out of 6590 (97.41%)
# Processing index 6420 out of 6590 (97.42%)
# Processing index 6421 out of 6590 (97.44%)
# Processing index 6422 out of 6590 (97.45%)
# Processing index 6423 out of 6590 (97.47%)
# Processing index 6424 out of 6590 (97.48%)
# Processing index 6425 out of 6590 (97.5%)
# Processing index 6426 out of 6590 (97.51%)
# Processing index 6427 out of 6590 (97.53%)
# Processing index 6428 out of 6590 (97.54%)
# Processing index 6429 out of 6590 (97.56%)
# Processing index 6430 out of 6590 (97.57%)
# Processing index 6431 out of 6590 (97.59%)
# Processing index 6432 out of 6590 (97.6%)
# Processing index 6433 out of 6590 (97.62%)
# Processing index 6434 out of 6590 (97.63%)
# Processing index 6435 out of 6590 (97.65%)
# Processing index 6436 out of 6590 (97.66%)
# Processing index 6437 out of 6590 (97.68%)
# Processing index 6438 out of 6590 (97.69%)
# Processing index 6439 out of 6590 (97.71%)
# Processing index 6440 out of 6590 (97.72%)
# Processing index 6441 out of 6590 (97.74%)
# Processing index 6442 out of 6590 (97.75%)
# Processing index 6443 out of 6590 (97.77%)
# Processing index 6444 out of 6590 (97.78%)
# Processing index 6445 out of 6590 (97.8%)
# Processing index 6446 out of 6590 (97.81%)
# Processing index 6447 out of 6590 (97.83%)
# Processing index 6448 out of 6590 (97.85%)
# Processing index 6449 out of 6590 (97.86%)
# Processing index 6450 out of 6590 (97.88%)
# Processing index 6451 out of 6590 (97.89%)
# Processing index 6452 out of 6590 (97.91%)
# Processing index 6453 out of 6590 (97.92%)
# Processing index 6454 out of 6590 (97.94%)
# Processing index 6455 out of 6590 (97.95%)
# Processing index 6456 out of 6590 (97.97%)
# Processing index 6457 out of 6590 (97.98%)
# Processing index 6458 out of 6590 (98.0%)
# Processing index 6459 out of 6590 (98.01%)
# Processing index 6460 out of 6590 (98.03%)
# Processing index 6461 out of 6590 (98.04%)
# Processing index 6462 out of 6590 (98.06%)
# Processing index 6463 out of 6590 (98.07%)
# Processing index 6464 out of 6590 (98.09%)
# Processing index 6465 out of 6590 (98.1%)
# Processing index 6466 out of 6590 (98.12%)
# Processing index 6467 out of 6590 (98.13%)
# Processing index 6468 out of 6590 (98.15%)
# Processing index 6469 out of 6590 (98.16%)
# Processing index 6470 out of 6590 (98.18%)
# Processing index 6471 out of 6590 (98.19%)
# Processing index 6472 out of 6590 (98.21%)
# Processing index 6473 out of 6590 (98.22%)
# Processing index 6474 out of 6590 (98.24%)
# Processing index 6475 out of 6590 (98.25%)
# Processing index 6476 out of 6590 (98.27%)
# Processing index 6477 out of 6590 (98.29%)
# Processing index 6478 out of 6590 (98.3%)
# Processing index 6479 out of 6590 (98.32%)
# Processing index 6480 out of 6590 (98.33%)
# Processing index 6481 out of 6590 (98.35%)
# Processing index 6482 out of 6590 (98.36%)
# Processing index 6483 out of 6590 (98.38%)
# Processing index 6484 out of 6590 (98.39%)
# Processing index 6485 out of 6590 (98.41%)
# Processing index 6486 out of 6590 (98.42%)
# Processing index 6487 out of 6590 (98.44%)
# Processing index 6488 out of 6590 (98.45%)
# Processing index 6489 out of 6590 (98.47%)
# Processing index 6490 out of 6590 (98.48%)
# Processing index 6491 out of 6590 (98.5%)
# Processing index 6492 out of 6590 (98.51%)
# Processing index 6493 out of 6590 (98.53%)
# Processing index 6494 out of 6590 (98.54%)
# Processing index 6495 out of 6590 (98.56%)
# Processing index 6496 out of 6590 (98.57%)
# Processing index 6497 out of 6590 (98.59%)
# Processing index 6498 out of 6590 (98.6%)
# Processing index 6499 out of 6590 (98.62%)
# Processing index 6500 out of 6590 (98.63%)
# Processing index 6501 out of 6590 (98.65%)
# Processing index 6502 out of 6590 (98.66%)
# Processing index 6503 out of 6590 (98.68%)
# Processing index 6504 out of 6590 (98.69%)
# Processing index 6505 out of 6590 (98.71%)
# Processing index 6506 out of 6590 (98.73%)
# Processing index 6507 out of 6590 (98.74%)
# Processing index 6508 out of 6590 (98.76%)
# Processing index 6509 out of 6590 (98.77%)
# Processing index 6510 out of 6590 (98.79%)
# Processing index 6511 out of 6590 (98.8%)
# Processing index 6512 out of 6590 (98.82%)
# Processing index 6513 out of 6590 (98.83%)
# Processing index 6514 out of 6590 (98.85%)
# Processing index 6515 out of 6590 (98.86%)
# Processing index 6516 out of 6590 (98.88%)
# Processing index 6517 out of 6590 (98.89%)
# Processing index 6518 out of 6590 (98.91%)
# Processing index 6519 out of 6590 (98.92%)
# Processing index 6520 out of 6590 (98.94%)
# Processing index 6521 out of 6590 (98.95%)
# Processing index 6522 out of 6590 (98.97%)
# Processing index 6523 out of 6590 (98.98%)
# Processing index 6524 out of 6590 (99.0%)
# Processing index 6525 out of 6590 (99.01%)
# Processing index 6526 out of 6590 (99.03%)
# Processing index 6527 out of 6590 (99.04%)
# Processing index 6528 out of 6590 (99.06%)
# Processing index 6529 out of 6590 (99.07%)
# Processing index 6530 out of 6590 (99.09%)
# Processing index 6531 out of 6590 (99.1%)
# Processing index 6532 out of 6590 (99.12%)
# Processing index 6533 out of 6590 (99.14%)
# Processing index 6534 out of 6590 (99.15%)
# Processing index 6535 out of 6590 (99.17%)
# Processing index 6536 out of 6590 (99.18%)
# Processing index 6537 out of 6590 (99.2%)
# Processing index 6538 out of 6590 (99.21%)
# Processing index 6539 out of 6590 (99.23%)
# Processing index 6540 out of 6590 (99.24%)
# Processing index 6541 out of 6590 (99.26%)
# Processing index 6542 out of 6590 (99.27%)
# Processing index 6543 out of 6590 (99.29%)
# Processing index 6544 out of 6590 (99.3%)
# Processing index 6545 out of 6590 (99.32%)
# Processing index 6546 out of 6590 (99.33%)
# Processing index 6547 out of 6590 (99.35%)
# Processing index 6548 out of 6590 (99.36%)
# Processing index 6549 out of 6590 (99.38%)
# Processing index 6550 out of 6590 (99.39%)
# Processing index 6551 out of 6590 (99.41%)
# Processing index 6552 out of 6590 (99.42%)
# Processing index 6553 out of 6590 (99.44%)
# Processing index 6554 out of 6590 (99.45%)
# Processing index 6555 out of 6590 (99.47%)
# Processing index 6556 out of 6590 (99.48%)
# Processing index 6557 out of 6590 (99.5%)
# Processing index 6558 out of 6590 (99.51%)
# Processing index 6559 out of 6590 (99.53%)
# Processing index 6560 out of 6590 (99.54%)
# Processing index 6561 out of 6590 (99.56%)
# Processing index 6562 out of 6590 (99.58%)
# Processing index 6563 out of 6590 (99.59%)
# Processing index 6564 out of 6590 (99.61%)
# Processing index 6565 out of 6590 (99.62%)
# Processing index 6566 out of 6590 (99.64%)
# Processing index 6567 out of 6590 (99.65%)
# Processing index 6568 out of 6590 (99.67%)
# Processing index 6569 out of 6590 (99.68%)
# Processing index 6570 out of 6590 (99.7%)
# Processing index 6571 out of 6590 (99.71%)
# Processing index 6572 out of 6590 (99.73%)
# Processing index 6573 out of 6590 (99.74%)
# Processing index 6574 out of 6590 (99.76%)
# Processing index 6575 out of 6590 (99.77%)
# Processing index 6576 out of 6590 (99.79%)
# Processing index 6577 out of 6590 (99.8%)
# Processing index 6578 out of 6590 (99.82%)
# Processing index 6579 out of 6590 (99.83%)
# Processing index 6580 out of 6590 (99.85%)
# Processing index 6581 out of 6590 (99.86%)
# Processing index 6582 out of 6590 (99.88%)
# Processing index 6583 out of 6590 (99.89%)
# Processing index 6584 out of 6590 (99.91%)
# Processing index 6585 out of 6590 (99.92%)
# Processing index 6586 out of 6590 (99.94%)
# Processing index 6587 out of 6590 (99.95%)
# Processing index 6588 out of 6590 (99.97%)
# Processing index 6589 out of 6590 (99.98%)

# %% [markdown]
# #### Loop I Statistics & Sanity Check

# %%
matches = original_mpv_size - mpv.shape[0]
print(f"MPV Matches = {matches} / {original_mpv_size} ({round( matches/original_mpv_size * 100, 2)}%)")
# Out:
# MPV Matches = 5789 / 6063 (95.48%)

# %%
matches = original_wp_size - wp.shape[0] #95% match
print(f"WP Matches = {matches} / {original_wp_size} ({round( matches/original_wp_size * 100, 2)}%)")
# Out:
# WP Matches = 5601 / 5946 (94.2%)

# %%
print("Search Statistics (i.e., comparing every row of FE to MP and WP)")
search_results_dict
# Out:
# Search Statistics (i.e., comparing every row of FE to MP and WP)
# {'no_results_counter': 1698,
#  '1_result_counter': 11222,
#  '2_or_more_result_counter': 260}

# %%
# FE should have queried each database for 2 * its lenght. I.e., one row in FE will produce two queries: one in MPV, one in WP.
# Thus, let's verify it

intended_queries = len(fe) * 2
print(f"FE should have produced {intended_queries} queries: one row shuld have queried MPV and WP, and FE is {len(fe)} rows so {len(fe)}*2. Let's make sure this is correct.")
assert(sum(search_results_dict.values()) == intended_queries)
print("Assertion Passed")
# Out:
# FE should have produced 13180 queries: one row shuld have queried MPV and WP, and FE is 6590 rows so 6590*2. Let's make sure this is correct.
# Assertion Passed

# %% [markdown]
# ### 5.3 | Loop II: Add MPV to DM-FS, checking against WP

# %%
# Prints pre-loop statistics
original_wp_size = wp.shape[0]
intended_queries = len(mpv) * 1 # Number of queries we expect MPV to make on the 2 datbases it'll query: FE_Suicdies and WP
print(f"MPV is expected to make {intended_queries} queries. In other words, each row will query one database: MPV. MPV contains {len(mpv)} rows, so there will be {len(mpv)} * 1 total queries.")
# Out:
# MPV is expected to make 274 queries. In other words, each row will query one database: MPV. MPV contains 274 rows, so there will be 274 * 1 total queries.

# %%
# Adds leftover MPV cases to the end of master_df, which is more-or-less a copy of FE

mpv_index = 0 # Note that we need a seperate mpv_index: the index in the loop refers to master_df index, which adds new data to the END of the existing dataframe
for i in range(len(master_df), len(master_df) + len(mpv) ) : # Adds MPV rows at the very end of master_df (i.e., why it starts at len(fe))

    # Displays progression
    print(f"Processing index {mpv_index} out of {len(mpv)-1} ({round(mpv_index/ (len(mpv)-1) * 100, 2)}%) to be added to master_df index {i}")

    # Extracts the base row
    mpv_row = mpv.iloc[mpv_index].copy() 
    mpv_index += 1 # So that, on next iteration, the next row of MPV Can be used
    name, state, city, date = mpv_row["name_abr"], mpv_row["state_of_death"], mpv_row["city_of_death_abr"], mpv_row["date"]

    # Adds discrpeencies to our row AND adds it to Master DF
    add_discrepencies_to_df(mpv_row, filler_value = False)
    master_df = pd.concat([master_df,  pd.DataFrame([mpv_row]) ], ignore_index=True) 

    # Adds relevant info to master_df, concerning MPV
    master_df.loc[i, "URL_MPV"] = mpv_row["URL_MPV"]
    master_df.loc[i, "omission_fe"] = True
    master_df.loc[i, "URL_FE"] = None
    
    # *************************************
    # Checks for a match in other DBs
    # *************************************

    # Name, City, & State match
    wp_rows = wp.query(f"name_abr == '{name}' & state_of_death == '{state}'")

    # If no match, then salavage it with a fuzzy search
    if wp_rows.empty:      
        wp_rows = get_candidate_rows_via_fuzzzy_name_search (wp[ (wp['state_of_death'] == state) ], "mpv", "wp")

    # *************************************
    # Handles match
    # *************************************
    
    # Initialize the row to search for mpv and wp. If empty, return 'None'.
    wp_row = initialize_row_to_search(wp_rows, mpv_row["date"], "mpv", "wp")
            
    # *************************************
    # Prepares match & lack of match
    # *************************************

    # Handles WP: Records as (i) an ommission or (ii) records discrepencies
    if wp_row is None:
        master_df.loc[i, "omission_wp"] = True
        master_df.loc[i, "date_discrepancy_days"] = 0
    else: # WP has a hit
        check_for_all_discrepencies(master_df, i, None, mpv_row, wp_row)
        wp = wp.drop(wp_row.name)
# Out:
# Processing index 0 out of 273 (0.0%) to be added to master_df index 6590
# Processing index 1 out of 273 (0.37%) to be added to master_df index 6591
# Processing index 2 out of 273 (0.73%) to be added to master_df index 6592
# Processing index 3 out of 273 (1.1%) to be added to master_df index 6593
# Processing index 4 out of 273 (1.47%) to be added to master_df index 6594
# Processing index 5 out of 273 (1.83%) to be added to master_df index 6595
# Processing index 6 out of 273 (2.2%) to be added to master_df index 6596
# Processing index 7 out of 273 (2.56%) to be added to master_df index 6597
# Processing index 8 out of 273 (2.93%) to be added to master_df index 6598
# Processing index 9 out of 273 (3.3%) to be added to master_df index 6599
# Processing index 10 out of 273 (3.66%) to be added to master_df index 6600
# Processing index 11 out of 273 (4.03%) to be added to master_df index 6601
# Processing index 12 out of 273 (4.4%) to be added to master_df index 6602
# Processing index 13 out of 273 (4.76%) to be added to master_df index 6603
# Processing index 14 out of 273 (5.13%) to be added to master_df index 6604
# Processing index 15 out of 273 (5.49%) to be added to master_df index 6605
# Processing index 16 out of 273 (5.86%) to be added to master_df index 6606
# Processing index 17 out of 273 (6.23%) to be added to master_df index 6607
# Processing index 18 out of 273 (6.59%) to be added to master_df index 6608
# Processing index 19 out of 273 (6.96%) to be added to master_df index 6609
# Processing index 20 out of 273 (7.33%) to be added to master_df index 6610
# Processing index 21 out of 273 (7.69%) to be added to master_df index 6611
# Processing index 22 out of 273 (8.06%) to be added to master_df index 6612
# Processing index 23 out of 273 (8.42%) to be added to master_df index 6613
# Processing index 24 out of 273 (8.79%) to be added to master_df index 6614
# Processing index 25 out of 273 (9.16%) to be added to master_df index 6615
# Processing index 26 out of 273 (9.52%) to be added to master_df index 6616
# Processing index 27 out of 273 (9.89%) to be added to master_df index 6617
# Processing index 28 out of 273 (10.26%) to be added to master_df index 6618
# Processing index 29 out of 273 (10.62%) to be added to master_df index 6619
# Processing index 30 out of 273 (10.99%) to be added to master_df index 6620
# Processing index 31 out of 273 (11.36%) to be added to master_df index 6621
# Processing index 32 out of 273 (11.72%) to be added to master_df index 6622
# Processing index 33 out of 273 (12.09%) to be added to master_df index 6623
# Processing index 34 out of 273 (12.45%) to be added to master_df index 6624
# Processing index 35 out of 273 (12.82%) to be added to master_df index 6625
# Processing index 36 out of 273 (13.19%) to be added to master_df index 6626
# Processing index 37 out of 273 (13.55%) to be added to master_df index 6627
# Processing index 38 out of 273 (13.92%) to be added to master_df index 6628
# Processing index 39 out of 273 (14.29%) to be added to master_df index 6629
# Processing index 40 out of 273 (14.65%) to be added to master_df index 6630
# Processing index 41 out of 273 (15.02%) to be added to master_df index 6631
# Processing index 42 out of 273 (15.38%) to be added to master_df index 6632
# Processing index 43 out of 273 (15.75%) to be added to master_df index 6633
# Processing index 44 out of 273 (16.12%) to be added to master_df index 6634
# Processing index 45 out of 273 (16.48%) to be added to master_df index 6635
# Processing index 46 out of 273 (16.85%) to be added to master_df index 6636
# Processing index 47 out of 273 (17.22%) to be added to master_df index 6637
# Processing index 48 out of 273 (17.58%) to be added to master_df index 6638
# Processing index 49 out of 273 (17.95%) to be added to master_df index 6639
# Processing index 50 out of 273 (18.32%) to be added to master_df index 6640
# Processing index 51 out of 273 (18.68%) to be added to master_df index 6641
# Processing index 52 out of 273 (19.05%) to be added to master_df index 6642
# Processing index 53 out of 273 (19.41%) to be added to master_df index 6643
# Processing index 54 out of 273 (19.78%) to be added to master_df index 6644
# Processing index 55 out of 273 (20.15%) to be added to master_df index 6645
# Processing index 56 out of 273 (20.51%) to be added to master_df index 6646
# Processing index 57 out of 273 (20.88%) to be added to master_df index 6647
# Processing index 58 out of 273 (21.25%) to be added to master_df index 6648
# Processing index 59 out of 273 (21.61%) to be added to master_df index 6649
# Processing index 60 out of 273 (21.98%) to be added to master_df index 6650
# Processing index 61 out of 273 (22.34%) to be added to master_df index 6651
# Processing index 62 out of 273 (22.71%) to be added to master_df index 6652
# Processing index 63 out of 273 (23.08%) to be added to master_df index 6653
# Processing index 64 out of 273 (23.44%) to be added to master_df index 6654
# Processing index 65 out of 273 (23.81%) to be added to master_df index 6655
# Processing index 66 out of 273 (24.18%) to be added to master_df index 6656
# Processing index 67 out of 273 (24.54%) to be added to master_df index 6657
# Processing index 68 out of 273 (24.91%) to be added to master_df index 6658
# Processing index 69 out of 273 (25.27%) to be added to master_df index 6659
# Processing index 70 out of 273 (25.64%) to be added to master_df index 6660
# Processing index 71 out of 273 (26.01%) to be added to master_df index 6661
# Processing index 72 out of 273 (26.37%) to be added to master_df index 6662
# Processing index 73 out of 273 (26.74%) to be added to master_df index 6663
# Processing index 74 out of 273 (27.11%) to be added to master_df index 6664
# Processing index 75 out of 273 (27.47%) to be added to master_df index 6665
# Processing index 76 out of 273 (27.84%) to be added to master_df index 6666
# Processing index 77 out of 273 (28.21%) to be added to master_df index 6667
# Processing index 78 out of 273 (28.57%) to be added to master_df index 6668
# Processing index 79 out of 273 (28.94%) to be added to master_df index 6669
# Processing index 80 out of 273 (29.3%) to be added to master_df index 6670
# Processing index 81 out of 273 (29.67%) to be added to master_df index 6671
# Processing index 82 out of 273 (30.04%) to be added to master_df index 6672
# Processing index 83 out of 273 (30.4%) to be added to master_df index 6673
# Processing index 84 out of 273 (30.77%) to be added to master_df index 6674
# Processing index 85 out of 273 (31.14%) to be added to master_df index 6675
# Processing index 86 out of 273 (31.5%) to be added to master_df index 6676
# Processing index 87 out of 273 (31.87%) to be added to master_df index 6677
# Processing index 88 out of 273 (32.23%) to be added to master_df index 6678
# Processing index 89 out of 273 (32.6%) to be added to master_df index 6679
# Processing index 90 out of 273 (32.97%) to be added to master_df index 6680
# Processing index 91 out of 273 (33.33%) to be added to master_df index 6681
# Processing index 92 out of 273 (33.7%) to be added to master_df index 6682
# Processing index 93 out of 273 (34.07%) to be added to master_df index 6683
# Processing index 94 out of 273 (34.43%) to be added to master_df index 6684
# Processing index 95 out of 273 (34.8%) to be added to master_df index 6685
# Processing index 96 out of 273 (35.16%) to be added to master_df index 6686
# Processing index 97 out of 273 (35.53%) to be added to master_df index 6687
# Processing index 98 out of 273 (35.9%) to be added to master_df index 6688
# Processing index 99 out of 273 (36.26%) to be added to master_df index 6689
# Processing index 100 out of 273 (36.63%) to be added to master_df index 6690
# Processing index 101 out of 273 (37.0%) to be added to master_df index 6691
# Processing index 102 out of 273 (37.36%) to be added to master_df index 6692
# Processing index 103 out of 273 (37.73%) to be added to master_df index 6693
# Processing index 104 out of 273 (38.1%) to be added to master_df index 6694
# Processing index 105 out of 273 (38.46%) to be added to master_df index 6695
# Processing index 106 out of 273 (38.83%) to be added to master_df index 6696
# Processing index 107 out of 273 (39.19%) to be added to master_df index 6697
# Processing index 108 out of 273 (39.56%) to be added to master_df index 6698
# Processing index 109 out of 273 (39.93%) to be added to master_df index 6699
# Processing index 110 out of 273 (40.29%) to be added to master_df index 6700
# Processing index 111 out of 273 (40.66%) to be added to master_df index 6701
# Processing index 112 out of 273 (41.03%) to be added to master_df index 6702
# Processing index 113 out of 273 (41.39%) to be added to master_df index 6703
# Processing index 114 out of 273 (41.76%) to be added to master_df index 6704
# Processing index 115 out of 273 (42.12%) to be added to master_df index 6705
# Processing index 116 out of 273 (42.49%) to be added to master_df index 6706
# Processing index 117 out of 273 (42.86%) to be added to master_df index 6707
# Processing index 118 out of 273 (43.22%) to be added to master_df index 6708
# Processing index 119 out of 273 (43.59%) to be added to master_df index 6709
# Processing index 120 out of 273 (43.96%) to be added to master_df index 6710
# Processing index 121 out of 273 (44.32%) to be added to master_df index 6711
# Processing index 122 out of 273 (44.69%) to be added to master_df index 6712
# Processing index 123 out of 273 (45.05%) to be added to master_df index 6713
# Processing index 124 out of 273 (45.42%) to be added to master_df index 6714
# Processing index 125 out of 273 (45.79%) to be added to master_df index 6715
# Processing index 126 out of 273 (46.15%) to be added to master_df index 6716
# Processing index 127 out of 273 (46.52%) to be added to master_df index 6717
# Processing index 128 out of 273 (46.89%) to be added to master_df index 6718
# Processing index 129 out of 273 (47.25%) to be added to master_df index 6719
# Processing index 130 out of 273 (47.62%) to be added to master_df index 6720
# Processing index 131 out of 273 (47.99%) to be added to master_df index 6721
# Processing index 132 out of 273 (48.35%) to be added to master_df index 6722
# Processing index 133 out of 273 (48.72%) to be added to master_df index 6723
# Processing index 134 out of 273 (49.08%) to be added to master_df index 6724
# Processing index 135 out of 273 (49.45%) to be added to master_df index 6725
# Processing index 136 out of 273 (49.82%) to be added to master_df index 6726
# Processing index 137 out of 273 (50.18%) to be added to master_df index 6727
# Processing index 138 out of 273 (50.55%) to be added to master_df index 6728
# Processing index 139 out of 273 (50.92%) to be added to master_df index 6729
# Processing index 140 out of 273 (51.28%) to be added to master_df index 6730
# Processing index 141 out of 273 (51.65%) to be added to master_df index 6731
# Processing index 142 out of 273 (52.01%) to be added to master_df index 6732
# Processing index 143 out of 273 (52.38%) to be added to master_df index 6733
# Processing index 144 out of 273 (52.75%) to be added to master_df index 6734
# Processing index 145 out of 273 (53.11%) to be added to master_df index 6735
# Processing index 146 out of 273 (53.48%) to be added to master_df index 6736
# Processing index 147 out of 273 (53.85%) to be added to master_df index 6737
# Processing index 148 out of 273 (54.21%) to be added to master_df index 6738
# Processing index 149 out of 273 (54.58%) to be added to master_df index 6739
# Processing index 150 out of 273 (54.95%) to be added to master_df index 6740
# Processing index 151 out of 273 (55.31%) to be added to master_df index 6741
# Processing index 152 out of 273 (55.68%) to be added to master_df index 6742
# Processing index 153 out of 273 (56.04%) to be added to master_df index 6743
# Processing index 154 out of 273 (56.41%) to be added to master_df index 6744
# Processing index 155 out of 273 (56.78%) to be added to master_df index 6745
# Processing index 156 out of 273 (57.14%) to be added to master_df index 6746
# Processing index 157 out of 273 (57.51%) to be added to master_df index 6747
# Processing index 158 out of 273 (57.88%) to be added to master_df index 6748
# Processing index 159 out of 273 (58.24%) to be added to master_df index 6749
# Processing index 160 out of 273 (58.61%) to be added to master_df index 6750
# Processing index 161 out of 273 (58.97%) to be added to master_df index 6751
# Processing index 162 out of 273 (59.34%) to be added to master_df index 6752
# Processing index 163 out of 273 (59.71%) to be added to master_df index 6753
# Processing index 164 out of 273 (60.07%) to be added to master_df index 6754
# Processing index 165 out of 273 (60.44%) to be added to master_df index 6755
# Processing index 166 out of 273 (60.81%) to be added to master_df index 6756
# Processing index 167 out of 273 (61.17%) to be added to master_df index 6757
# Processing index 168 out of 273 (61.54%) to be added to master_df index 6758
# Processing index 169 out of 273 (61.9%) to be added to master_df index 6759
# Processing index 170 out of 273 (62.27%) to be added to master_df index 6760
# Processing index 171 out of 273 (62.64%) to be added to master_df index 6761
# Processing index 172 out of 273 (63.0%) to be added to master_df index 6762
# Processing index 173 out of 273 (63.37%) to be added to master_df index 6763
# Processing index 174 out of 273 (63.74%) to be added to master_df index 6764
# Processing index 175 out of 273 (64.1%) to be added to master_df index 6765
# Processing index 176 out of 273 (64.47%) to be added to master_df index 6766
# Processing index 177 out of 273 (64.84%) to be added to master_df index 6767
# Processing index 178 out of 273 (65.2%) to be added to master_df index 6768
# Processing index 179 out of 273 (65.57%) to be added to master_df index 6769
# Processing index 180 out of 273 (65.93%) to be added to master_df index 6770
# Processing index 181 out of 273 (66.3%) to be added to master_df index 6771
# Processing index 182 out of 273 (66.67%) to be added to master_df index 6772
# Processing index 183 out of 273 (67.03%) to be added to master_df index 6773
# Processing index 184 out of 273 (67.4%) to be added to master_df index 6774
# Processing index 185 out of 273 (67.77%) to be added to master_df index 6775
# Processing index 186 out of 273 (68.13%) to be added to master_df index 6776
# Processing index 187 out of 273 (68.5%) to be added to master_df index 6777
# Processing index 188 out of 273 (68.86%) to be added to master_df index 6778
# Processing index 189 out of 273 (69.23%) to be added to master_df index 6779
# Processing index 190 out of 273 (69.6%) to be added to master_df index 6780
# Processing index 191 out of 273 (69.96%) to be added to master_df index 6781
# Processing index 192 out of 273 (70.33%) to be added to master_df index 6782
# Processing index 193 out of 273 (70.7%) to be added to master_df index 6783
# Processing index 194 out of 273 (71.06%) to be added to master_df index 6784
# Processing index 195 out of 273 (71.43%) to be added to master_df index 6785
# Processing index 196 out of 273 (71.79%) to be added to master_df index 6786
# Processing index 197 out of 273 (72.16%) to be added to master_df index 6787
# Processing index 198 out of 273 (72.53%) to be added to master_df index 6788
# Processing index 199 out of 273 (72.89%) to be added to master_df index 6789
# Processing index 200 out of 273 (73.26%) to be added to master_df index 6790
# Processing index 201 out of 273 (73.63%) to be added to master_df index 6791
# Processing index 202 out of 273 (73.99%) to be added to master_df index 6792
# Processing index 203 out of 273 (74.36%) to be added to master_df index 6793
# Processing index 204 out of 273 (74.73%) to be added to master_df index 6794
# Processing index 205 out of 273 (75.09%) to be added to master_df index 6795
# Processing index 206 out of 273 (75.46%) to be added to master_df index 6796
# Processing index 207 out of 273 (75.82%) to be added to master_df index 6797
# Processing index 208 out of 273 (76.19%) to be added to master_df index 6798
# Processing index 209 out of 273 (76.56%) to be added to master_df index 6799
# Processing index 210 out of 273 (76.92%) to be added to master_df index 6800
# Processing index 211 out of 273 (77.29%) to be added to master_df index 6801
# Processing index 212 out of 273 (77.66%) to be added to master_df index 6802
# Processing index 213 out of 273 (78.02%) to be added to master_df index 6803
# Processing index 214 out of 273 (78.39%) to be added to master_df index 6804
# Processing index 215 out of 273 (78.75%) to be added to master_df index 6805
# Processing index 216 out of 273 (79.12%) to be added to master_df index 6806
# Processing index 217 out of 273 (79.49%) to be added to master_df index 6807
# Processing index 218 out of 273 (79.85%) to be added to master_df index 6808
# Processing index 219 out of 273 (80.22%) to be added to master_df index 6809
# Processing index 220 out of 273 (80.59%) to be added to master_df index 6810
# Processing index 221 out of 273 (80.95%) to be added to master_df index 6811
# Processing index 222 out of 273 (81.32%) to be added to master_df index 6812
# Processing index 223 out of 273 (81.68%) to be added to master_df index 6813
# Processing index 224 out of 273 (82.05%) to be added to master_df index 6814
# Processing index 225 out of 273 (82.42%) to be added to master_df index 6815
# Processing index 226 out of 273 (82.78%) to be added to master_df index 6816
# Processing index 227 out of 273 (83.15%) to be added to master_df index 6817
# Processing index 228 out of 273 (83.52%) to be added to master_df index 6818
# Processing index 229 out of 273 (83.88%) to be added to master_df index 6819
# Processing index 230 out of 273 (84.25%) to be added to master_df index 6820
# Processing index 231 out of 273 (84.62%) to be added to master_df index 6821
# Processing index 232 out of 273 (84.98%) to be added to master_df index 6822
# Processing index 233 out of 273 (85.35%) to be added to master_df index 6823
# Processing index 234 out of 273 (85.71%) to be added to master_df index 6824
# Processing index 235 out of 273 (86.08%) to be added to master_df index 6825
# Processing index 236 out of 273 (86.45%) to be added to master_df index 6826
# Processing index 237 out of 273 (86.81%) to be added to master_df index 6827
# Processing index 238 out of 273 (87.18%) to be added to master_df index 6828
# Processing index 239 out of 273 (87.55%) to be added to master_df index 6829
# Processing index 240 out of 273 (87.91%) to be added to master_df index 6830
# Processing index 241 out of 273 (88.28%) to be added to master_df index 6831
# Processing index 242 out of 273 (88.64%) to be added to master_df index 6832
# Processing index 243 out of 273 (89.01%) to be added to master_df index 6833
# Processing index 244 out of 273 (89.38%) to be added to master_df index 6834
# Processing index 245 out of 273 (89.74%) to be added to master_df index 6835
# Processing index 246 out of 273 (90.11%) to be added to master_df index 6836
# Processing index 247 out of 273 (90.48%) to be added to master_df index 6837
# Processing index 248 out of 273 (90.84%) to be added to master_df index 6838
# Processing index 249 out of 273 (91.21%) to be added to master_df index 6839
# Processing index 250 out of 273 (91.58%) to be added to master_df index 6840
# Processing index 251 out of 273 (91.94%) to be added to master_df index 6841
# Processing index 252 out of 273 (92.31%) to be added to master_df index 6842
# Processing index 253 out of 273 (92.67%) to be added to master_df index 6843
# Processing index 254 out of 273 (93.04%) to be added to master_df index 6844
# Processing index 255 out of 273 (93.41%) to be added to master_df index 6845
# Processing index 256 out of 273 (93.77%) to be added to master_df index 6846
# Processing index 257 out of 273 (94.14%) to be added to master_df index 6847
# Processing index 258 out of 273 (94.51%) to be added to master_df index 6848
# Processing index 259 out of 273 (94.87%) to be added to master_df index 6849
# Processing index 260 out of 273 (95.24%) to be added to master_df index 6850
# Processing index 261 out of 273 (95.6%) to be added to master_df index 6851
# Processing index 262 out of 273 (95.97%) to be added to master_df index 6852
# Processing index 263 out of 273 (96.34%) to be added to master_df index 6853
# Processing index 264 out of 273 (96.7%) to be added to master_df index 6854
# Processing index 265 out of 273 (97.07%) to be added to master_df index 6855
# Processing index 266 out of 273 (97.44%) to be added to master_df index 6856
# Processing index 267 out of 273 (97.8%) to be added to master_df index 6857
# Processing index 268 out of 273 (98.17%) to be added to master_df index 6858
# Processing index 269 out of 273 (98.53%) to be added to master_df index 6859
# Processing index 270 out of 273 (98.9%) to be added to master_df index 6860
# Processing index 271 out of 273 (99.27%) to be added to master_df index 6861
# Processing index 272 out of 273 (99.63%) to be added to master_df index 6862
# Processing index 273 out of 273 (100.0%) to be added to master_df index 6863

# %% [markdown]
# #### Loop II Statistics

# %%
print(f"WP: Added {original_wp_size - len(wp)} to master DF. Have {len(wp)} rows remaining")
# Out:
# WP: Added 104 to master DF. Have 241 rows remaining

# %%
print("Search Statistics: FE, MPV Complete")
search_results_dict
# Out:
# Search Statistics: FE, MPV Complete
# {'no_results_counter': 1862,
#  '1_result_counter': 11321,
#  '2_or_more_result_counter': 271}

# %% [markdown]
# ### 5.4 | Loop III: Add unmatched WP victims to DM-FS

# %%
wp_index = 0 # Note that we need a seperate mpv_index: the index in the loop refers to master_df index, which is much larger
starting_index = len(master_df)

for i in range(starting_index, len(wp)+starting_index) : # Adds MPV rows at the very end of master_df (i.e., why it starts at len(fe))
    
    # Displays progression
    print(f"Processing index {wp_index} out of {len(wp)-1} ({round(wp_index/ (len(wp)-1) * 100, 2)}%) to be added to master_df index {i}")

    # Extracts row
    wp_row = wp.iloc[wp_index].copy()
    wp_index += 1
    name, state, city, date = wp_row["name_abr"], wp_row["state_of_death"], wp_row["city_of_death_abr"], wp_row["date"]

    # Add row to master DF
    add_discrepencies_to_df(wp_row, filler_value = False)
    master_df = pd.concat([master_df,  pd.DataFrame([wp_row]) ], ignore_index=True) 
    master_df.loc[i, "URL_MPV"], master_df.loc[i, "URL_FE"] = None, None
    master_df.loc[i, "date_discrepancy_days"] = 0

    # Flags as ommission
    master_df.loc[i, "omission_fe"] = True
    master_df.loc[i, "omission_mpv"] = True
# Out:
# Processing index 0 out of 240 (0.0%) to be added to master_df index 6864
# Processing index 1 out of 240 (0.42%) to be added to master_df index 6865
# Processing index 2 out of 240 (0.83%) to be added to master_df index 6866
# Processing index 3 out of 240 (1.25%) to be added to master_df index 6867
# Processing index 4 out of 240 (1.67%) to be added to master_df index 6868
# Processing index 5 out of 240 (2.08%) to be added to master_df index 6869
# Processing index 6 out of 240 (2.5%) to be added to master_df index 6870
# Processing index 7 out of 240 (2.92%) to be added to master_df index 6871
# Processing index 8 out of 240 (3.33%) to be added to master_df index 6872
# Processing index 9 out of 240 (3.75%) to be added to master_df index 6873
# Processing index 10 out of 240 (4.17%) to be added to master_df index 6874
# Processing index 11 out of 240 (4.58%) to be added to master_df index 6875
# Processing index 12 out of 240 (5.0%) to be added to master_df index 6876
# Processing index 13 out of 240 (5.42%) to be added to master_df index 6877
# Processing index 14 out of 240 (5.83%) to be added to master_df index 6878
# Processing index 15 out of 240 (6.25%) to be added to master_df index 6879
# Processing index 16 out of 240 (6.67%) to be added to master_df index 6880
# Processing index 17 out of 240 (7.08%) to be added to master_df index 6881
# Processing index 18 out of 240 (7.5%) to be added to master_df index 6882
# Processing index 19 out of 240 (7.92%) to be added to master_df index 6883
# Processing index 20 out of 240 (8.33%) to be added to master_df index 6884
# Processing index 21 out of 240 (8.75%) to be added to master_df index 6885
# Processing index 22 out of 240 (9.17%) to be added to master_df index 6886
# Processing index 23 out of 240 (9.58%) to be added to master_df index 6887
# Processing index 24 out of 240 (10.0%) to be added to master_df index 6888
# Processing index 25 out of 240 (10.42%) to be added to master_df index 6889
# Processing index 26 out of 240 (10.83%) to be added to master_df index 6890
# Processing index 27 out of 240 (11.25%) to be added to master_df index 6891
# Processing index 28 out of 240 (11.67%) to be added to master_df index 6892
# Processing index 29 out of 240 (12.08%) to be added to master_df index 6893
# Processing index 30 out of 240 (12.5%) to be added to master_df index 6894
# Processing index 31 out of 240 (12.92%) to be added to master_df index 6895
# Processing index 32 out of 240 (13.33%) to be added to master_df index 6896
# Processing index 33 out of 240 (13.75%) to be added to master_df index 6897
# Processing index 34 out of 240 (14.17%) to be added to master_df index 6898
# Processing index 35 out of 240 (14.58%) to be added to master_df index 6899
# Processing index 36 out of 240 (15.0%) to be added to master_df index 6900
# Processing index 37 out of 240 (15.42%) to be added to master_df index 6901
# Processing index 38 out of 240 (15.83%) to be added to master_df index 6902
# Processing index 39 out of 240 (16.25%) to be added to master_df index 6903
# Processing index 40 out of 240 (16.67%) to be added to master_df index 6904
# Processing index 41 out of 240 (17.08%) to be added to master_df index 6905
# Processing index 42 out of 240 (17.5%) to be added to master_df index 6906
# Processing index 43 out of 240 (17.92%) to be added to master_df index 6907
# Processing index 44 out of 240 (18.33%) to be added to master_df index 6908
# Processing index 45 out of 240 (18.75%) to be added to master_df index 6909
# Processing index 46 out of 240 (19.17%) to be added to master_df index 6910
# Processing index 47 out of 240 (19.58%) to be added to master_df index 6911
# Processing index 48 out of 240 (20.0%) to be added to master_df index 6912
# Processing index 49 out of 240 (20.42%) to be added to master_df index 6913
# Processing index 50 out of 240 (20.83%) to be added to master_df index 6914
# Processing index 51 out of 240 (21.25%) to be added to master_df index 6915
# Processing index 52 out of 240 (21.67%) to be added to master_df index 6916
# Processing index 53 out of 240 (22.08%) to be added to master_df index 6917
# Processing index 54 out of 240 (22.5%) to be added to master_df index 6918
# Processing index 55 out of 240 (22.92%) to be added to master_df index 6919
# Processing index 56 out of 240 (23.33%) to be added to master_df index 6920
# Processing index 57 out of 240 (23.75%) to be added to master_df index 6921
# Processing index 58 out of 240 (24.17%) to be added to master_df index 6922
# Processing index 59 out of 240 (24.58%) to be added to master_df index 6923
# Processing index 60 out of 240 (25.0%) to be added to master_df index 6924
# Processing index 61 out of 240 (25.42%) to be added to master_df index 6925
# Processing index 62 out of 240 (25.83%) to be added to master_df index 6926
# Processing index 63 out of 240 (26.25%) to be added to master_df index 6927
# Processing index 64 out of 240 (26.67%) to be added to master_df index 6928
# Processing index 65 out of 240 (27.08%) to be added to master_df index 6929
# Processing index 66 out of 240 (27.5%) to be added to master_df index 6930
# Processing index 67 out of 240 (27.92%) to be added to master_df index 6931
# Processing index 68 out of 240 (28.33%) to be added to master_df index 6932
# Processing index 69 out of 240 (28.75%) to be added to master_df index 6933
# Processing index 70 out of 240 (29.17%) to be added to master_df index 6934
# Processing index 71 out of 240 (29.58%) to be added to master_df index 6935
# Processing index 72 out of 240 (30.0%) to be added to master_df index 6936
# Processing index 73 out of 240 (30.42%) to be added to master_df index 6937
# Processing index 74 out of 240 (30.83%) to be added to master_df index 6938
# Processing index 75 out of 240 (31.25%) to be added to master_df index 6939
# Processing index 76 out of 240 (31.67%) to be added to master_df index 6940
# Processing index 77 out of 240 (32.08%) to be added to master_df index 6941
# Processing index 78 out of 240 (32.5%) to be added to master_df index 6942
# Processing index 79 out of 240 (32.92%) to be added to master_df index 6943
# Processing index 80 out of 240 (33.33%) to be added to master_df index 6944
# Processing index 81 out of 240 (33.75%) to be added to master_df index 6945
# Processing index 82 out of 240 (34.17%) to be added to master_df index 6946
# Processing index 83 out of 240 (34.58%) to be added to master_df index 6947
# Processing index 84 out of 240 (35.0%) to be added to master_df index 6948
# Processing index 85 out of 240 (35.42%) to be added to master_df index 6949
# Processing index 86 out of 240 (35.83%) to be added to master_df index 6950
# Processing index 87 out of 240 (36.25%) to be added to master_df index 6951
# Processing index 88 out of 240 (36.67%) to be added to master_df index 6952
# Processing index 89 out of 240 (37.08%) to be added to master_df index 6953
# Processing index 90 out of 240 (37.5%) to be added to master_df index 6954
# Processing index 91 out of 240 (37.92%) to be added to master_df index 6955
# Processing index 92 out of 240 (38.33%) to be added to master_df index 6956
# Processing index 93 out of 240 (38.75%) to be added to master_df index 6957
# Processing index 94 out of 240 (39.17%) to be added to master_df index 6958
# Processing index 95 out of 240 (39.58%) to be added to master_df index 6959
# Processing index 96 out of 240 (40.0%) to be added to master_df index 6960
# Processing index 97 out of 240 (40.42%) to be added to master_df index 6961
# Processing index 98 out of 240 (40.83%) to be added to master_df index 6962
# Processing index 99 out of 240 (41.25%) to be added to master_df index 6963
# Processing index 100 out of 240 (41.67%) to be added to master_df index 6964
# Processing index 101 out of 240 (42.08%) to be added to master_df index 6965
# Processing index 102 out of 240 (42.5%) to be added to master_df index 6966
# Processing index 103 out of 240 (42.92%) to be added to master_df index 6967
# Processing index 104 out of 240 (43.33%) to be added to master_df index 6968
# Processing index 105 out of 240 (43.75%) to be added to master_df index 6969
# Processing index 106 out of 240 (44.17%) to be added to master_df index 6970
# Processing index 107 out of 240 (44.58%) to be added to master_df index 6971
# Processing index 108 out of 240 (45.0%) to be added to master_df index 6972
# Processing index 109 out of 240 (45.42%) to be added to master_df index 6973
# Processing index 110 out of 240 (45.83%) to be added to master_df index 6974
# Processing index 111 out of 240 (46.25%) to be added to master_df index 6975
# Processing index 112 out of 240 (46.67%) to be added to master_df index 6976
# Processing index 113 out of 240 (47.08%) to be added to master_df index 6977
# Processing index 114 out of 240 (47.5%) to be added to master_df index 6978
# Processing index 115 out of 240 (47.92%) to be added to master_df index 6979
# Processing index 116 out of 240 (48.33%) to be added to master_df index 6980
# Processing index 117 out of 240 (48.75%) to be added to master_df index 6981
# Processing index 118 out of 240 (49.17%) to be added to master_df index 6982
# Processing index 119 out of 240 (49.58%) to be added to master_df index 6983
# Processing index 120 out of 240 (50.0%) to be added to master_df index 6984
# Processing index 121 out of 240 (50.42%) to be added to master_df index 6985
# Processing index 122 out of 240 (50.83%) to be added to master_df index 6986
# Processing index 123 out of 240 (51.25%) to be added to master_df index 6987
# Processing index 124 out of 240 (51.67%) to be added to master_df index 6988
# Processing index 125 out of 240 (52.08%) to be added to master_df index 6989
# Processing index 126 out of 240 (52.5%) to be added to master_df index 6990
# Processing index 127 out of 240 (52.92%) to be added to master_df index 6991
# Processing index 128 out of 240 (53.33%) to be added to master_df index 6992
# Processing index 129 out of 240 (53.75%) to be added to master_df index 6993
# Processing index 130 out of 240 (54.17%) to be added to master_df index 6994
# Processing index 131 out of 240 (54.58%) to be added to master_df index 6995
# Processing index 132 out of 240 (55.0%) to be added to master_df index 6996
# Processing index 133 out of 240 (55.42%) to be added to master_df index 6997
# Processing index 134 out of 240 (55.83%) to be added to master_df index 6998
# Processing index 135 out of 240 (56.25%) to be added to master_df index 6999
# Processing index 136 out of 240 (56.67%) to be added to master_df index 7000
# Processing index 137 out of 240 (57.08%) to be added to master_df index 7001
# Processing index 138 out of 240 (57.5%) to be added to master_df index 7002
# Processing index 139 out of 240 (57.92%) to be added to master_df index 7003
# Processing index 140 out of 240 (58.33%) to be added to master_df index 7004
# Processing index 141 out of 240 (58.75%) to be added to master_df index 7005
# Processing index 142 out of 240 (59.17%) to be added to master_df index 7006
# Processing index 143 out of 240 (59.58%) to be added to master_df index 7007
# Processing index 144 out of 240 (60.0%) to be added to master_df index 7008
# Processing index 145 out of 240 (60.42%) to be added to master_df index 7009
# Processing index 146 out of 240 (60.83%) to be added to master_df index 7010
# Processing index 147 out of 240 (61.25%) to be added to master_df index 7011
# Processing index 148 out of 240 (61.67%) to be added to master_df index 7012
# Processing index 149 out of 240 (62.08%) to be added to master_df index 7013
# Processing index 150 out of 240 (62.5%) to be added to master_df index 7014
# Processing index 151 out of 240 (62.92%) to be added to master_df index 7015
# Processing index 152 out of 240 (63.33%) to be added to master_df index 7016
# Processing index 153 out of 240 (63.75%) to be added to master_df index 7017
# Processing index 154 out of 240 (64.17%) to be added to master_df index 7018
# Processing index 155 out of 240 (64.58%) to be added to master_df index 7019
# Processing index 156 out of 240 (65.0%) to be added to master_df index 7020
# Processing index 157 out of 240 (65.42%) to be added to master_df index 7021
# Processing index 158 out of 240 (65.83%) to be added to master_df index 7022
# Processing index 159 out of 240 (66.25%) to be added to master_df index 7023
# Processing index 160 out of 240 (66.67%) to be added to master_df index 7024
# Processing index 161 out of 240 (67.08%) to be added to master_df index 7025
# Processing index 162 out of 240 (67.5%) to be added to master_df index 7026
# Processing index 163 out of 240 (67.92%) to be added to master_df index 7027
# Processing index 164 out of 240 (68.33%) to be added to master_df index 7028
# Processing index 165 out of 240 (68.75%) to be added to master_df index 7029
# Processing index 166 out of 240 (69.17%) to be added to master_df index 7030
# Processing index 167 out of 240 (69.58%) to be added to master_df index 7031
# Processing index 168 out of 240 (70.0%) to be added to master_df index 7032
# Processing index 169 out of 240 (70.42%) to be added to master_df index 7033
# Processing index 170 out of 240 (70.83%) to be added to master_df index 7034
# Processing index 171 out of 240 (71.25%) to be added to master_df index 7035
# Processing index 172 out of 240 (71.67%) to be added to master_df index 7036
# Processing index 173 out of 240 (72.08%) to be added to master_df index 7037
# Processing index 174 out of 240 (72.5%) to be added to master_df index 7038
# Processing index 175 out of 240 (72.92%) to be added to master_df index 7039
# Processing index 176 out of 240 (73.33%) to be added to master_df index 7040
# Processing index 177 out of 240 (73.75%) to be added to master_df index 7041
# Processing index 178 out of 240 (74.17%) to be added to master_df index 7042
# Processing index 179 out of 240 (74.58%) to be added to master_df index 7043
# Processing index 180 out of 240 (75.0%) to be added to master_df index 7044
# Processing index 181 out of 240 (75.42%) to be added to master_df index 7045
# Processing index 182 out of 240 (75.83%) to be added to master_df index 7046
# Processing index 183 out of 240 (76.25%) to be added to master_df index 7047
# Processing index 184 out of 240 (76.67%) to be added to master_df index 7048
# Processing index 185 out of 240 (77.08%) to be added to master_df index 7049
# Processing index 186 out of 240 (77.5%) to be added to master_df index 7050
# Processing index 187 out of 240 (77.92%) to be added to master_df index 7051
# Processing index 188 out of 240 (78.33%) to be added to master_df index 7052
# Processing index 189 out of 240 (78.75%) to be added to master_df index 7053
# Processing index 190 out of 240 (79.17%) to be added to master_df index 7054
# Processing index 191 out of 240 (79.58%) to be added to master_df index 7055
# Processing index 192 out of 240 (80.0%) to be added to master_df index 7056
# Processing index 193 out of 240 (80.42%) to be added to master_df index 7057
# Processing index 194 out of 240 (80.83%) to be added to master_df index 7058
# Processing index 195 out of 240 (81.25%) to be added to master_df index 7059
# Processing index 196 out of 240 (81.67%) to be added to master_df index 7060
# Processing index 197 out of 240 (82.08%) to be added to master_df index 7061
# Processing index 198 out of 240 (82.5%) to be added to master_df index 7062
# Processing index 199 out of 240 (82.92%) to be added to master_df index 7063
# Processing index 200 out of 240 (83.33%) to be added to master_df index 7064
# Processing index 201 out of 240 (83.75%) to be added to master_df index 7065
# Processing index 202 out of 240 (84.17%) to be added to master_df index 7066
# Processing index 203 out of 240 (84.58%) to be added to master_df index 7067
# Processing index 204 out of 240 (85.0%) to be added to master_df index 7068
# Processing index 205 out of 240 (85.42%) to be added to master_df index 7069
# Processing index 206 out of 240 (85.83%) to be added to master_df index 7070
# Processing index 207 out of 240 (86.25%) to be added to master_df index 7071
# Processing index 208 out of 240 (86.67%) to be added to master_df index 7072
# Processing index 209 out of 240 (87.08%) to be added to master_df index 7073
# Processing index 210 out of 240 (87.5%) to be added to master_df index 7074
# Processing index 211 out of 240 (87.92%) to be added to master_df index 7075
# Processing index 212 out of 240 (88.33%) to be added to master_df index 7076
# Processing index 213 out of 240 (88.75%) to be added to master_df index 7077
# Processing index 214 out of 240 (89.17%) to be added to master_df index 7078
# Processing index 215 out of 240 (89.58%) to be added to master_df index 7079
# Processing index 216 out of 240 (90.0%) to be added to master_df index 7080
# Processing index 217 out of 240 (90.42%) to be added to master_df index 7081
# Processing index 218 out of 240 (90.83%) to be added to master_df index 7082
# Processing index 219 out of 240 (91.25%) to be added to master_df index 7083
# Processing index 220 out of 240 (91.67%) to be added to master_df index 7084
# Processing index 221 out of 240 (92.08%) to be added to master_df index 7085
# Processing index 222 out of 240 (92.5%) to be added to master_df index 7086
# Processing index 223 out of 240 (92.92%) to be added to master_df index 7087
# Processing index 224 out of 240 (93.33%) to be added to master_df index 7088
# Processing index 225 out of 240 (93.75%) to be added to master_df index 7089
# Processing index 226 out of 240 (94.17%) to be added to master_df index 7090
# Processing index 227 out of 240 (94.58%) to be added to master_df index 7091
# Processing index 228 out of 240 (95.0%) to be added to master_df index 7092
# Processing index 229 out of 240 (95.42%) to be added to master_df index 7093
# Processing index 230 out of 240 (95.83%) to be added to master_df index 7094
# Processing index 231 out of 240 (96.25%) to be added to master_df index 7095
# Processing index 232 out of 240 (96.67%) to be added to master_df index 7096
# Processing index 233 out of 240 (97.08%) to be added to master_df index 7097
# Processing index 234 out of 240 (97.5%) to be added to master_df index 7098
# Processing index 235 out of 240 (97.92%) to be added to master_df index 7099
# Processing index 236 out of 240 (98.33%) to be added to master_df index 7100
# Processing index 237 out of 240 (98.75%) to be added to master_df index 7101
# Processing index 238 out of 240 (99.17%) to be added to master_df index 7102
# Processing index 239 out of 240 (99.58%) to be added to master_df index 7103
# Processing index 240 out of 240 (100.0%) to be added to master_df index 7104

# %% [markdown]
# #### Loop III Statistics

# %%
# Removes the column that was added to WP as a placeholder
master_df.drop(columns=["URL"], inplace = True)

# Drops (now obsolete) "erroneous inclusion" criteria
master_df.drop(columns=["erroneous_inclusion_fe", "erroneous_inclusion_mpv", "erroneous_inclusion_wp" ], inplace = True)

# %%
# Print final search result statistics
print("Search Statistics (i.e., comparing every row of MPV to WP and FE_Suicidies")
print(f"Total Queries = {sum(search_results_dict.values()) }")
search_results_dict
# Out:
# Search Statistics (i.e., comparing every row of MPV to WP and FE_Suicidies
# Total Queries = 13454
# {'no_results_counter': 1862,
#  '1_result_counter': 11321,
#  '2_or_more_result_counter': 271}

# %%
# Number of civilians that were successfully matched by checking each row for omissions

# Calculates unmatched civilians from each of the 3 databases via omissions
fe_unmatched, mpv_unmatched, wp_unmatched, matched_between_at_least_two_databases = 0, 0, 0, 0
for i, ind_row in master_df.iterrows():
    if ind_row["omission_fe"] and ind_row["omission_mpv"] and ind_row["omission_wp"]:
        print(f"ERROR. Row {i} is recorded as having been omitted from all 3 databases. This shouldn't be possible: a fatally shot civillian should not be in this database if he/she doens't appear in any database")
        assert(False)
    elif ind_row["omission_mpv"] and ind_row["omission_wp"]:
        fe_unmatched += 1
    elif ind_row["omission_fe"] and ind_row["omission_wp"]:
        mpv_unmatched += 1
    elif ind_row["omission_fe"] and ind_row["omission_mpv"]:
        wp_unmatched += 1
    else:
        matched_between_at_least_two_databases += 1

#fe_original_size
#mpv_original_size
#wp_original_size 

# Prints results
print(f"Total: {matched_between_at_least_two_databases} successfully matched ({master_df.shape[0] - matched_between_at_least_two_databases} unmatched out of {master_df.shape[0]}) ({ 100 - round( (master_df.shape[0] - matched_between_at_least_two_databases) / master_df.shape[0] * 100, 2) }% match)")
print(f"Fatal Encounters: {fe_original_size - fe_unmatched} successfully matched ({fe_unmatched} unmatched out of {fe_original_size} total) ({ round( (fe_original_size - fe_unmatched) / fe_original_size * 100, 2) }% match)")
print(f"Mapping Police Violence: {mpv_original_size - mpv_unmatched} successfully matched ({mpv_unmatched} unmatched out of {mpv_original_size} total) ({ round( (mpv_original_size - mpv_unmatched) / mpv_original_size * 100, 2) }% match)")
print(f"Washington Post: {wp_original_size - wp_unmatched} successfully matched ({wp_unmatched} unmatched out of {wp_original_size} total) ({ round( (wp_original_size - wp_unmatched) / wp_original_size * 100, 2) }% match)")
# Out:
# Total: 6263 successfully matched (842 unmatched out of 7105) (88.15% match)
# Fatal Encounters: 6159 successfully matched (431 unmatched out of 6590 total) (93.46% match)
# Mapping Police Violence: 5893 successfully matched (170 unmatched out of 6063 total) (97.2% match)
# Washington Post: 5705 successfully matched (241 unmatched out of 5946 total) (95.95% match)

# %%
# Verify WP additions
print(master_df.shape)
master_df.tail(10)
# Out:
# (7105, 45)
#                      date             victim_name victim_age victim_gender  \
# 7095  2015-09-14 00:00:00       David Todd Powell         28          Male
# 7096  2015-08-29 00:00:00      James Marcus Brown         25          Male
# 7097  2015-08-12 00:00:00  Richard Dean Shull Jr.         24          Male
# 7098  2015-05-20 00:00:00           Anthony Gomez         29          Male
# 7099  2015-04-18 00:00:00             Grover Sapp         45          Male
# 7100  2015-04-15 00:00:00          Frank Shephard         41          Male
# 7101  2015-04-09 00:00:00               Don Smith         29          Male
# 7102  2015-02-16 00:00:00       Lawrence Caldwell         56          Male
# 7103  2015-02-09 00:00:00          Desmond Luster         45          Male
# 7104  2015-01-07 00:00:00               Ron Sneed         31          Male
#
#      victim_race    city_of_death state_of_death  \
# 7095       White          Barstow             CA
# 7096       Black  North Las Vegas             NV
# 7097       White           Odessa             TX
# 7098       Black        Lancaster             PA
# 7099       White      Panama City             FL
# 7100       Black          Houston             TX
# 7101       Black            Monon             IN
# 7102       White           Marana             AZ
# 7103       Black           Dallas             TX
# 7104       Black         Freeport             TX
#
#                           agency_responsible_1       agency_responsible_2  \
# 7095                 Barstow Police Department                       None
# 7096  Las Vegas Metropolitan Police Department                       None
# 7097                  Odessa Police Department              Texas Rangers
# 7098           Lancaster City Bureau of Police                       None
# 7099             Panama City Police Department                       None
# 7100                 Houston Police Department                       None
# 7101    Tippecanoe County Sheriff's Department  Wasketa Police Department
# 7102                  Marana Police Department                       None
# 7103                  Dallas Police Department                       None
# 7104                Freeport Police Department                       None
#
#       agency_responsible_3 agency_responsible_4 agency_responsible_5  \
# 7095                  None                 None                 None
# 7096                  None                 None                 None
# 7097                  None                 None                 None
# 7098                  None                 None                 None
# 7099                  None                 None                 None
# 7100                  None                 None                 None
# 7101  Indiana State Police                 None                 None
# 7102                  None                 None                 None
# 7103                  None                 None                 None
# 7104                  None                 None                 None
#
#      agency_responsible_6           name_abr agency_responsible_abr_1  \
# 7095                  NaN       david_powell           barstow_police
# 7096                  NaN        james_brown         las_vegas_police
# 7097                  NaN         richard_jr            odessa_police
# 7098                  NaN      anthony_gomez    lancaster_city_police
# 7099                  NaN        grover_sapp       panama_city_police
# 7100                  NaN     frank_shephard           houston_police
# 7101                  NaN          don_smith       tippecanoe_sheriff
# 7102                  NaN  lawrence_caldwell            marana_police
# 7103                  NaN     desmond_luster            dallas_police
# 7104                  NaN          ron_sneed          freeport_police
#
#      agency_responsible_abr_2 agency_responsible_abr_3  \
# 7095                     none                     none
# 7096                     none                     none
# 7097            texas_rangers                     none
# 7098                     none                     none
# 7099                     none                     none
# 7100                     none                     none
# 7101           wasketa_police     indiana_state_police
# 7102                     none                     none
# 7103                     none                     none
# 7104                     none                     none
#
#      agency_responsible_abr_4 agency_responsible_abr_5  \
# 7095                     none                     none
# 7096                     none                     none
# 7097                     none                     none
# 7098                     none                     none
# 7099                     none                     none
# 7100                     none                     none
# 7101                     none                     none
# 7102                     none                     none
# 7103                     none                     none
# 7104                     none                     none
#
#      agency_responsible_abr_6 city_of_death_abr omission_fe omission_mpv  \
# 7095                      NaN           barstow        True         True
# 7096                      NaN   north las vegas        True         True
# 7097                      NaN            odessa        True         True
# 7098                      NaN         lancaster        True         True
# 7099                      NaN       panama city        True         True
# 7100                      NaN           houston        True         True
# 7101                      NaN             monon        True         True
# 7102                      NaN            marana        True         True
# 7103                      NaN            dallas        True         True
# 7104                      NaN          freeport        True         True
#
#      omission_wp date_fe date_mpv date_wp city_fe city_mpv city_wp gender_fe  \
# 7095       False   False    False   False   False    False   False     False
# 7096       False   False    False   False   False    False   False     False
# 7097       False   False    False   False   False    False   False     False
# 7098       False   False    False   False   False    False   False     False
# 7099       False   False    False   False   False    False   False     False
# 7100       False   False    False   False   False    False   False     False
# 7101       False   False    False   False   False    False   False     False
# 7102       False   False    False   False   False    False   False     False
# 7103       False   False    False   False   False    False   False     False
# 7104       False   False    False   False   False    False   False     False
#
#      gender_mpv gender_wp age_fe age_mpv age_wp race_fe race_mpv race_wp  \
# 7095      False     False  False   False  False   False    False   False
# 7096      False     False  False   False  False   False    False   False
# 7097      False     False  False   False  False   False    False   False
# 7098      False     False  False   False  False   False    False   False
# 7099      False     False  False   False  False   False    False   False
# 7100      False     False  False   False  False   False    False   False
# 7101      False     False  False   False  False   False    False   False
# 7102      False     False  False   False  False   False    False   False
# 7103      False     False  False   False  False   False    False   False
# 7104      False     False  False   False  False   False    False   False
#
#      agency_responsible_fe agency_responsible_mpv agency_responsible_wp  \
# 7095                 False                  False                 False
# 7096                 False                  False                 False
# 7097                 False                  False                 False
# 7098                 False                  False                 False
# 7099                 False                  False                 False
# 7100                 False                  False                 False
# 7101                 False                  False                 False
# 7102                 False                  False                 False
# 7103                 False                  False                 False
# 7104                 False                  False                 False
#
#      date_discrepancy_days URL_FE URL_MPV
# 7095                     0   None    None
# 7096                     0   None    None
# 7097                     0   None    None
# 7098                     0   None    None
# 7099                     0   None    None
# 7100                     0   None    None
# 7101                     0   None    None
# 7102                     0   None    None
# 7103                     0   None    None
# 7104                     0   None    None

# %% [markdown]
# ### 5.5 | Exports Our Manual Corrections Dataframe (if applicable)

# %% [markdown]
# If we made new manual corrections, i.e., if USE_MANUAL_MATHING_DATAFRAME was set to False, then saves these manual corrections to a dataframe so they can be replicated later.

# %%
if not USE_MANUAL_MATCHING_DATAFRAME:
    print("Saving our manual match dataframe")
    manual_match_verification_df = pd.read_csv(f"{MATCH_DIR}manual_matches.csv", index = False)
    manual_fuzzy_match_verification_df = pd.read_csv(f"{MATCH_DIR}fuzzy_search_name_matches.csv", index = False)
else:
    print("USE_MANUAL_MATHING_DATAFRAME was set to false. This means that you used the decisions contained in the pre-existing dataframe to handle manual matches.")
    print("Thus, no changes were made to the dataframe, hence, there is no need to save them.\nNo action is needed. Please proceed with the program.")
# Out:
# USE_MANUAL_MATHING_DATAFRAME was set to false. This means that you used the decisions contained in the pre-existing dataframe to handle manual matches.
# Thus, no changes were made to the dataframe, hence, there is no need to save them.
# No action is needed. Please proceed with the program.

# %% [markdown]
# # 6 | Export (i) DM-FS and (ii) a version of DM-FS that Needs Manual Corrections

# %% [markdown]
# "Needing manual corrections" is defined as any value in which the databases disagree.

# %% [markdown]
# ### 6.1 | Aux Functions

# %%
# Prints the number of manual corrections that need to be undertaken, by column. Returns total manual corrections (int)
def print_manual_corrections(df, col):
    
    # Gets errors
    error_df = df[df[col].isin(["ERROR - 2 Databases Disagree", "ERROR - 3 Databases Disagree"])]
    error_counts = error_df[col].value_counts()

    # Prints them
    print(col)
    for index, count in error_counts.items():
            print(f"{index} : {count}")
    print(f"TOTAL = {len(error_df)}")

    # Returns (i) the total number of errors that need to be manually corrected and (ii) their indices
    return len(error_df), list(error_df.index)

# %% [markdown]
# ### 6.2 | Explore number of manual corrections needed by column

# %%
# Prints all discrepencies & their total
grand_total = 0 # Records grand total number of discrepencies
error_indices = []

for ind_col in master_df.columns[0:8]:
    total, manual_correction_indices = print_manual_corrections(master_df, ind_col)
    grand_total += total
    error_indices.append(manual_correction_indices)
print(f"{'*'*20}\nTotal Manual Corrections = {grand_total}")
# Out:
# date
# ERROR - 2 Databases Disagree : 50
# ERROR - 3 Databases Disagree : 2
# TOTAL = 52
# victim_name
# TOTAL = 0
# victim_age
# ERROR - 2 Databases Disagree : 74
# ERROR - 3 Databases Disagree : 4
# TOTAL = 78
# victim_gender
# ERROR - 2 Databases Disagree : 4
# ERROR - 3 Databases Disagree : 1
# TOTAL = 5
# victim_race
# ERROR - 2 Databases Disagree : 100
# ERROR - 3 Databases Disagree : 20
# TOTAL = 120
# city_of_death
# ERROR - 2 Databases Disagree : 111
# ERROR - 3 Databases Disagree : 54
# TOTAL = 165
# state_of_death
# TOTAL = 0
# agency_responsible_1
# ERROR - 3 Databases Disagree : 141
# ERROR - 2 Databases Disagree : 81
# TOTAL = 222
# ********************
# Total Manual Corrections = 642

# %% [markdown]
# ### 6.3 | Create dataframe of just manual corrections

# %%
# Cleans error indices so it's (i) one list (vs. lists of indices-lists) with (ii) no empty lists and (iii) only unique indices
error_indices = [sublist for sublist in error_indices if sublist]  # Remove empty lists
error_indices = [item for sublist in error_indices for item in sublist]  # Flatten the list of lists
error_indices = sorted(list(set(error_indices)))  # Keep only unique values

print(f"Rows that need to undergo manual review = {len(error_indices)}")
# Out:
# Rows that need to undergo manual review = 552

# %%
manual_correction_df = master_df.loc[error_indices]
manual_correction_df.head(5)
# Out:
#                    date         victim_name                    victim_age  \
# 3   2020-12-30 00:00:00  David Jacob Rigsby                            39
# 10  2020-12-29 00:00:00       Samuel Lazaro                            18
# 19  2020-12-28 00:00:00       Not Disclosed                            -1
# 44  2020-12-18 00:00:00       Not Disclosed  ERROR - 2 Databases Disagree
# 45  2020-12-17 00:00:00     Andrew Mansilla                            25
#
#                    victim_gender                   victim_race  \
# 3                           Male  ERROR - 2 Databases Disagree
# 10                          Male  ERROR - 2 Databases Disagree
# 19  ERROR - 2 Databases Disagree                       Unknown
# 44                          Male                       Unknown
# 45                          Male  ERROR - 2 Databases Disagree
#
#                    city_of_death state_of_death  \
# 3                        Waverly             TN
# 10  ERROR - 2 Databases Disagree             NY
# 19                       Holyoke             CO
# 44                Lucerne Valley             CA
# 45                 Daytona Beach             FL
#
#                       agency_responsible_1  \
# 3                Waverly Police Department
# 10      City of New York Police Department
# 19               Holyoke Police Department
# 44  San Bernardino County Sheriff's Office
# 45         Daytona Beach Police Department
#
#                   agency_responsible_2 agency_responsible_3  \
# 3    Humphreys County Sheriff's Office                 None
# 10                                None                 None
# 19                                None                 None
# 44                                None                 None
# 45                                None                 None
#
#    agency_responsible_4 agency_responsible_5 agency_responsible_6  \
# 3                  None                 None                 None
# 10                 None                 None                 None
# 19                 None                 None                 None
# 44                 None                 None                 None
# 45                 None                 None                 None
#
#            name_abr agency_responsible_abr_1 agency_responsible_abr_2  \
# 3      david_rigsby           waverly_police        humphreys_sheriff
# 10    samuel_lazaro  city_of_new_york_police                      NaN
# 19    not_disclosed           holyoke_police                      NaN
# 44    not_disclosed   san_bernardino_sheriff                      NaN
# 45  andrew_mansilla     daytona_beach_police                      NaN
#
#    agency_responsible_abr_3 agency_responsible_abr_4 agency_responsible_abr_5  \
# 3                       NaN                      NaN                      NaN
# 10                      NaN                      NaN                      NaN
# 19                      NaN                      NaN                      NaN
# 44                      NaN                      NaN                      NaN
# 45                      NaN                      NaN                      NaN
#
#    agency_responsible_abr_6 city_of_death_abr omission_fe omission_mpv  \
# 3                       NaN           waverly       False         True
# 10                      NaN          brooklyn       False         True
# 19                      NaN           holyoke       False        False
# 44                      NaN    lucerne valley       False         True
# 45                      NaN     daytona beach       False         True
#
#    omission_wp date_fe date_mpv date_wp   city_fe city_mpv   city_wp  \
# 3        False   False    False   False     False    False     False
# 10       False   False    False   False  Brooklyn    False  New York
# 19        True   False    False   False     False    False     False
# 44       False   False    False   False     False    False     False
# 45       False   False    False   False     False    False     False
#
#    gender_fe gender_mpv gender_wp age_fe age_mpv age_wp  race_fe race_mpv  \
# 3      False      False     False  False   False  False  Unknown    False
# 10     False      False     False  False   False  False  Unknown    False
# 19   Unknown       Male     False  False   False  False    False    False
# 44     False      False     False     -1   False     65    False    False
# 45     False      False     False  False   False  False    White    False
#
#      race_wp agency_responsible_fe agency_responsible_mpv  \
# 3      White                 False                  False
# 10  Hispanic                 False                  False
# 19     False                 False                  False
# 44     False                 False                  False
# 45  Hispanic                 False                  False
#
#    agency_responsible_wp date_discrepancy_days  \
# 3                  False                     0
# 10                 False                     0
# 19                 False                     0
# 44                 False                     0
# 45                 False                     0
#
#                                                URL_FE  \
# 3   https://www.newschannel5.com/news/tbi-investig...
# 10  https://www.radio.com/1010wins/news/local/nypd...
# 19  https://denver.cbslocal.com/2020/12/30/holyoke...
# 44  https://www.sbsun.com/2020/12/19/deputies-shoo...
# 45  https://www.clickorlando.com/news/local/2020/1...
#
#                                               URL_MPV
# 3                                                 NaN
# 10                                                NaN
# 19  https://denver.cbslocal.com/2020/12/30/holyoke...
# 44                                                NaN
# 45                                                NaN

# %% [markdown]
# ### 6.4 | Export both dataframes

# %%
CORRECTIONS_DIR = "res/1.2 - DM-FS Before Manual Corrections/"
manual_correction_df.to_csv(f"{CORRECTIONS_DIR}manual_correction_to_make.csv", index = True)
master_df.to_csv(f"{CORRECTIONS_DIR}DMFS_no_manual_corrections.csv", index = True)
