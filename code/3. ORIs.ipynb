# %% [markdown]
# # Third Notebook: Apply ORIs

# %% [markdown]
# Looks up & applies ORI codes from Crosswalk file to DMFS Cops & Civilians. Also records any manual matches or manual corrections that are made.

# %% [markdown]
# # 0 | Imports

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from collections import Counter # Unique value ID

from thefuzz import fuzz # Fuzzy Search
import math
import os

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # 1 | Loads & Preprocesses Dataset

# %% [markdown]
# ### 1.1 | Loads DFs

# %%
# Inits Directories
INPUT_DIR = "res/2.0 - DM-FS with Manual Corrections/"

# %%
# Loads DFs
df_civ = pd.read_csv(f"{INPUT_DIR}DM-FS with Manual Corrections.csv")
df_ori = pd.read_csv(f"{INPUT_DIR}ORI_Crosswalk.csv", low_memory = False)
df_cops = pd.read_csv(f"{INPUT_DIR}DM-FS - Officers before ORIs.csv")

# %% [markdown]
# ### 1.2 | Preprocessing

# %%
# Fixes annoying spaces in df_ori column names
df_ori.columns = [x.strip() for x in list(df_ori.columns)]
df_ori.rename(columns={"NAME": "LEA_NAME"}, inplace=True) # Renames Name to LEA Name
df_ori.columns
# Out:
# Index(['FSTATE', 'FCOUNTY', 'FPLACE', 'FIPS_ST', 'FIPS_COUNTY', 'FIPS', 'ORI9',
#        'ORI7', 'LEA_NAME', 'UA', 'STATENAME', 'COUNTYNAME', 'UANAME', 'PARTOF',
#        'AGCYTYPE', 'SUBTYPE1', 'SUBTYPE2', 'GOVID', 'LG_NAME',
#        'address_corrected', 'ADDRESS_NAME', 'ADDRESS_STR1', 'ADDRESS_STR2',
#        'ADDRESS_CITY', 'ADDRESS_STATE', 'ADDRESS_ZIP', 'REPORT_FLAG',
#        'CSLLEA08_ID', 'LEMAS_ID', 'U_STATENO', 'U_CNTY', 'U_POPGRP', 'U_TPOP',
#        'LG_POPULATION', 'CSLLEA_SUB', 'COMMENT', 'INTPTLAT', 'INTPTLONG',
#        'CONGDIST1', 'CONGDIST2_18', 'DISTNAME', 'SOURCE_CSLLEA2008',
#        'SOURCE_UCR2010', 'SOURCE_UCR2011', 'SOURCE_UCR2012', 'SOURCE_NCIC2012',
#        'SOURCE_VENDOR'],
#       dtype='object')

# %%
# There's a ton of empty rows on the Crosswalk file, so let's only get the rows that have a value
df_ori = df_ori[df_ori["FSTATE"].notna()]
df_ori = df_ori.reset_index(drop = True)

# %%
# There's one agency in df_civ that wasn't seperated into LEA 1 and LEA 2 because a ';' was used instead of a ','. Let's fix that.
for bad_agency_index in list(df_civ[df_civ["agency_responsible_1"].str.contains(';', na=False)].index):
    problematic_value = df_civ.loc[bad_agency_index, "agency_responsible_1"]
    print(f"Multiple LEAs detected in df_civ at index {bad_agency_index} with value [{problematic_value}]. This has been corrected.")

    for i, ind_agency in enumerate(problematic_value.split(';')):
        df_civ.loc[bad_agency_index, f"agency_responsible_{i+1}"] = ind_agency.strip()
# Out:
# Multiple LEAs detected in df_civ at index 6614 with value [Weber County Sheriff's Office; Morgan County Sheriff's Office]. This has been corrected.

# %%
# DF_CIV has 6 columns for listing LEAs responsible for civillians deaths: one column per LEA
# However, Column #6 is never used: only up to 5 LEAs are responsible for a civillian's death
# Thus, we'll drop column #6

df_civ.drop(columns=['agency_responsible_6'], inplace=True)

# %%
# The databases list the "City of New York Police" as "New York Police". 
# This is confusing, because it may be confused with "New York State Police"
# Thus, to avoid ambiguity, New York Police will be renamed to City of New York Police in all the datasets

# Fixes it in Civillians
df_civ.loc[df_civ['agency_responsible_1'] == "New York Police Department", 'agency_responsible_1'] = "City of New York Police Department"

# Fixes it in Officers
df_cops.loc[df_cops['LEA_NAME'] == "New York Police Department", 'LEA_NAME'] = "City of New York Police Department"
df_cops.loc[df_cops['LEA_NAME'] == "New York Police Department, 46th Precinct", 'LEA_NAME'] = "City of New York Police Department"

# Fixes it in Crosswalk
df_ori.loc[df_ori['LEA_NAME'].str.startswith("NEW YORK CITY", na=False), 'LEA_NAME'] = df_ori['LEA_NAME'].str.replace(r'^NEW YORK CITY', 'CITY OF NEW YORK', regex=True)

# %% [markdown]
# # 2 | NLP

# %% [markdown]
# ### 2.1 | Aux Functions

# %%
def remove_parentheses(text):

    if not text:
        return text

    if pd.isna(text):  
        return text
    
    result = []
    inside_parentheses = False
    for char in text:
        if char == '(':
            inside_parentheses = True
        elif char == ')':
            inside_parentheses = False
        elif not inside_parentheses:
            result.append(char)
    return ''.join(result).strip()

# %%
# Creates a dummy  name column. An abbreviated version of the victim's name we can use for comparison

def clean_LEA_name(df, col):

    # Creates a new column that's a carbon copy of the LEA name, and modifies that from hereon out
    df[f'{col}_CLEANED'] = df[col] # Old Col Name
    col = f'{col}_CLEANED'
    df[col] = df[col].fillna('') # Fills any NAs with empty string values (mainly for df_civ for agency_2, agency_3, etc.)
    df[col] = df[col].str.lower() # Makes lower

    # Fixes weird punctuation
    df[col] = df[col].str.replace("'", "")# Removes '
    df[col] = df[col].str.replace("\"", "")# Removes "
    df[col] = df[col].str.replace(".", "")# Removes .
    df[col] = df[col].str.replace("’", "")# Removes weird ’
    df[col] = df[col].str.replace("-", " ")# Removes -

    # Removes ',' and 'in' because that indicates a specific detachment of state police which likely doesn't have a unique ORI
    df[col] = df[col].str.split(',').str[0]
    df[col] = df[col].str.split(' in ').str[0]

    # Removes 'department' and 'office' b/c theyr'e sometimes used interchangeably between databases
    df[col] = df[col].str.replace("department", "")
    df[col] = df[col].str.replace("deparment", "")
    df[col] = df[col].str.replace("departmen", "")
    df[col] = df[col].str.replace(" dept", "")
    df[col] = df[col].str.replace(" office", "")

    # Removes the (parentheses) that WP adds to some LEAs as notes
    df[col] = df[col].apply(lambda x: pd.Series(remove_parentheses(x))) # Removes middle name(s)
        
    # Misc
    df[col] = df[col].str.replace("sheriffs", "sheriff")
    df[col] = df[col].str.replace("constables", "constable")
    df[col] = df[col].str.replace("bureau of", "")
    df[col] = df[col].str.replace("division of", "")
    df[col] = df[col].str.replace("borough", "")
#    df[col] = df[col].str.replace("housing authority", "") # housing authorities are usually part of some parent police department
    df[col] = df[col].str.replace("public safety", "police") # There is usually a disticntion "police" and "public safety", but they mean same for ORI Matching
    df[col] = df[col].str.replace("tech university", "tech") # Makes it more likely that, if a tech-uni LEA forgot to put uni in its name, it'll match (e.g., "Texas Tech Police" vs "Texas Tech University Police"
    df[col] = df[col].str.replace("metropolitan", "")
    df[col] = df[col].str.replace("of", "")
    df[col] = df[col].str.replace("county", "")
    df[col] = df[col].str.replace(" co ", " ") # 'co' is an abbreiated form of county

    # Spell out abbreviations
    df[col] = df[col].str.replace(" pd", " police")
    df[col] = df[col].str.replace(" twp ", " township ")
    df[col] = df[col].str.replace(" pct ", " precinct ")
#    df[col] = df[col].str.replace(" hp ", " highway patrol ")
    df[col] = df[col].str.replace(" independent school district", " isd") # Don't use the full "independent school district" abbreviation b/c otherwise there'll be a ton of false positives in the fuzzy search
    
    # Removes whitespace
    df[col] = df[col].str.strip()
    df[col] = df[col].str.replace("  ", " ")
    df[col] = df[col].str.replace(" ", "_")

# %% [markdown]
# ### 2.2 | Applies NLP to LEA Names

# %%
# Cops
clean_LEA_name(df_cops, "LEA_NAME")
df_cops.loc[ : , ["LEA_NAME", "LEA_NAME_CLEANED"]].head(10)
# Out:
#                                  LEA_NAME                 LEA_NAME_CLEANED
# 0         Johnson County Sheriff’s Office                  johnson_sheriff
# 1               Hayward Police Department                   hayward_police
# 2              San Jose Police Department                  san_jose_police
# 3           Colorado State Patrol, Golden            colorado_state_patrol
# 4        Okaloosa County Sheriff’s Office                 okaloosa_sheriff
# 5         Coeur d’Alene Police Department              coeur_dalene_police
# 6         McHenry County Sheriff's Office                  mchenry_sheriff
# 7    Kentucky State Police, Mayfield Post            kentucky_state_police
# 8    U.S. Marshals Service of Baton Rouge  us_marshals_service_baton_rouge
# 9  Louisiana State Police in Lake Charles           louisiana_state_police

# %%
# Civs
for col_name in [f"agency_responsible_{x}" for x in range(1,6)]:
    clean_LEA_name(df_civ, col_name)

# %%
clean_LEA_name(df_ori, "LEA_NAME")
df_ori.loc[ : , ["LEA_NAME", "LEA_NAME_CLEANED"]].head(10)
# Out:
#                                             LEA_NAME  \
# 0  AUTAUGAVILLE POLICE DEPARTMENT                ...
# 1  PRATTVILLE POLICE DEPARTMENT                  ...
# 2  PRATTVILLE FIRE DEPT ARSON INVESTIGATION BRANC...
# 3  AUTAUGA COUNTY SHERIFF'S OFFICE               ...
# 4  FAULKNER STATE COMMUNITY COLLEGE POLICE DEPT  ...
# 5  BAY MINETTE POLICE DEPARTMENT                 ...
# 6  DAPHNE POLICE DEPARTMENT                      ...
# 7  ELBERTA POLICE DEPARTMENT                     ...
# 8  FAIRHOPE POLICE DEPARTMENT                    ...
# 9  FOLEY POLICE DEPARTMENT                       ...
#
#                              LEA_NAME_CLEANED
# 0                         autaugaville_police
# 1                           prattville_police
# 2  prattville_fire_arson_investigation_branch
# 3                             autauga_sheriff
# 4     faulkner_state_community_college_police
# 5                          bay_minette_police
# 6                               daphne_police
# 7                              elberta_police
# 8                             fairhope_police
# 9                                foley_police

# %% [markdown]
# ### 2.3 | Processes State Names

# %%
# df_civs only has state abbreviations, but the crosswalk requires full state names for linkage
# Thus, let's turn the abbreviations into state names

state_abbr_to_name = {
    'AL': 'Alabama', 'AK': 'Alaska', 'AZ': 'Arizona', 'AR': 'Arkansas', 'CA': 'California',
    'CO': 'Colorado', 'CT': 'Connecticut', 'DE': 'Delaware', 'FL': 'Florida', 'GA': 'Georgia',
    'HI': 'Hawaii', 'ID': 'Idaho', 'IL': 'Illinois', 'IN': 'Indiana', 'IA': 'Iowa',
    'KS': 'Kansas', 'KY': 'Kentucky', 'LA': 'Louisiana', 'ME': 'Maine', 'MD': 'Maryland',
    'MA': 'Massachusetts', 'MI': 'Michigan', 'MN': 'Minnesota', 'MS': 'Mississippi', 'MO': 'Missouri',
    'MT': 'Montana', 'NE': 'Nebraska', 'NV': 'Nevada', 'NH': 'New Hampshire', 'NJ': 'New Jersey',
    'NM': 'New Mexico', 'NY': 'New York', 'NC': 'North Carolina', 'ND': 'North Dakota', 'OH': 'Ohio',
    'OK': 'Oklahoma', 'OR': 'Oregon', 'PA': 'Pennsylvania', 'RI': 'Rhode Island', 'SC': 'South Carolina',
    'SD': 'South Dakota', 'TN': 'Tennessee', 'TX': 'Texas', 'UT': 'Utah', 'VT': 'Vermont',
    'VA': 'Virginia', 'WA': 'Washington', 'WV': 'West Virginia', 'WI': 'Wisconsin', 'WY': 'Wyoming',
    'DC': 'District of Columbia'
}

# Creates a 'state_of_death' column
df_civ.rename(columns={"state_of_death": "state_of_death_abr"}, inplace=True)
df_civ["state_of_death"] = df_civ["state_of_death_abr"].map(state_abbr_to_name)

# %%
# Rearrange cols to place 'state_of_death' before 'state_of_death_abr'
cols = list(df_civ.columns)  # Get the current columns
abr_index = cols.index("state_of_death_abr")  # Correctly find the index of 'state_of_death_abr'
new_order = cols[:abr_index] + ["state_of_death"] + cols[abr_index:]  # Create new column order
df_civ = df_civ[new_order].iloc[:, :-1] # Drops last column b/c it's a duplicate of state_of_death

df_civ.head(1)
# Out:
#                   date             victim_name victim_age victim_gender  \
# 0  2020-12-31 00:00:00  David Randall Shephard         39          Male
#
#   victim_race city_of_death state_of_death state_of_death_abr  \
# 0       White      Beaumont          Texas                 TX
#
#          agency_responsible_1 agency_responsible_2 agency_responsible_3  \
# 0  Beaumont Police Department                  NaN                  NaN
#
#   agency_responsible_4 agency_responsible_5  included_in_fe  included_in_mpv  \
# 0                  NaN                  NaN            True             True
#
#    included_in_wp  date_fe  date_mpv  date_wp  city_fe  city_mpv  city_wp  \
# 0            True    False     False    False    False     False    False
#
#    gender_fe  gender_mpv  gender_wp  age_fe  age_mpv  age_wp  race_fe  \
# 0      False       False      False   False    False   False    False
#
#    race_mpv  race_wp  agency_responsible_fe  agency_responsible_mpv  \
# 0     False    False                  False                   False
#
#    agency_responsible_wp  date_discrepancy_days  \
# 0                  False                      0
#
#                                               URL_FE  \
# 0  https://www.12newsnow.com/article/news/local/s...
#
#                                              URL_MPV URL_MANUAL_CORRECTION  \
# 0  https://www.usnews.com/news/best-states/texas/...                   NaN
#
#   agency_responsible_1_CLEANED agency_responsible_2_CLEANED  \
# 0              beaumont_police
#
#   agency_responsible_3_CLEANED agency_responsible_4_CLEANED  \
# 0
#
#   agency_responsible_5_CLEANED
# 0

# %%
# Let's make sure states are consistent within the 3 dataframes
df_cops["LEA_STATE"] = df_cops["LEA_STATE"].str.strip().str.title()
df_ori["STATENAME"] = df_ori["STATENAME"].str.strip().str.title()
df_civ["state_of_death"] = df_civ["state_of_death"].str.strip().str.title()

# %%
# Sanity check: do all datasets have the same states? Puerto Rico is OK

unique_cops = set(df_cops["LEA_STATE"].unique())
unique_ori = set(df_ori["STATENAME"].unique())
unique_civ = set(df_civ["state_of_death"].unique())

# Check for unique values in each list that do not appear in the others
unique_to_cops = unique_cops - unique_ori - unique_civ
unique_to_ori = unique_ori - unique_cops - unique_civ
unique_to_civ = unique_civ - unique_cops - unique_ori

# Print results
print("Unique States in DM-FS: Officers")
print(unique_to_cops)

print("Unique States in the Crosswalk")
print(unique_to_ori)

print("Unique States in DM-FS: Civillians")
print(unique_to_civ)
# Out:
# Unique States in DM-FS: Officers
# {'Puerto Rico'}
# Unique States in the Crosswalk
# set()
# Unique States in DM-FS: Civillians
# set()

# %% [markdown]
# # 3 | Loop Auxilary Functions

# %% [markdown]
# ### 3.1 | Match Methods: Manual Verification & Adding Match to DF

# %%
# Asks user to confirm match
# Loops until user types in Y or N

def manually_verify_match():
    while True:
        user_input = input("Confirm Match? Type 'Y' for Yes or 'N' for No: ").strip().upper()
        if user_input in ['Y', 'N']:
            return user_input
        else:
            print("Invalid input. Please enter 'Y' for Yes or 'N' for No.")

# %%
# Adds a new row to the match verification DF
def add_row_to_match_verification_df(db1_name, candidate_index, candidate_row, candidate_name, candidate_full_name, user_input, agency_responsible_num = -1):
    next_index = len(match_verification_df)
    match_verification_df.loc[next_index] = {"db_name" : db1_name, "agency_responsible_number" : agency_responsible_num, 
                                             "db_index" : i, "csslea_index" : candidate_index,
                                             "lea_name_db" : name, "lea_name_csllea" : candidate_name , 
                                            "lea_full_name_db" : full_name, "lea_full_name_csllea" : candidate_full_name,
                                             "lea_state_db" : state, "lea_state_csllea" : candidate_row["STATENAME"].strip().title(),
                                            "lea_ori_7" : candidate_row["ORI7"], "lea_ori_9" : candidate_row["ORI9"], "match_verified" : (user_input == "Y")}

# %% [markdown]
# ### 3.2 | Fuzzy Match

# %%
def get_candidate_rows_via_fuzzzy_name_search(db, db1_name, agency_responsible_num = -1, threshold = 80):

    candidate_indices = []

    last_fuzzy_match_full_name, last_fuzzy_match_decision = None, None
    for candidate_index, candidate_row in db.iterrows():

        # Calculates fuzzy match
        candidate_name, candidate_full_name = candidate_row['LEA_NAME_CLEANED'], candidate_row['LEA_NAME'].strip().title()
        fuzzy_match = fuzz.ratio(name, candidate_name) > threshold

        if fuzzy_match:

            # Checks to see if it's already been matched. T His is because it's common for lEAs of the same name (e.g., New York) to have MANY ENTRIES
            verification_record = match_verification_df.query(f"db_name == '{db1_name}' & agency_responsible_number == {agency_responsible_num} & db_index == {i} & csslea_index == {candidate_index}")

            # If a match hasn't been verified, have user verify it
            if verification_record.empty:

                # Manually confirms fuzzy match
                print(f"{candidate_row['STATENAME']}: Fuzzy match for [{name}] and [{candidate_name}] ([{full_name}] and [{candidate_full_name})]?")
                if last_fuzzy_match_full_name and candidate_full_name == last_fuzzy_match_full_name: # If a repeat was detected (e.g., Philidalphia Police which has >100 entries)
                    print(f"--> Repeat entry detected. Using decision ['{user_input}'], the same as last time ")
                    user_input = last_fuzzy_match_decision
                else: # No duplicate
                    user_input = manually_verify_match()
                
                # Adds the user's decision to the dataframe (with ORI code)
                add_row_to_match_verification_df(db1_name, candidate_index, candidate_row, candidate_name, candidate_full_name, user_input, agency_responsible_num)
                last_fuzzy_match_full_name, last_fuzzy_match_decision = candidate_full_name, user_input # Stores the user's last decision
            
            # If a mach has been verified, re-use that same decision
            else:
                match_verified = verification_record["match_verified"].iloc[0]
                user_input = "Y" if match_verified else "N"
            
            # If match was verified, add it to our search results
            if user_input == 'Y':
                candidate_indices.append(candidate_index)
 
    return db.loc[candidate_indices]

# %% [markdown]
# ### 3.3 | Initialize Match

# %% [markdown]
# Contains different matching proceure for 0 matches, 1 matches, and multiple matches

# %%
# Takes ORI Candidates (a pandas dataframe) and returns either None or a match

def initialize_ori_match_from_candidates(candidates, db1_name, agency_responsible_num = -1):
    # If there's 0 or 1 candidate
    if len(candidates) == 0:
        return None
    elif len(candidates) == 1:
        return candidates.iloc[0]

    # If there are multiple candidates...
    print(f"{name} has multiple candidates {len(candidates)}")

    # Select only the parent agencies
    candidates_parent_agency_only = candidates[ candidates["PARTOF"].str.contains("Parent agency", na=False) ]

    # If there's only 1 parent agency in the list, return that
    if len(candidates_parent_agency_only) == 1:
        return candidates_parent_agency_only.iloc[0]

    # **********************************************************************
    # Handles multiple parent agencies via user input
    # **********************************************************************
    
    # If there are multiple parents, then there are multiple very different agencies thrown in here.
    # Return "None" so we can manually review it.
    elif len(candidates_parent_agency_only) > 1:
            
        # Prints out all the candidates
        print(f"Uh oh! Multiple parent agencies! Please identify the ORI for [{name}] ([{full_name}])")
        for index, ind_match in candidates_parent_agency_only.iterrows():
            print(f"--> {index} | {ind_match['LEA_NAME'].strip().title()} | {ind_match['LEA_NAME_CLEANED']} | {ind_match['ORI7']} | {ind_match['ORI9']}")
        print("We will go one-by-one. Please select the match you want to use")

        # Go row-by-row, asking user which one they'd like to select as candidate
        index_to_use = -1
        for candidate_index, candidate_row in candidates_parent_agency_only.iterrows():

            # Checks to see if it's already been matched. T His is because it's common for lEAs of the same name (e.g., New York) to have MANY ENTRIES
            verification_record = match_verification_df.query(f"db_name == '{db1_name}' & agency_responsible_number == {agency_responsible_num} & db_index == {i} & csslea_index == {candidate_index}")
            
            if verification_record.empty:
                print(f"--> {candidate_index} | {candidate_row['LEA_NAME'].strip().title()} | {candidate_row['LEA_NAME_CLEANED']} | {candidate_row['ORI7']} | {candidate_row['ORI9']}")
                user_input = manually_verify_match()
                add_row_to_match_verification_df(db1_name, candidate_index, candidate_row, candidate_row['LEA_NAME_CLEANED'], candidate_row['LEA_NAME'].strip(), 
                                                 user_input, agency_responsible_num)
            else:
                match_verified = verification_record["match_verified"].iloc[0]
                user_input = "Y" if match_verified else "N"

            # Updates index_to_use wiht whatever user selects/has selected
            index_to_use = candidate_index if user_input == 'Y' else index_to_use
            
        print("Using index ",index_to_use)
        return None if index_to_use == -1 else candidates_parent_agency_only.loc[index_to_use]

    # **********************************************************************
    # Handles multiple child agencies
    # **********************************************************************

    # If there's only one child agency with a valid ORI7, return that.
    candidates_with_ori = candidates_parent_agency_only[ ~candidates_parent_agency_only["ORI7"].str.contains("-1", na=False) ]
    if len(candidates_with_ori) == 1:
        return candidates_with_ori.iloc[0]

    # If there's only one child agency with a valid ORI9, return that
    candidates_with_ori = candidates_parent_agency_only[ ~candidates_parent_agency_only["ORI9"].str.contains("-1", na=False) ]
    if len(candidates_with_ori) == 1:
        return candidates_with_ori.iloc[0]
        
    # If there's multiple children with no clear ORI or parent, just arbitrarily use the first one.
    return candidates.iloc[0]

# %% [markdown]
# ### 3.4 | Records Manual Matches

# %%
# Records all manual ORI matches for transparency/replication
def record_manual_match(db_name, agency_responsible_num, og_lea, new_lea, new_lea_index, ori7, ori9, notes):
    new_row = {"db_name" : db_name, "agency_responsible_num" : agency_responsible_num, 
               "original_LEA_name" : og_lea, "LEA_that_original_was_mapped_onto_for_ORI_code" : new_lea, 
               "LEA_that_original_was_mapped_onto_csllea_index" : new_lea_index, "ORI7" : ori7, "ORI9" : ori9, "Notes" : notes}
    manual_corrections_df.loc[len(manual_corrections_df)] = new_row

# %% [markdown]
# ### 3.5 | Add & Initilaize CSLLEA Cols for Police

# %%
def add_csllea_cols_to_df_cops(df):
    cols_to_add = ["ORI7", "ORI9", "LEA_TYPE", "LEA_SUBTYPE_1", "LEA_SUBTYPE_2", "COUNTY", "LOCAL_GOVERNMENT_NAME", "DISTRICT", "FIPS_STATE", "FIPS_COUNTY", "FCOUNTY", "FPLACE"]
    for ind_col in cols_to_add:
        df[ind_col] = None

# %%
# Initializes a new row to add to the cops dataset
def initialize_match_to_add_for_dmfs_cops(ind_candidate):

    # Initializes match_to_add if there's a candidate
    if not ind_candidate.empty:
        match_to_add = {"ORI7" : ind_candidate['ORI7'].strip(), "ORI9" : ind_candidate['ORI9'].strip(), 
                        "LEA_TYPE" : ind_candidate['AGCYTYPE'].strip(), "LEA_SUBTYPE_1" : ind_candidate['SUBTYPE1'].strip(),
                        "LEA_SUBTYPE_2" : ind_candidate['SUBTYPE2'].strip(), "COUNTY" : ind_candidate['COUNTYNAME'].strip().title(),
                        "LOCAL_GOVERNMENT_NAME" : ind_candidate['LG_NAME'].strip().title(), "DISTRICT" : ind_candidate['DISTNAME'].strip().title(), 
                        "FIPS_STATE" : int(ind_candidate['FIPS_ST']), "FIPS_COUNTY" : int(ind_candidate['FIPS_COUNTY']), 
                        "FCOUNTY" : int(ind_candidate['FCOUNTY']), "FPLACE" : int(ind_candidate['FPLACE'])}

    # If there's no candidate, fill it with blank values
    else:
        match_to_add = {"ORI7" : -1, "ORI9" : -1, 
                        "LEA_TYPE" : "N/A", "LEA_SUBTYPE_1" : "N/A", "LEA_SUBTYPE_2" : "N/A", "COUNTY" : "N/A",
                        "LOCAL_GOVERNMENT_NAME" : "N/A", "DISTRICT" : "N/A", 
                        "FIPS_STATE" : -1, "FIPS_COUNTY" : -1, 
                        "FCOUNTY" : -1, "FPLACE" : -1 }
    return match_to_add

# %% [markdown]
# ### 3.6 | Add & Initialize CSLLEA Cols for CIVILIANS

# %%
def add_csllea_cols_to_df_civs(df):
    cols_to_add = ["ORI7", "ORI9", "LEA_TYPE", "LEA_SUBTYPE_1", "LEA_SUBTYPE_2", "LOCAL_GOVERNMENT_NAME", "DISTRICT", "FIPS_STATE", "FIPS_COUNTY"]

    # Loop through the agency_responsible_1 to agency_responsible_5
    for x in range(1, 6):
        # Find the index of the current 'agency_responsible_x' column
        agency_col = f"agency_responsible_{x}"
        if agency_col in df.columns:
            insert_loc = df.columns.get_loc(agency_col) + 1  # Insert after the agency column

            for ind_col in cols_to_add:
                new_col_name = f"agency_responsible_{x}_{ind_col}"
                # Insert the new column right after the agency column
                df.insert(insert_loc, new_col_name, None)
                insert_loc += 1  # Move the insertion location for the next column
        else:
            print(f"Column {agency_col} not found in the DataFrame.")

# %%
def initialize_match_to_add_for_dmfs_civs(ind_candidate, agency_responsible_col):
    
    # Initializes match_to_add if there's a candidate
    if not ind_candidate.empty:
        match_to_add = {f"{agency_responsible_col}_ORI7" : ind_candidate['ORI7'].strip(), f"{agency_responsible_col}_ORI9" : ind_candidate['ORI9'].strip(), 
                        f"{agency_responsible_col}_LEA_TYPE" : ind_candidate['AGCYTYPE'].strip(), f"{agency_responsible_col}_LEA_SUBTYPE_1" : ind_candidate['SUBTYPE1'].strip(),
                        f"{agency_responsible_col}_LEA_SUBTYPE_2" : ind_candidate['SUBTYPE2'].strip(), 
                        f"{agency_responsible_col}_LOCAL_GOVERNMENT_NAME" : ind_candidate['LG_NAME'].strip().title(), 
                        f"{agency_responsible_col}_DISTRICT" : ind_candidate['DISTNAME'].strip().title(), 
                        f"{agency_responsible_col}_FIPS_STATE" : int(ind_candidate['FIPS_ST']), f"{agency_responsible_col}_FIPS_COUNTY" : int(ind_candidate['FIPS_COUNTY'])}

    # Otherwise, fill these values up with placeholders
    else:
        match_to_add = {f"{agency_responsible_col}_ORI7" : -1, f"{agency_responsible_col}_ORI9" : -1, 
                        f"{agency_responsible_col}_LEA_TYPE" : "N/A", f"{agency_responsible_col}_LEA_SUBTYPE_1" : "N/A",
                        f"{agency_responsible_col}_LEA_SUBTYPE_2" : "N/A", 
                        f"{agency_responsible_col}_LOCAL_GOVERNMENT_NAME" : "N/A", 
                        f"{agency_responsible_col}_DISTRICT" : "N/A", 
                        f"{agency_responsible_col}_FIPS_STATE" : -1, f"{agency_responsible_col}_FIPS_COUNTY" : -1}
    return match_to_add

# %% [markdown]
# # 4 | Add ORIs to DMFS: Cops

# %% [markdown]
# ### 4.1 | Init Key Variables

# %%
# Adds CSLLEA data placeholders
add_csllea_cols_to_df_cops(df_cops)

USE_PRE_EXISTING_MATCH_DATAFRAME = True
MATCH_DIR = "res/3.0 - Manual ORI Matches/"

# Records any manual corrections / overrides regarding ORI code assignment
manual_corrections_df = pd.DataFrame(columns=["db_name", "agency_responsible_num", "original_LEA_name", "LEA_that_original_was_mapped_onto_for_ORI_code", "LEA_that_original_was_mapped_onto_csllea_index", "ORI7", "ORI9", "Notes"])

# Creates a new dataframe to store manual matches
if USE_PRE_EXISTING_MATCH_DATAFRAME:
    print("Using pre-existing manual match dataframe")
    match_verification_df = pd.read_csv(f"{MATCH_DIR}manual_ori_matches.csv")
else:
    print("Creating new manual match dataframe. You will need to manually confirm any match ambiguities in the for loop.")
    match_verification_df =  pd.DataFrame(columns=["db_name", "agency_responsible_number", #agency_responsible_number is only for df_civ
                                                   "db_index", "csslea_index", "lea_name_db", "lea_name_csllea", "lea_full_name_db", "lea_full_name_csllea", 
                                                   "lea_state_db", "lea_state_csllea",
                                                   "lea_ori_7", "lea_ori_9", "match_verified"])

match_verification_df.head(1)
# Out:
# Using pre-existing manual match dataframe
#          db_name  agency_responsible_number  db_index  csslea_index  \
# 0  dmfs_officers                         -1         5          6466
#
#            lea_name_db      lea_name_csllea                 lea_full_name_db  \
# 0  coeur_dalene_police  couer_dalene_police  Coeur d’Alene Police Department
#
#               lea_full_name_csllea lea_state_db lea_state_csllea lea_ori_7  \
# 0  Couer D'Alene Police Department        Idaho            Idaho   ID02801
#
#    lea_ori_9  match_verified
# 0  ID0280100            True

# %% [markdown]
# ### 4.2 | Main Loop

# %% [markdown]
# Loops through each row of DMFS-Officers. Takes the LEA name of each row and pairs it with the equivlent name in CSLLEA. Finally, once a match is found, import key information from that match into DMFS (e.g., ORI codes, FIPS codes, etc.)

# %%
# DMFS-Officers
for i in range(0, len(df_cops) ) :
    print(f"Processing index {i} out of {len(df_cops)} ({round(i/len(df_cops) * 100, 2)}%)")
    lea_row = df_cops.iloc[i].copy()
    name, full_name, state = lea_row["LEA_NAME_CLEANED"], lea_row["LEA_NAME"], lea_row["LEA_STATE"]


    # *************************************
    # Checks for a match in other DBs
    # *************************************

    # Name & State Match
    ori_candidates = df_ori.query(f"LEA_NAME_CLEANED == '{name}' & STATENAME == '{state}'")# & city_of_death_abr == '{city}'")

    # If no match, then salavage it with a fuzzy search
    if ori_candidates.empty:
        print("Trying fuzzy match for ",name)
        ori_candidates = get_candidate_rows_via_fuzzzy_name_search (df_ori[ (df_ori['STATENAME'] == state) ], "dmfs_officers",)

    # Extracts a match from the candidates
    ind_candidate = initialize_ori_match_from_candidates(ori_candidates, "dmfs_officers")
    
    if ind_candidate is None:
        print(f"No match for {name}")
        continue
        
    match_to_add = initialize_match_to_add_for_dmfs_cops(ind_candidate)
    df_cops.loc[i, match_to_add.keys()] =  match_to_add.values()
# Out:
# Processing index 0 out of 232 (0.0%)
# Processing index 1 out of 232 (0.43%)
# Processing index 2 out of 232 (0.86%)
# Processing index 3 out of 232 (1.29%)
# colorado_state_patrol has multiple candidates 2
# Processing index 4 out of 232 (1.72%)
# Processing index 5 out of 232 (2.16%)
# Trying fuzzy match for  coeur_dalene_police
# Processing index 6 out of 232 (2.59%)
# Processing index 7 out of 232 (3.02%)
# kentucky_state_police has multiple candidates 2
# Processing index 8 out of 232 (3.45%)
# Trying fuzzy match for  us_marshals_service_baton_rouge
# No match for us_marshals_service_baton_rouge
# Processing index 9 out of 232 (3.88%)
# louisiana_state_police has multiple candidates 14
# Processing index 10 out of 232 (4.31%)
# Trying fuzzy match for  housing_authority_new_orleans_police
# No match for housing_authority_new_orleans_police
# Processing index 11 out of 232 (4.74%)
# new_orleans_police has multiple candidates 10
# Processing index 12 out of 232 (5.17%)
# shreveport_police has multiple candidates 149
# Processing index 13 out of 232 (5.6%)
# Processing index 14 out of 232 (6.03%)
# Processing index 15 out of 232 (6.47%)
# omaha_police has multiple candidates 5
# Processing index 16 out of 232 (6.9%)
# Processing index 17 out of 232 (7.33%)
# Processing index 18 out of 232 (7.76%)
# Trying fuzzy match for  navajo_police
# No match for navajo_police
# Processing index 19 out of 232 (8.19%)
# Trying fuzzy match for  rio_rancho_police
# rio_rancho_police has multiple candidates 2
# Processing index 20 out of 232 (8.62%)
# city_new_york_police has multiple candidates 2
# Processing index 21 out of 232 (9.05%)
# city_new_york_police has multiple candidates 2
# Processing index 22 out of 232 (9.48%)
# Processing index 23 out of 232 (9.91%)
# philadelphia_police has multiple candidates 101
# Processing index 24 out of 232 (10.34%)
# Processing index 25 out of 232 (10.78%)
# Trying fuzzy match for  police_puerto_rico
# No match for police_puerto_rico
# Processing index 26 out of 232 (11.21%)
# Trying fuzzy match for  police_puerto_rico
# No match for police_puerto_rico
# Processing index 27 out of 232 (11.64%)
# Processing index 28 out of 232 (12.07%)
# memphis_police has multiple candidates 5
# Processing index 29 out of 232 (12.5%)
# Processing index 30 out of 232 (12.93%)
# Processing index 31 out of 232 (13.36%)
# Processing index 32 out of 232 (13.79%)
# Processing index 33 out of 232 (14.22%)
# Processing index 34 out of 232 (14.66%)
# Processing index 35 out of 232 (15.09%)
# Processing index 36 out of 232 (15.52%)
# phoenix_police has multiple candidates 4
# Processing index 37 out of 232 (15.95%)
# Processing index 38 out of 232 (16.38%)
# Processing index 39 out of 232 (16.81%)
# Processing index 40 out of 232 (17.24%)
# Processing index 41 out of 232 (17.67%)
# Processing index 42 out of 232 (18.1%)
# Processing index 43 out of 232 (18.53%)
# Processing index 44 out of 232 (18.97%)
# Processing index 45 out of 232 (19.4%)
# Processing index 46 out of 232 (19.83%)
# Processing index 47 out of 232 (20.26%)
# Processing index 48 out of 232 (20.69%)
# Processing index 49 out of 232 (21.12%)
# des_moines_police has multiple candidates 2
# Processing index 50 out of 232 (21.55%)
# baton_rouge_police has multiple candidates 6
# Processing index 51 out of 232 (21.98%)
# east_baton_rouge_parish_sheriff has multiple candidates 5
# Processing index 52 out of 232 (22.41%)
# jefferson_parish_sheriff has multiple candidates 11
# Processing index 53 out of 232 (22.84%)
# Processing index 54 out of 232 (23.28%)
# Processing index 55 out of 232 (23.71%)
# Processing index 56 out of 232 (24.14%)
# Processing index 57 out of 232 (24.57%)
# Processing index 58 out of 232 (25.0%)
# st_louis_police has multiple candidates 3
# Uh oh! Multiple parent agencies! Please identify the ORI for [st_louis_police] ([St. Louis County Police Department])
# --> 16786 | St. Louis County Police Dept | st_louis_police | MO09500 | MO0950000
# --> 16934 | St. Louis (City) Police Dept | st_louis_police | MOSPD00 | MOSPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  16786
# Processing index 59 out of 232 (25.43%)
# Processing index 60 out of 232 (25.86%)
# city_new_york_police has multiple candidates 2
# Processing index 61 out of 232 (26.29%)
# Processing index 62 out of 232 (26.72%)
# Processing index 63 out of 232 (27.16%)
# Processing index 64 out of 232 (27.59%)
# Processing index 65 out of 232 (28.02%)
# Processing index 66 out of 232 (28.45%)
# Processing index 67 out of 232 (28.88%)
# pennsylvania_state_police has multiple candidates 28
# Processing index 68 out of 232 (29.31%)
# Processing index 69 out of 232 (29.74%)
# Processing index 70 out of 232 (30.17%)
# Processing index 71 out of 232 (30.6%)
# memphis_police has multiple candidates 5
# Processing index 72 out of 232 (31.03%)
# Processing index 73 out of 232 (31.47%)
# Processing index 74 out of 232 (31.9%)
# Processing index 75 out of 232 (32.33%)
# Processing index 76 out of 232 (32.76%)
# Processing index 77 out of 232 (33.19%)
# Processing index 78 out of 232 (33.62%)
# Processing index 79 out of 232 (34.05%)
# Processing index 80 out of 232 (34.48%)
# Processing index 81 out of 232 (34.91%)
# Processing index 82 out of 232 (35.34%)
# Trying fuzzy match for  navajo_nation_police__window_rock_district
# No match for navajo_nation_police__window_rock_district
# Processing index 83 out of 232 (35.78%)
# Processing index 84 out of 232 (36.21%)
# Processing index 85 out of 232 (36.64%)
# Processing index 86 out of 232 (37.07%)
# Processing index 87 out of 232 (37.5%)
# delaware_state_police has multiple candidates 2
# Processing index 88 out of 232 (37.93%)
# dover_police has multiple candidates 4
# Processing index 89 out of 232 (38.36%)
# Processing index 90 out of 232 (38.79%)
# orlando_police has multiple candidates 2
# Processing index 91 out of 232 (39.22%)
# Processing index 92 out of 232 (39.66%)
# chicago_police has multiple candidates 2
# Processing index 93 out of 232 (40.09%)
# Processing index 94 out of 232 (40.52%)
# Processing index 95 out of 232 (40.95%)
# pottawattamie_sheriff has multiple candidates 2
# Processing index 96 out of 232 (41.38%)
# east_baton_rouge_parish_sheriff has multiple candidates 5
# Processing index 97 out of 232 (41.81%)
# lafayette_police has multiple candidates 3
# Processing index 98 out of 232 (42.24%)
# new_orleans_police has multiple candidates 10
# Processing index 99 out of 232 (42.67%)
# Processing index 100 out of 232 (43.1%)
# Processing index 101 out of 232 (43.53%)
# Processing index 102 out of 232 (43.97%)
# Processing index 103 out of 232 (44.4%)
# las_vegas_police has multiple candidates 18
# Processing index 104 out of 232 (44.83%)
# city_new_york_police has multiple candidates 2
# Processing index 105 out of 232 (45.26%)
# new_york_state_police has multiple candidates 3
# Processing index 106 out of 232 (45.69%)
# Processing index 107 out of 232 (46.12%)
# Processing index 108 out of 232 (46.55%)
# Processing index 109 out of 232 (46.98%)
# Processing index 110 out of 232 (47.41%)
# Processing index 111 out of 232 (47.84%)
# Trying fuzzy match for  police_puerto_rico
# No match for police_puerto_rico
# Processing index 112 out of 232 (48.28%)
# Trying fuzzy match for  puerto_rico
# No match for puerto_rico
# Processing index 113 out of 232 (48.71%)
# harris_constable_precinct_3 has multiple candidates 2
# Uh oh! Multiple parent agencies! Please identify the ORI for [harris_constable_precinct_3] ([Harris County Constable’s Office PCT 3])
# --> 31309 | Harris County Constable Pct. 3 | harris_constable_precinct_3 | -1 | -1
# --> 31315 | Harris County Constables Office Pct 3 | harris_constable_precinct_3 | -1 | TX1014800
# We will go one-by-one. Please select the match you want to use
# Using index  31315
# Processing index 114 out of 232 (49.14%)
# Processing index 115 out of 232 (49.57%)
# Processing index 116 out of 232 (50.0%)
# Processing index 117 out of 232 (50.43%)
# Processing index 118 out of 232 (50.86%)
# Trying fuzzy match for  us_border_patrol
# No match for us_border_patrol
# Processing index 119 out of 232 (51.29%)
# Processing index 120 out of 232 (51.72%)
# Processing index 121 out of 232 (52.16%)
# Processing index 122 out of 232 (52.59%)
# arizona__police has multiple candidates 3
# Processing index 123 out of 232 (53.02%)
# Processing index 124 out of 232 (53.45%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 125 out of 232 (53.88%)
# Processing index 126 out of 232 (54.31%)
# Processing index 127 out of 232 (54.74%)
# Trying fuzzy match for  rancho_cordova_police
# No match for rancho_cordova_police
# Processing index 128 out of 232 (55.17%)
# Processing index 129 out of 232 (55.6%)
# Processing index 130 out of 232 (56.03%)
# Processing index 131 out of 232 (56.47%)
# Processing index 132 out of 232 (56.9%)
# Processing index 133 out of 232 (57.33%)
# Processing index 134 out of 232 (57.76%)
# Processing index 135 out of 232 (58.19%)
# Processing index 136 out of 232 (58.62%)
# Processing index 137 out of 232 (59.05%)
# Processing index 138 out of 232 (59.48%)
# chicago_police has multiple candidates 2
# Processing index 139 out of 232 (59.91%)
# Processing index 140 out of 232 (60.34%)
# terre_haute_police has multiple candidates 2
# Processing index 141 out of 232 (60.78%)
# Processing index 142 out of 232 (61.21%)
# Processing index 143 out of 232 (61.64%)
# Processing index 144 out of 232 (62.07%)
# Processing index 145 out of 232 (62.5%)
# Processing index 146 out of 232 (62.93%)
# Processing index 147 out of 232 (63.36%)
# prince_georges_police has multiple candidates 2
# Processing index 148 out of 232 (63.79%)
# baltimore_police has multiple candidates 4
# Uh oh! Multiple parent agencies! Please identify the ORI for [baltimore_police] ([Baltimore County Police Department])
# --> 12337 | Baltimore County Police Department | baltimore_police | MD00301 | MD0030100
# --> 12586 | Baltimore Police Department | baltimore_police | MDBPD00 | MDBPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  12337
# Processing index 149 out of 232 (64.22%)
# Processing index 150 out of 232 (64.66%)
# Processing index 151 out of 232 (65.09%)
# Processing index 152 out of 232 (65.52%)
# Processing index 153 out of 232 (65.95%)
# Processing index 154 out of 232 (66.38%)
# new_york_state_police has multiple candidates 3
# Processing index 155 out of 232 (66.81%)
# Trying fuzzy match for  north_carolina_highway_patrol
# Processing index 156 out of 232 (67.24%)
# Processing index 157 out of 232 (67.67%)
# Trying fuzzy match for  comanche_district_attorneys
# No match for comanche_district_attorneys
# Processing index 158 out of 232 (68.1%)
# Trying fuzzy match for  juncos_municipal_police
# No match for juncos_municipal_police
# Processing index 159 out of 232 (68.53%)
# Processing index 160 out of 232 (68.97%)
# Processing index 161 out of 232 (69.4%)
# Processing index 162 out of 232 (69.83%)
# Processing index 163 out of 232 (70.26%)
# Processing index 164 out of 232 (70.69%)
# Processing index 165 out of 232 (71.12%)
# pierce_sheriff has multiple candidates 3
# Processing index 166 out of 232 (71.55%)
# milwaukee_police has multiple candidates 2
# Processing index 167 out of 232 (71.98%)
# birmingham_police has multiple candidates 2
# Processing index 168 out of 232 (72.41%)
# Processing index 169 out of 232 (72.84%)
# Processing index 170 out of 232 (73.28%)
# Processing index 171 out of 232 (73.71%)
# Processing index 172 out of 232 (74.14%)
# Processing index 173 out of 232 (74.57%)
# Processing index 174 out of 232 (75.0%)
# Processing index 175 out of 232 (75.43%)
# Processing index 176 out of 232 (75.86%)
# Processing index 177 out of 232 (76.29%)
# Processing index 178 out of 232 (76.72%)
# Processing index 179 out of 232 (77.16%)
# Processing index 180 out of 232 (77.59%)
# richmond_sheriff has multiple candidates 4
# Processing index 181 out of 232 (78.02%)
# Trying fuzzy match for  savannah_police
# No match for savannah_police
# Processing index 182 out of 232 (78.45%)
# Processing index 183 out of 232 (78.88%)
# illinois_state_police has multiple candidates 10
# Processing index 184 out of 232 (79.31%)
# Processing index 185 out of 232 (79.74%)
# mandeville_police has multiple candidates 3
# Processing index 186 out of 232 (80.17%)
# Processing index 187 out of 232 (80.6%)
# Processing index 188 out of 232 (81.03%)
# Trying fuzzy match for  panola_justice_court_constable
# No match for panola_justice_court_constable
# Processing index 189 out of 232 (81.47%)
# Trying fuzzy match for  north_police_cooperative
# No match for north_police_cooperative
# Processing index 190 out of 232 (81.9%)
# Processing index 191 out of 232 (82.33%)
# Processing index 192 out of 232 (82.76%)
# Processing index 193 out of 232 (83.19%)
# Trying fuzzy match for  manati_municipal_police
# No match for manati_municipal_police
# Processing index 194 out of 232 (83.62%)
# Trying fuzzy match for  police_puerto_rico
# No match for police_puerto_rico
# Processing index 195 out of 232 (84.05%)
# Processing index 196 out of 232 (84.48%)
# Processing index 197 out of 232 (84.91%)
# Processing index 198 out of 232 (85.34%)
# Processing index 199 out of 232 (85.78%)
# Processing index 200 out of 232 (86.21%)
# Processing index 201 out of 232 (86.64%)
# Trying fuzzy match for  texas_highway_patrol
# No match for texas_highway_patrol
# Processing index 202 out of 232 (87.07%)
# Processing index 203 out of 232 (87.5%)
# Trying fuzzy match for  us_navy_security_forces
# No match for us_navy_security_forces
# Processing index 204 out of 232 (87.93%)
# Processing index 205 out of 232 (88.36%)
# Processing index 206 out of 232 (88.79%)
# milwaukee_police has multiple candidates 2
# Processing index 207 out of 232 (89.22%)
# Processing index 208 out of 232 (89.66%)
# phoenix_police has multiple candidates 4
# Processing index 209 out of 232 (90.09%)
# Processing index 210 out of 232 (90.52%)
# Trying fuzzy match for  helena_west_helena_police
# Processing index 211 out of 232 (90.95%)
# Processing index 212 out of 232 (91.38%)
# Processing index 213 out of 232 (91.81%)
# florida_highway_patrol has multiple candidates 2
# Processing index 214 out of 232 (92.24%)
# Processing index 215 out of 232 (92.67%)
# indianapolis_police has multiple candidates 2
# Processing index 216 out of 232 (93.1%)
# Processing index 217 out of 232 (93.53%)
# Processing index 218 out of 232 (93.97%)
# Processing index 219 out of 232 (94.4%)
# Processing index 220 out of 232 (94.83%)
# Processing index 221 out of 232 (95.26%)
# Processing index 222 out of 232 (95.69%)
# Processing index 223 out of 232 (96.12%)
# Processing index 224 out of 232 (96.55%)
# philadelphia_police has multiple candidates 101
# Processing index 225 out of 232 (96.98%)
# Processing index 226 out of 232 (97.41%)
# Processing index 227 out of 232 (97.84%)
# Processing index 228 out of 232 (98.28%)
# Trying fuzzy match for  houston_fire
# No match for houston_fire
# Processing index 229 out of 232 (98.71%)
# Processing index 230 out of 232 (99.14%)
# Processing index 231 out of 232 (99.57%)

# %% [markdown]
# ### 4.3 | Apply Manual Corrections to Missed ORIs

# %%
# Contains dmfs_index : [csllea_index, notes] mapping
manual_corrections = {
    10 : [11692, "Housing Authority of New Orleans Police mapped onto New Orleans Police (generic) because former does not have ORI code"],
    127 : [2366, "Manually located Ranco Corvo PD"],
    181 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    189 : [16776, "North County Police Co-Op doesn't have an ORI code. However, it is located in Vinita Terrace, and there's a \"Vinita Terrace PD\" listed on the website of \"North County Police Co-Op\". Thus, we used the ORI of Vinita Terrace"],
    201 : [32807, "Mapped Texas Highway Patrol onto its headquarters rather than a satellite location."],
}

# %%
# Loops thorugh ORIs with missing data & corrects them

missed_LEAs = df_cops.query(f"ORI7.isnull()")
print(f"There are {df_cops.shape[0]} LEAs, of which {missed_LEAs.shape[0]} have a missing ORI ({ round(missed_LEAs.shape[0] / df_cops.shape[0] * 100, 2)}% of total).")
print(f"Applying {len(manual_corrections.keys())} manual corrections to the {missed_LEAs.shape[0]} agencies with missing ORIs, thereby remedying {round(len(manual_corrections.keys()) / missed_LEAs.shape[0] * 100, 2)}% of missing ORIs")

for index, ind_LEA in missed_LEAs.iterrows():
    
    # Applies manual correctioon, if it exists
    if index in manual_corrections.keys():
        ori_index = manual_corrections[index][0]
        match_to_add = initialize_match_to_add_for_dmfs_cops( df_ori.loc[ ori_index ] ) # Adds to DM-FS
        record_manual_match("dmfs_officers", "N/A", ind_LEA["LEA_NAME"], df_ori.loc[ori_index, "LEA_NAME"].strip().title(), 
                            ori_index, df_ori.loc[ori_index, "ORI7"], df_ori.loc[ori_index, "ORI9"], manual_corrections[index][1]) # Records manual match for replication

    # Else, just create a bunch of blank/NA cells to add
    else:
        match_to_add = initialize_match_to_add_for_dmfs_cops( pd.Series() )
        record_manual_match("dmfs_officers", "N/A", ind_LEA["LEA_NAME"], "No Match Found", -1, -1, -1, notes="")
        
    # Adds data to DM-FS
    df_cops.loc[index, match_to_add.keys()] =  match_to_add.values()
# Out:
# There are 232 LEAs, of which 21 have a missing ORI (9.05% of total).
# Applying 5 manual corrections to the 21 agencies with missing ORIs, thereby remedying 23.81% of missing ORIs

# %% [markdown]
# ### 4.4 |  Exports

# %%
# Exports Manual Match Dataframe, the one that records all our manual matches (if appliable)
if not USE_PRE_EXISTING_MATCH_DATAFRAME:
    print(f"Saving manual ORI matches to dir [{MATCH_DIR}] so that the manual matches can be replicated in a future run.")
    match_verification_df.to_csv(f"{MATCH_DIR}manual_ori_matches.csv", index = False)
else:
    print("Used pre-existing manual match dataframe. That dataframe was not modified in any way, hence, no saving is necessary.\nNo action is needed. Please proceed.")
# Out:
# Used pre-existing manual match dataframe. That dataframe was not modified in any way, hence, no saving is necessary.
# No action is needed. Please proceed.

# %%
# Also exports any manual corrections we've made
print(f"Exporting manual corrections to [{MATCH_DIR}]")
manual_corrections_df.to_csv(f"{MATCH_DIR}manual_ori_corrections.csv", index = False)
# Out:
# Exporting manual corrections to [res/3.0 - Manual ORI Matches/]

# %%
# Exports DMFS-Officers
EXPORT_DIR = "res/3.1 - Penultimate Databases/"
if not os.path.exists(EXPORT_DIR):
    os.makedirs(EXPORT_DIR)
    
df_cops.drop(columns=["LEA_NAME_CLEANED"], inplace=True)
df_cops.to_csv(f"{EXPORT_DIR}DMFS Officers.csv", index=False)

# %% [markdown]
# # 5 | Add ORI to DMFS-Civilians

# %% [markdown]
# ### 5.1 | Pre Loop Corrections

# %% [markdown]
# While applying manual corrections, we discovered some rows that had a mistake like an erroneous LEA attribution or a mistaken state of death. Our earlier steps didn't detect these issues because, in these cases, two/three databases actually AGREED on the erroneous bit of information. If all 3 databases, for example, claimed that John Doe was killed by Chicago Police when in actuality, he was killed by Illinois State Police, there was no reason to flag it because we assumed that, if all 3 databases agree, the information is generally reliable.
#
# Unfortunately, there were a few rare cases where that assumption didn't pan out, and these are corrected below, before the ORIs are assigned in the main loop.

# %%
# Corrects an issue of LEA Attribution discovered while correcting these manual discrepancies.
# In other words, all 3 databases claim some Georgia sheriff's department fatally shot 2 civillians in Maine.
# This is wrong: it was Maine State Troopers and the local LEA. The below code fixes that. See https://fox23maine.com/news/local/report-state-police-justified-in-controversial-shooting-of-man-woman-in-vassalboro
df_civ.loc[4345, ["agency_responsible_1", "agency_responsible_2"]] = ["Maine State Police", "Vassalboro Police",]
df_civ.loc[4351, ["agency_responsible_1", "agency_responsible_2"]] = ["Maine State Police", "Vassalboro Police",]


# Other Mistakes
df_civ.loc[1291, "state_of_death"] = "Kansas" # Claims Pittsburg was in MO when, in actuality, it's in Kansas.
df_civ.loc[1291, "state_of_death_abr"] = "KS"
df_civ.loc[303, "state_of_death"] = "Florida" # Article confirms victim perished in Florida, not Tennessee.
df_civ.loc[303, "state_of_death_abr"] = "FL"
df_civ.loc[1171, "state_of_death"] = "Alabama" # Mobile police is located in Alabama, not Arkansas.
df_civ.loc[1171, "state_of_death_abr"] = "AL"
df_civ.loc[3080, "agency_responsible_1"] = "Corpus Christi Police Department" #DBs list just "Corpus Christi", which has a marshal, sheriff, etc. Article confirms it's the PD
df_civ.loc[2045, "agency_responsible_1"] = "Hertford County Sheriff's Office" # DBs originally said "Hertford County Chief Deputy Will Liverman" was agency responsible
df_civ.loc[5376, "agency_responsible_1"] = "Harris County Constable Precinct 6" # Changes entry from "Harris COunty Constable" to the specific precinct that fatally shot the man.

# %% [markdown]
# ### 5.2 | Init Key Variables

# %%
# Adds ORI cols to dmfs-civ
add_csllea_cols_to_df_civs(df_civ)

# %% [markdown]
# ### 5.3 | Main Loop

# %% [markdown]
# Similar to §4.2, the main loop goes row-by-row in DM-FS. Namely, it extracts (i) LEA name and (ii) state-of-death from DM-FS. It then pairs it with the equivlent LEA in the Crosswalk file (CSLLEA) to extract its LEA.
#
# If an LEA name cannot be found, the name is salvaged via a fuzzy search, and the user needs to confirm the fuzzy match is valid before proceeding. All fuzzy match decisions are recorded in the "3.0 - Manual ORI Matches" directory  by default, under 'manual_ori_matches.csv'.
#
# If multiple LEA names are returned, then it asks the user to select the LEA responsible, and the user's decisions are recorded in the aforementioned CSV file. This was most common when there were two LEAs with extremely similar names but served different purposes, e.g., "Baltimore Police" vs. "Baltimore County Polcie"

# %%
# Goes one agency at a time: agency_responsible_1, agency_responsible_2 [...], agency_responsible 5
for agency_responsible_num in range(1,6):
    
    agency_responsible_col = f"agency_responsible_{agency_responsible_num}"
    print(f"\n{'*'*80}\nMATCHING AGENCIES IN [{agency_responsible_col}] WITH AN ORI\n{'*'*80}\n")

    # Goes one-by-one, pairing each agency in DMFS-Civs with its ORI in the Crosswalk file
    for i in range(0, len(df_civ) ) :
    
    
        lea_row = df_civ.iloc[i].copy()
        name, full_name, state = lea_row[f"{agency_responsible_col}_CLEANED"], lea_row[agency_responsible_col], lea_row["state_of_death"]

        # Checks for empty values. If so, it doesn't print out anything & just continues with the loop
        if name == "":
            df_civ.loc[i, agency_responsible_col] = "N/A"
            continue
        else:
            print(f"Processing index {i} out of {len(df_civ)} ({round(i/len(df_civ) * 100, 2)}%)")

        # *************************************
        # Checks for a match in Crosswalk file
        # *************************************

        # Name & State Match
        ori_candidates = df_ori.query(f"LEA_NAME_CLEANED == '{name}' & STATENAME == '{state}'")

        # If no match, then salavage it with a fuzzy search
        if ori_candidates.empty:
            print("Trying fuzzy match for ",name)
            ori_candidates = get_candidate_rows_via_fuzzzy_name_search (df_ori[ (df_ori['STATENAME'] == state) ], "dmfs_civilians", agency_responsible_num)
    
        # Extracts a match from the candidates
        ind_candidate = initialize_ori_match_from_candidates(ori_candidates, "dmfs_civilians", agency_responsible_num)
    
        if ind_candidate is None:
            print(f"No match for {name}")
            continue

        match_to_add = initialize_match_to_add_for_dmfs_civs(ind_candidate, agency_responsible_col)
        df_civ.loc[i, match_to_add.keys()] =  match_to_add.values()
# Out:
# ********************************************************************************
# MATCHING AGENCIES IN [agency_responsible_1] WITH AN ORI
# ********************************************************************************
#
# Processing index 0 out of 7105 (0.0%)
# Processing index 1 out of 7105 (0.01%)
# miami_police has multiple candidates 2
# Processing index 2 out of 7105 (0.03%)
# pennsylvania_state_police has multiple candidates 28
# Processing index 3 out of 7105 (0.04%)
# Processing index 4 out of 7105 (0.06%)
# minneapolis_police has multiple candidates 3
# Processing index 5 out of 7105 (0.07%)
# Processing index 6 out of 7105 (0.08%)
# Processing index 7 out of 7105 (0.1%)
# Processing index 8 out of 7105 (0.11%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 9 out of 7105 (0.13%)
# Processing index 10 out of 7105 (0.14%)
# city_new_york_police has multiple candidates 2
# Processing index 11 out of 7105 (0.15%)
# Processing index 12 out of 7105 (0.17%)
# Processing index 13 out of 7105 (0.18%)
# Processing index 14 out of 7105 (0.2%)
# Processing index 15 out of 7105 (0.21%)
# Processing index 16 out of 7105 (0.23%)
# phoenix_police has multiple candidates 4
# Processing index 17 out of 7105 (0.24%)
# phoenix_police has multiple candidates 4
# Processing index 18 out of 7105 (0.25%)
# Processing index 19 out of 7105 (0.27%)
# Processing index 20 out of 7105 (0.28%)
# Processing index 21 out of 7105 (0.3%)
# Processing index 22 out of 7105 (0.31%)
# Trying fuzzy match for  georgia__corrections
# No match for georgia__corrections
# Processing index 23 out of 7105 (0.32%)
# Processing index 24 out of 7105 (0.34%)
# Processing index 25 out of 7105 (0.35%)
# philadelphia_police has multiple candidates 101
# Processing index 26 out of 7105 (0.37%)
# philadelphia_police has multiple candidates 101
# Processing index 27 out of 7105 (0.38%)
# Processing index 28 out of 7105 (0.39%)
# Processing index 29 out of 7105 (0.41%)
# Processing index 30 out of 7105 (0.42%)
# Processing index 31 out of 7105 (0.44%)
# Processing index 32 out of 7105 (0.45%)
# Processing index 33 out of 7105 (0.46%)
# Processing index 34 out of 7105 (0.48%)
# Processing index 35 out of 7105 (0.49%)
# Processing index 36 out of 7105 (0.51%)
# Processing index 37 out of 7105 (0.52%)
# anchorage_police has multiple candidates 2
# Processing index 38 out of 7105 (0.53%)
# Processing index 39 out of 7105 (0.55%)
# Processing index 40 out of 7105 (0.56%)
# chicago_police has multiple candidates 2
# Processing index 41 out of 7105 (0.58%)
# Processing index 42 out of 7105 (0.59%)
# Processing index 43 out of 7105 (0.61%)
# Processing index 44 out of 7105 (0.62%)
# Processing index 45 out of 7105 (0.63%)
# Processing index 46 out of 7105 (0.65%)
# cobb_sheriff has multiple candidates 2
# Processing index 47 out of 7105 (0.66%)
# sevierville_police has multiple candidates 2
# Processing index 48 out of 7105 (0.68%)
# Processing index 49 out of 7105 (0.69%)
# orlando_police has multiple candidates 2
# Processing index 50 out of 7105 (0.7%)
# Trying fuzzy match for  us_customs_and_border_protection
# No match for us_customs_and_border_protection
# Processing index 51 out of 7105 (0.72%)
# Processing index 52 out of 7105 (0.73%)
# Processing index 53 out of 7105 (0.75%)
# Processing index 54 out of 7105 (0.76%)
# Processing index 55 out of 7105 (0.77%)
# Processing index 56 out of 7105 (0.79%)
# Processing index 57 out of 7105 (0.8%)
# city_new_york_police has multiple candidates 2
# Processing index 58 out of 7105 (0.82%)
# Processing index 59 out of 7105 (0.83%)
# Processing index 60 out of 7105 (0.84%)
# oklahoma_city_police has multiple candidates 8
# Processing index 61 out of 7105 (0.86%)
# Processing index 62 out of 7105 (0.87%)
# Processing index 63 out of 7105 (0.89%)
# Processing index 64 out of 7105 (0.9%)
# Processing index 65 out of 7105 (0.91%)
# Processing index 66 out of 7105 (0.93%)
# Processing index 67 out of 7105 (0.94%)
# Processing index 68 out of 7105 (0.96%)
# Processing index 69 out of 7105 (0.97%)
# Processing index 70 out of 7105 (0.99%)
# Processing index 71 out of 7105 (1.0%)
# Processing index 72 out of 7105 (1.01%)
# Processing index 73 out of 7105 (1.03%)
# chicago_police has multiple candidates 2
# Processing index 74 out of 7105 (1.04%)
# Processing index 75 out of 7105 (1.06%)
# hills_sheriff has multiple candidates 3
# Processing index 76 out of 7105 (1.07%)
# las_vegas_police has multiple candidates 18
# Processing index 77 out of 7105 (1.08%)
# oregon_state_police has multiple candidates 7
# Processing index 78 out of 7105 (1.1%)
# Processing index 79 out of 7105 (1.11%)
# michigan_state_police has multiple candidates 8
# Processing index 80 out of 7105 (1.13%)
# Processing index 81 out of 7105 (1.14%)
# Processing index 82 out of 7105 (1.15%)
# Processing index 83 out of 7105 (1.17%)
# st_louis_police has multiple candidates 3
# Uh oh! Multiple parent agencies! Please identify the ORI for [st_louis_police] ([St. Louis Metropolitan Police Department])
# --> 16786 | St. Louis County Police Dept | st_louis_police | MO09500 | MO0950000
# --> 16934 | St. Louis (City) Police Dept | st_louis_police | MOSPD00 | MOSPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  16934
# Processing index 84 out of 7105 (1.18%)
# Processing index 85 out of 7105 (1.2%)
# Processing index 86 out of 7105 (1.21%)
# Processing index 87 out of 7105 (1.22%)
# Trying fuzzy match for  savannah_police
# No match for savannah_police
# Processing index 88 out of 7105 (1.24%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 89 out of 7105 (1.25%)
# Processing index 90 out of 7105 (1.27%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 91 out of 7105 (1.28%)
# Trying fuzzy match for  spokane_detention_services
# No match for spokane_detention_services
# Processing index 92 out of 7105 (1.29%)
# west_virginia_state_police has multiple candidates 18
# Processing index 93 out of 7105 (1.31%)
# Processing index 94 out of 7105 (1.32%)
# Processing index 95 out of 7105 (1.34%)
# phoenix_police has multiple candidates 4
# Processing index 96 out of 7105 (1.35%)
# Processing index 97 out of 7105 (1.37%)
# st_petersburg_police has multiple candidates 2
# Processing index 98 out of 7105 (1.38%)
# Processing index 99 out of 7105 (1.39%)
# Trying fuzzy match for  us_investigation
# No match for us_investigation
# Processing index 100 out of 7105 (1.41%)
# phoenix_police has multiple candidates 4
# Processing index 101 out of 7105 (1.42%)
# Processing index 102 out of 7105 (1.44%)
# Processing index 103 out of 7105 (1.45%)
# Processing index 104 out of 7105 (1.46%)
# Processing index 105 out of 7105 (1.48%)
# Processing index 106 out of 7105 (1.49%)
# Processing index 107 out of 7105 (1.51%)
# philadelphia_police has multiple candidates 101
# Processing index 108 out of 7105 (1.52%)
# Processing index 109 out of 7105 (1.53%)
# Processing index 110 out of 7105 (1.55%)
# Processing index 111 out of 7105 (1.56%)
# Processing index 112 out of 7105 (1.58%)
# Processing index 113 out of 7105 (1.59%)
# city_new_york_police has multiple candidates 2
# Processing index 114 out of 7105 (1.6%)
# miami_police has multiple candidates 2
# Processing index 115 out of 7105 (1.62%)
# oklahoma_city_police has multiple candidates 8
# Processing index 116 out of 7105 (1.63%)
# Processing index 117 out of 7105 (1.65%)
# Processing index 118 out of 7105 (1.66%)
# Processing index 119 out of 7105 (1.67%)
# Processing index 120 out of 7105 (1.69%)
# spokane_sheriff has multiple candidates 2
# Processing index 121 out of 7105 (1.7%)
# Processing index 122 out of 7105 (1.72%)
# Processing index 123 out of 7105 (1.73%)
# volusia_sheriff has multiple candidates 2
# Processing index 124 out of 7105 (1.75%)
# Processing index 125 out of 7105 (1.76%)
# Trying fuzzy match for  upper_darby_police
# No match for upper_darby_police
# Processing index 126 out of 7105 (1.77%)
# Processing index 127 out of 7105 (1.79%)
# Processing index 128 out of 7105 (1.8%)
# omaha_police has multiple candidates 5
# Processing index 129 out of 7105 (1.82%)
# oklahoma_city_police has multiple candidates 8
# Processing index 130 out of 7105 (1.83%)
# new_mexico_state_police has multiple candidates 2
# Processing index 131 out of 7105 (1.84%)
# Trying fuzzy match for  tyler_junior_college_police
# Processing index 132 out of 7105 (1.86%)
# Processing index 133 out of 7105 (1.87%)
# kentucky_state_police has multiple candidates 2
# Processing index 134 out of 7105 (1.89%)
# Trying fuzzy match for  la_vergne_police
# Processing index 135 out of 7105 (1.9%)
# miami_dade_police has multiple candidates 5
# Processing index 136 out of 7105 (1.91%)
# montgomery_police has multiple candidates 3
# Processing index 137 out of 7105 (1.93%)
# greensboro_police has multiple candidates 2
# Processing index 138 out of 7105 (1.94%)
# Trying fuzzy match for  indiana_state_police_emergency_response_team
# No match for indiana_state_police_emergency_response_team
# Processing index 139 out of 7105 (1.96%)
# broward_sheriff has multiple candidates 3
# Processing index 140 out of 7105 (1.97%)
# Processing index 141 out of 7105 (1.98%)
# atlanta_police has multiple candidates 4
# Processing index 142 out of 7105 (2.0%)
# Processing index 143 out of 7105 (2.01%)
# Processing index 144 out of 7105 (2.03%)
# Processing index 145 out of 7105 (2.04%)
# Processing index 146 out of 7105 (2.05%)
# Processing index 147 out of 7105 (2.07%)
# Processing index 148 out of 7105 (2.08%)
# Trying fuzzy match for  cuyahoga_housing_authority
# Processing index 149 out of 7105 (2.1%)
# Processing index 150 out of 7105 (2.11%)
# Processing index 151 out of 7105 (2.13%)
# Processing index 152 out of 7105 (2.14%)
# Processing index 153 out of 7105 (2.15%)
# Processing index 154 out of 7105 (2.17%)
# Processing index 155 out of 7105 (2.18%)
# philadelphia_police has multiple candidates 101
# Processing index 156 out of 7105 (2.2%)
# oklahoma_city_police has multiple candidates 8
# Processing index 157 out of 7105 (2.21%)
# scottsdale_police has multiple candidates 2
# Processing index 158 out of 7105 (2.22%)
# Processing index 159 out of 7105 (2.24%)
# Processing index 160 out of 7105 (2.25%)
# Processing index 161 out of 7105 (2.27%)
# Processing index 162 out of 7105 (2.28%)
# Processing index 163 out of 7105 (2.29%)
# Trying fuzzy match for  navajo_nation_police
# No match for navajo_nation_police
# Processing index 164 out of 7105 (2.31%)
# prince_georges_police has multiple candidates 2
# Processing index 165 out of 7105 (2.32%)
# prince_georges_police has multiple candidates 2
# Processing index 166 out of 7105 (2.34%)
# Processing index 167 out of 7105 (2.35%)
# baltimore_police has multiple candidates 4
# Uh oh! Multiple parent agencies! Please identify the ORI for [baltimore_police] ([Baltimore Police Department])
# --> 12337 | Baltimore County Police Department | baltimore_police | MD00301 | MD0030100
# --> 12586 | Baltimore Police Department | baltimore_police | MDBPD00 | MDBPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  12586
# Processing index 168 out of 7105 (2.36%)
# king_sheriff has multiple candidates 6
# Processing index 169 out of 7105 (2.38%)
# Processing index 170 out of 7105 (2.39%)
# Processing index 171 out of 7105 (2.41%)
# Processing index 172 out of 7105 (2.42%)
# Processing index 173 out of 7105 (2.43%)
# Processing index 174 out of 7105 (2.45%)
# Processing index 175 out of 7105 (2.46%)
# Processing index 176 out of 7105 (2.48%)
# Processing index 177 out of 7105 (2.49%)
# Processing index 178 out of 7105 (2.51%)
# atlanta_police has multiple candidates 4
# Processing index 179 out of 7105 (2.52%)
# atlanta_police has multiple candidates 4
# Processing index 180 out of 7105 (2.53%)
# tulsa_police has multiple candidates 4
# Processing index 181 out of 7105 (2.55%)
# Processing index 182 out of 7105 (2.56%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 183 out of 7105 (2.58%)
# Processing index 184 out of 7105 (2.59%)
# Processing index 185 out of 7105 (2.6%)
# Processing index 186 out of 7105 (2.62%)
# Processing index 187 out of 7105 (2.63%)
# Processing index 188 out of 7105 (2.65%)
# Processing index 189 out of 7105 (2.66%)
# Processing index 190 out of 7105 (2.67%)
# Processing index 191 out of 7105 (2.69%)
# henderson_police has multiple candidates 5
# Processing index 192 out of 7105 (2.7%)
# Processing index 193 out of 7105 (2.72%)
# Processing index 194 out of 7105 (2.73%)
# henderson_police has multiple candidates 5
# Processing index 195 out of 7105 (2.74%)
# Processing index 196 out of 7105 (2.76%)
# Trying fuzzy match for  drug_enforcement_administration
# No match for drug_enforcement_administration
# Processing index 197 out of 7105 (2.77%)
# Processing index 198 out of 7105 (2.79%)
# Processing index 199 out of 7105 (2.8%)
# Processing index 200 out of 7105 (2.81%)
# pierce_sheriff has multiple candidates 3
# Processing index 201 out of 7105 (2.83%)
# Trying fuzzy match for  cherokee_nation_marshal_service
# Processing index 202 out of 7105 (2.84%)
# Processing index 203 out of 7105 (2.86%)
# Processing index 204 out of 7105 (2.87%)
# chattanooga_police has multiple candidates 5
# Processing index 205 out of 7105 (2.89%)
# Processing index 206 out of 7105 (2.9%)
# Processing index 207 out of 7105 (2.91%)
# clark_sheriff has multiple candidates 2
# Processing index 208 out of 7105 (2.93%)
# Processing index 209 out of 7105 (2.94%)
# Processing index 210 out of 7105 (2.96%)
# tucson_police has multiple candidates 2
# Processing index 211 out of 7105 (2.97%)
# Processing index 212 out of 7105 (2.98%)
# chattanooga_police has multiple candidates 5
# Processing index 213 out of 7105 (3.0%)
# Processing index 214 out of 7105 (3.01%)
# las_vegas_police has multiple candidates 18
# Processing index 215 out of 7105 (3.03%)
# palm_beach_sheriff has multiple candidates 3
# Processing index 216 out of 7105 (3.04%)
# Processing index 217 out of 7105 (3.05%)
# Processing index 218 out of 7105 (3.07%)
# philadelphia_police has multiple candidates 101
# Processing index 219 out of 7105 (3.08%)
# phoenix_police has multiple candidates 4
# Processing index 220 out of 7105 (3.1%)
# Processing index 221 out of 7105 (3.11%)
# Processing index 222 out of 7105 (3.12%)
# Processing index 223 out of 7105 (3.14%)
# Trying fuzzy match for  missouri_highway_patrol
# Processing index 224 out of 7105 (3.15%)
# Processing index 225 out of 7105 (3.17%)
# Trying fuzzy match for  us_border_patrol
# No match for us_border_patrol
# Processing index 226 out of 7105 (3.18%)
# Processing index 227 out of 7105 (3.19%)
# Processing index 228 out of 7105 (3.21%)
# Processing index 229 out of 7105 (3.22%)
# chicago_police has multiple candidates 2
# Processing index 230 out of 7105 (3.24%)
# Processing index 231 out of 7105 (3.25%)
# Processing index 232 out of 7105 (3.27%)
# anchorage_police has multiple candidates 2
# Processing index 233 out of 7105 (3.28%)
# Processing index 234 out of 7105 (3.29%)
# Processing index 235 out of 7105 (3.31%)
# Processing index 236 out of 7105 (3.32%)
# Processing index 237 out of 7105 (3.34%)
# Processing index 238 out of 7105 (3.35%)
# manatee_sheriff has multiple candidates 2
# Processing index 239 out of 7105 (3.36%)
# tampa_police has multiple candidates 2
# Processing index 240 out of 7105 (3.38%)
# phoenix_police has multiple candidates 4
# Processing index 241 out of 7105 (3.39%)
# phoenix_police has multiple candidates 4
# Processing index 242 out of 7105 (3.41%)
# Processing index 243 out of 7105 (3.42%)
# Processing index 244 out of 7105 (3.43%)
# Processing index 245 out of 7105 (3.45%)
# Trying fuzzy match for  pennsylvania_state_police
# No match for pennsylvania_state_police
# Processing index 246 out of 7105 (3.46%)
# Processing index 247 out of 7105 (3.48%)
# pennsylvania_state_police has multiple candidates 28
# Processing index 248 out of 7105 (3.49%)
# Processing index 249 out of 7105 (3.5%)
# Processing index 250 out of 7105 (3.52%)
# Processing index 251 out of 7105 (3.53%)
# Trying fuzzy match for  georgia_state_patrol
# No match for georgia_state_patrol
# Processing index 252 out of 7105 (3.55%)
# Processing index 253 out of 7105 (3.56%)
# Trying fuzzy match for  tooele_police
# Processing index 254 out of 7105 (3.57%)
# Processing index 255 out of 7105 (3.59%)
# Processing index 256 out of 7105 (3.6%)
# kentucky_state_police has multiple candidates 2
# Processing index 257 out of 7105 (3.62%)
# Processing index 258 out of 7105 (3.63%)
# Processing index 259 out of 7105 (3.65%)
# new_mexico_state_police has multiple candidates 2
# Processing index 260 out of 7105 (3.66%)
# Processing index 261 out of 7105 (3.67%)
# Processing index 262 out of 7105 (3.69%)
# Processing index 263 out of 7105 (3.7%)
# Processing index 264 out of 7105 (3.72%)
# pennsylvania_state_police has multiple candidates 28
# Processing index 265 out of 7105 (3.73%)
# Processing index 266 out of 7105 (3.74%)
# Processing index 267 out of 7105 (3.76%)
# Processing index 268 out of 7105 (3.77%)
# Processing index 269 out of 7105 (3.79%)
# Processing index 270 out of 7105 (3.8%)
# Processing index 271 out of 7105 (3.81%)
# Processing index 272 out of 7105 (3.83%)
# polk_sheriff has multiple candidates 2
# Processing index 273 out of 7105 (3.84%)
# Processing index 274 out of 7105 (3.86%)
# Processing index 275 out of 7105 (3.87%)
# Processing index 276 out of 7105 (3.88%)
# Processing index 277 out of 7105 (3.9%)
# billings_police has multiple candidates 3
# Processing index 278 out of 7105 (3.91%)
# Processing index 279 out of 7105 (3.93%)
# Processing index 280 out of 7105 (3.94%)
# san_francisco_police has multiple candidates 2
# Processing index 281 out of 7105 (3.95%)
# Processing index 282 out of 7105 (3.97%)
# Processing index 283 out of 7105 (3.98%)
# Processing index 284 out of 7105 (4.0%)
# Processing index 285 out of 7105 (4.01%)
# Processing index 286 out of 7105 (4.03%)
# city_new_york_police has multiple candidates 2
# Processing index 287 out of 7105 (4.04%)
# Processing index 288 out of 7105 (4.05%)
# illinois_state_police has multiple candidates 10
# Processing index 289 out of 7105 (4.07%)
# Processing index 290 out of 7105 (4.08%)
# Processing index 291 out of 7105 (4.1%)
# Processing index 292 out of 7105 (4.11%)
# Processing index 293 out of 7105 (4.12%)
# Processing index 294 out of 7105 (4.14%)
# Processing index 295 out of 7105 (4.15%)
# Processing index 296 out of 7105 (4.17%)
# Processing index 297 out of 7105 (4.18%)
# Processing index 298 out of 7105 (4.19%)
# Processing index 299 out of 7105 (4.21%)
# philadelphia_police has multiple candidates 101
# Processing index 300 out of 7105 (4.22%)
# Processing index 301 out of 7105 (4.24%)
# Processing index 302 out of 7105 (4.25%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 303 out of 7105 (4.26%)
# Processing index 304 out of 7105 (4.28%)
# Processing index 305 out of 7105 (4.29%)
# Processing index 306 out of 7105 (4.31%)
# Processing index 307 out of 7105 (4.32%)
# Processing index 308 out of 7105 (4.33%)
# Processing index 309 out of 7105 (4.35%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 310 out of 7105 (4.36%)
# Processing index 311 out of 7105 (4.38%)
# Processing index 312 out of 7105 (4.39%)
# Processing index 313 out of 7105 (4.41%)
# jefferson_parish_sheriff has multiple candidates 11
# Processing index 314 out of 7105 (4.42%)
# Processing index 315 out of 7105 (4.43%)
# Processing index 316 out of 7105 (4.45%)
# jefferson_parish_sheriff has multiple candidates 11
# Processing index 317 out of 7105 (4.46%)
# Processing index 318 out of 7105 (4.48%)
# Processing index 319 out of 7105 (4.49%)
# mesa_police has multiple candidates 2
# Processing index 320 out of 7105 (4.5%)
# milwaukee_police has multiple candidates 2
# Processing index 321 out of 7105 (4.52%)
# Processing index 322 out of 7105 (4.53%)
# spokane_police has multiple candidates 2
# Processing index 323 out of 7105 (4.55%)
# Trying fuzzy match for  lasalle_parish_sheriff
# Processing index 324 out of 7105 (4.56%)
# Processing index 325 out of 7105 (4.57%)
# Processing index 326 out of 7105 (4.59%)
# Processing index 327 out of 7105 (4.6%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 328 out of 7105 (4.62%)
# atlanta_police has multiple candidates 4
# Processing index 329 out of 7105 (4.63%)
# Processing index 330 out of 7105 (4.64%)
# Trying fuzzy match for  border_patrol
# No match for border_patrol
# Processing index 331 out of 7105 (4.66%)
# st_louis_police has multiple candidates 3
# Uh oh! Multiple parent agencies! Please identify the ORI for [st_louis_police] ([St. Louis County Police Department])
# --> 16786 | St. Louis County Police Dept | st_louis_police | MO09500 | MO0950000
# --> 16934 | St. Louis (City) Police Dept | st_louis_police | MOSPD00 | MOSPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  16786
# Processing index 332 out of 7105 (4.67%)
# Processing index 333 out of 7105 (4.69%)
# brunswick_police has multiple candidates 2
# Processing index 334 out of 7105 (4.7%)
# Processing index 335 out of 7105 (4.71%)
# king_sheriff has multiple candidates 6
# Processing index 336 out of 7105 (4.73%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 337 out of 7105 (4.74%)
# Processing index 338 out of 7105 (4.76%)
# Processing index 339 out of 7105 (4.77%)
# Processing index 340 out of 7105 (4.79%)
# Processing index 341 out of 7105 (4.8%)
# Processing index 342 out of 7105 (4.81%)
# Processing index 343 out of 7105 (4.83%)
# collier_sheriff has multiple candidates 2
# Processing index 344 out of 7105 (4.84%)
# Processing index 345 out of 7105 (4.86%)
# Processing index 346 out of 7105 (4.87%)
# Processing index 347 out of 7105 (4.88%)
# Processing index 348 out of 7105 (4.9%)
# Processing index 349 out of 7105 (4.91%)
# Trying fuzzy match for  lancaster_city_police
# Processing index 350 out of 7105 (4.93%)
# Processing index 351 out of 7105 (4.94%)
# Processing index 352 out of 7105 (4.95%)
# Processing index 353 out of 7105 (4.97%)
# spokane_police has multiple candidates 2
# Processing index 354 out of 7105 (4.98%)
# fayetteville_police has multiple candidates 2
# Processing index 355 out of 7105 (5.0%)
# Processing index 356 out of 7105 (5.01%)
# Processing index 357 out of 7105 (5.02%)
# Processing index 358 out of 7105 (5.04%)
# Processing index 359 out of 7105 (5.05%)
# Processing index 360 out of 7105 (5.07%)
# Processing index 361 out of 7105 (5.08%)
# las_vegas_police has multiple candidates 18
# Processing index 362 out of 7105 (5.1%)
# florida_highway_patrol has multiple candidates 2
# Processing index 363 out of 7105 (5.11%)
# san_francisco_police has multiple candidates 2
# Processing index 364 out of 7105 (5.12%)
# Processing index 365 out of 7105 (5.14%)
# Processing index 366 out of 7105 (5.15%)
# las_vegas_police has multiple candidates 18
# Processing index 367 out of 7105 (5.17%)
# Processing index 368 out of 7105 (5.18%)
# Processing index 369 out of 7105 (5.19%)
# Processing index 370 out of 7105 (5.21%)
# chicago_police has multiple candidates 2
# Processing index 371 out of 7105 (5.22%)
# Processing index 372 out of 7105 (5.24%)
# Processing index 373 out of 7105 (5.25%)
# Processing index 374 out of 7105 (5.26%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 375 out of 7105 (5.28%)
# cleveland_police has multiple candidates 2
# Processing index 376 out of 7105 (5.29%)
# Processing index 377 out of 7105 (5.31%)
# Trying fuzzy match for  dc_police
# No match for dc_police
# Processing index 378 out of 7105 (5.32%)
# Processing index 379 out of 7105 (5.33%)
# Processing index 380 out of 7105 (5.35%)
# Processing index 381 out of 7105 (5.36%)
# Processing index 382 out of 7105 (5.38%)
# Processing index 383 out of 7105 (5.39%)
# chicago_police has multiple candidates 2
# Processing index 384 out of 7105 (5.4%)
# Processing index 385 out of 7105 (5.42%)
# Processing index 386 out of 7105 (5.43%)
# Processing index 387 out of 7105 (5.45%)
# Processing index 388 out of 7105 (5.46%)
# Processing index 389 out of 7105 (5.48%)
# Processing index 390 out of 7105 (5.49%)
# maryland_state_police has multiple candidates 7
# Processing index 391 out of 7105 (5.5%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 392 out of 7105 (5.52%)
# kentucky_state_police has multiple candidates 2
# Processing index 393 out of 7105 (5.53%)
# Processing index 394 out of 7105 (5.55%)
# Processing index 395 out of 7105 (5.56%)
# tucson_police has multiple candidates 2
# Processing index 396 out of 7105 (5.57%)
# Processing index 397 out of 7105 (5.59%)
# kentucky_state_police has multiple candidates 2
# Processing index 398 out of 7105 (5.6%)
# Processing index 399 out of 7105 (5.62%)
# Processing index 400 out of 7105 (5.63%)
# bernalillo_sheriff has multiple candidates 3
# Processing index 401 out of 7105 (5.64%)
# Processing index 402 out of 7105 (5.66%)
# Processing index 403 out of 7105 (5.67%)
# Trying fuzzy match for  us_indian_affairs
# No match for us_indian_affairs
# Processing index 404 out of 7105 (5.69%)
# Processing index 405 out of 7105 (5.7%)
# Processing index 406 out of 7105 (5.71%)
# lafayette_police has multiple candidates 3
# Processing index 407 out of 7105 (5.73%)
# Processing index 408 out of 7105 (5.74%)
# Processing index 409 out of 7105 (5.76%)
# Processing index 410 out of 7105 (5.77%)
# Processing index 411 out of 7105 (5.78%)
# Processing index 412 out of 7105 (5.8%)
# Processing index 413 out of 7105 (5.81%)
# Processing index 414 out of 7105 (5.83%)
# Processing index 415 out of 7105 (5.84%)
# Processing index 416 out of 7105 (5.86%)
# Processing index 417 out of 7105 (5.87%)
# Processing index 418 out of 7105 (5.88%)
# Processing index 419 out of 7105 (5.9%)
# Processing index 420 out of 7105 (5.91%)
# Processing index 421 out of 7105 (5.93%)
# Processing index 422 out of 7105 (5.94%)
# Processing index 423 out of 7105 (5.95%)
# Processing index 424 out of 7105 (5.97%)
# Processing index 425 out of 7105 (5.98%)
# las_vegas_police has multiple candidates 18
# Processing index 426 out of 7105 (6.0%)
# Processing index 427 out of 7105 (6.01%)
# Processing index 428 out of 7105 (6.02%)
# Processing index 429 out of 7105 (6.04%)
# Processing index 430 out of 7105 (6.05%)
# oak_ridge_police has multiple candidates 2
# Processing index 431 out of 7105 (6.07%)
# Processing index 432 out of 7105 (6.08%)
# Processing index 433 out of 7105 (6.09%)
# Trying fuzzy match for  burlington_northern_santa_fe_railway_police
# No match for burlington_northern_santa_fe_railway_police
# Processing index 434 out of 7105 (6.11%)
# Processing index 435 out of 7105 (6.12%)
# broward_sheriff has multiple candidates 3
# Processing index 436 out of 7105 (6.14%)
# Processing index 437 out of 7105 (6.15%)
# Processing index 438 out of 7105 (6.16%)
# Processing index 439 out of 7105 (6.18%)
# Processing index 440 out of 7105 (6.19%)
# Processing index 441 out of 7105 (6.21%)
# Processing index 442 out of 7105 (6.22%)
# Processing index 443 out of 7105 (6.24%)
# las_vegas_police has multiple candidates 18
# Processing index 444 out of 7105 (6.25%)
# pierce_sheriff has multiple candidates 3
# Processing index 445 out of 7105 (6.26%)
# tulsa_police has multiple candidates 4
# Processing index 446 out of 7105 (6.28%)
# Processing index 447 out of 7105 (6.29%)
# Processing index 448 out of 7105 (6.31%)
# tulsa_police has multiple candidates 4
# Processing index 449 out of 7105 (6.32%)
# Processing index 450 out of 7105 (6.33%)
# Processing index 451 out of 7105 (6.35%)
# Trying fuzzy match for  st_croix_falls_police
# Processing index 452 out of 7105 (6.36%)
# Processing index 453 out of 7105 (6.38%)
# Processing index 454 out of 7105 (6.39%)
# st_petersburg_police has multiple candidates 2
# Processing index 455 out of 7105 (6.4%)
# Trying fuzzy match for  georgia_state_patrol
# No match for georgia_state_patrol
# Processing index 456 out of 7105 (6.42%)
# hills_sheriff has multiple candidates 3
# Processing index 457 out of 7105 (6.43%)
# Processing index 458 out of 7105 (6.45%)
# orange_sheriff has multiple candidates 2
# Processing index 459 out of 7105 (6.46%)
# Trying fuzzy match for  ventnor_city_police
# Processing index 460 out of 7105 (6.47%)
# Processing index 461 out of 7105 (6.49%)
# Processing index 462 out of 7105 (6.5%)
# Processing index 463 out of 7105 (6.52%)
# Processing index 464 out of 7105 (6.53%)
# Processing index 465 out of 7105 (6.54%)
# Processing index 466 out of 7105 (6.56%)
# Processing index 467 out of 7105 (6.57%)
# Processing index 468 out of 7105 (6.59%)
# Processing index 469 out of 7105 (6.6%)
# Processing index 470 out of 7105 (6.62%)
# Processing index 471 out of 7105 (6.63%)
# Processing index 472 out of 7105 (6.64%)
# Processing index 473 out of 7105 (6.66%)
# miami_dade_police has multiple candidates 5
# Processing index 474 out of 7105 (6.67%)
# Processing index 475 out of 7105 (6.69%)
# Processing index 476 out of 7105 (6.7%)
# Processing index 477 out of 7105 (6.71%)
# Processing index 478 out of 7105 (6.73%)
# Processing index 479 out of 7105 (6.74%)
# Processing index 480 out of 7105 (6.76%)
# Processing index 481 out of 7105 (6.77%)
# north_las_vegas_police has multiple candidates 3
# Processing index 482 out of 7105 (6.78%)
# Processing index 483 out of 7105 (6.8%)
# Processing index 484 out of 7105 (6.81%)
# lake_charles_police has multiple candidates 3
# Processing index 485 out of 7105 (6.83%)
# Processing index 486 out of 7105 (6.84%)
# Processing index 487 out of 7105 (6.85%)
# Processing index 488 out of 7105 (6.87%)
# Processing index 489 out of 7105 (6.88%)
# Processing index 490 out of 7105 (6.9%)
# city_new_york_police has multiple candidates 2
# Processing index 491 out of 7105 (6.91%)
# chicago_police has multiple candidates 2
# Processing index 492 out of 7105 (6.92%)
# Processing index 493 out of 7105 (6.94%)
# Processing index 494 out of 7105 (6.95%)
# Processing index 495 out of 7105 (6.97%)
# Processing index 496 out of 7105 (6.98%)
# Processing index 497 out of 7105 (7.0%)
# Processing index 498 out of 7105 (7.01%)
# miami_dade_police has multiple candidates 5
# Processing index 499 out of 7105 (7.02%)
# Processing index 500 out of 7105 (7.04%)
# Processing index 501 out of 7105 (7.05%)
# Processing index 502 out of 7105 (7.07%)
# Processing index 503 out of 7105 (7.08%)
# Processing index 504 out of 7105 (7.09%)
# Processing index 505 out of 7105 (7.11%)
# Processing index 506 out of 7105 (7.12%)
# Processing index 507 out of 7105 (7.14%)
# Processing index 508 out of 7105 (7.15%)
# baton_rouge_police has multiple candidates 6
# Processing index 509 out of 7105 (7.16%)
# Processing index 510 out of 7105 (7.18%)
# indianapolis_police has multiple candidates 2
# Processing index 511 out of 7105 (7.19%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 512 out of 7105 (7.21%)
# Processing index 513 out of 7105 (7.22%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 514 out of 7105 (7.23%)
# Processing index 515 out of 7105 (7.25%)
# king_sheriff has multiple candidates 6
# Processing index 516 out of 7105 (7.26%)
# Processing index 517 out of 7105 (7.28%)
# lee_sheriff has multiple candidates 2
# Processing index 518 out of 7105 (7.29%)
# Processing index 519 out of 7105 (7.3%)
# kentucky_state_police has multiple candidates 2
# Processing index 520 out of 7105 (7.32%)
# Trying fuzzy match for  tennessee_highway_patrol
# No match for tennessee_highway_patrol
# Processing index 521 out of 7105 (7.33%)
# Processing index 522 out of 7105 (7.35%)
# Processing index 523 out of 7105 (7.36%)
# Processing index 524 out of 7105 (7.38%)
# Processing index 525 out of 7105 (7.39%)
# Processing index 526 out of 7105 (7.4%)
# Processing index 527 out of 7105 (7.42%)
# Processing index 528 out of 7105 (7.43%)
# Processing index 529 out of 7105 (7.45%)
# cobb_police has multiple candidates 5
# Processing index 530 out of 7105 (7.46%)
# Processing index 531 out of 7105 (7.47%)
# Processing index 532 out of 7105 (7.49%)
# Processing index 533 out of 7105 (7.5%)
# Processing index 534 out of 7105 (7.52%)
# las_vegas_police has multiple candidates 18
# Processing index 535 out of 7105 (7.53%)
# colorado_state_patrol has multiple candidates 2
# Processing index 536 out of 7105 (7.54%)
# Processing index 537 out of 7105 (7.56%)
# Trying fuzzy match for  dc_police
# No match for dc_police
# Processing index 538 out of 7105 (7.57%)
# Processing index 539 out of 7105 (7.59%)
# Processing index 540 out of 7105 (7.6%)
# Processing index 541 out of 7105 (7.61%)
# Processing index 542 out of 7105 (7.63%)
# reno_police has multiple candidates 2
# Uh oh! Multiple parent agencies! Please identify the ORI for [reno_police] ([Reno Police Department])
# --> 31780 | Reno (Lamar Co.) Police Department | reno_police | TX13910 | TX1391000
# --> 32319 | Reno (Parker Co.) Police Department | reno_police | -1 | TX1840700
# We will go one-by-one. Please select the match you want to use
# Using index  31780
# Processing index 543 out of 7105 (7.64%)
# Processing index 544 out of 7105 (7.66%)
# Trying fuzzy match for  us_customs_and_border_protection
# No match for us_customs_and_border_protection
# Processing index 545 out of 7105 (7.67%)
# Processing index 546 out of 7105 (7.68%)
# Processing index 547 out of 7105 (7.7%)
# louisiana_state_police has multiple candidates 14
# Processing index 548 out of 7105 (7.71%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 549 out of 7105 (7.73%)
# Processing index 550 out of 7105 (7.74%)
# Processing index 551 out of 7105 (7.76%)
# Processing index 552 out of 7105 (7.77%)
# harris_constable_precinct_3 has multiple candidates 2
# Uh oh! Multiple parent agencies! Please identify the ORI for [harris_constable_precinct_3] ([Harris County Constable's Office Precinct 3])
# --> 31309 | Harris County Constable Pct. 3 | harris_constable_precinct_3 | -1 | -1
# --> 31315 | Harris County Constables Office Pct 3 | harris_constable_precinct_3 | -1 | TX1014800
# We will go one-by-one. Please select the match you want to use
# Using index  31315
# Processing index 553 out of 7105 (7.78%)
# Trying fuzzy match for  ramapo_police
# Processing index 554 out of 7105 (7.8%)
# pennsylvania_state_police has multiple candidates 28
# Processing index 555 out of 7105 (7.81%)
# Trying fuzzy match for  us__veterans_affairs
# No match for us__veterans_affairs
# Processing index 556 out of 7105 (7.83%)
# Processing index 557 out of 7105 (7.84%)
# brunswick_police has multiple candidates 2
# Processing index 558 out of 7105 (7.85%)
# Processing index 559 out of 7105 (7.87%)
# Processing index 560 out of 7105 (7.88%)
# Processing index 561 out of 7105 (7.9%)
# Processing index 562 out of 7105 (7.91%)
# Processing index 563 out of 7105 (7.92%)
# phoenix_police has multiple candidates 4
# Processing index 564 out of 7105 (7.94%)
# maricopa_sheriff has multiple candidates 4
# Processing index 565 out of 7105 (7.95%)
# Processing index 566 out of 7105 (7.97%)
# Processing index 567 out of 7105 (7.98%)
# Processing index 568 out of 7105 (7.99%)
# Processing index 569 out of 7105 (8.01%)
# Processing index 570 out of 7105 (8.02%)
# Processing index 571 out of 7105 (8.04%)
# Trying fuzzy match for  johnson_city
# No match for johnson_city
# Processing index 572 out of 7105 (8.05%)
# Processing index 573 out of 7105 (8.06%)
# Processing index 574 out of 7105 (8.08%)
# Processing index 575 out of 7105 (8.09%)
# pennsylvania_state_police has multiple candidates 28
# Processing index 576 out of 7105 (8.11%)
# Processing index 577 out of 7105 (8.12%)
# arkansas_state_police has multiple candidates 6
# Processing index 578 out of 7105 (8.14%)
# Processing index 579 out of 7105 (8.15%)
# Processing index 580 out of 7105 (8.16%)
# Processing index 581 out of 7105 (8.18%)
# Processing index 582 out of 7105 (8.19%)
# Processing index 583 out of 7105 (8.21%)
# Processing index 584 out of 7105 (8.22%)
# Processing index 585 out of 7105 (8.23%)
# cobb_police has multiple candidates 5
# Processing index 586 out of 7105 (8.25%)
# Processing index 587 out of 7105 (8.26%)
# Processing index 588 out of 7105 (8.28%)
# Processing index 589 out of 7105 (8.29%)
# Processing index 590 out of 7105 (8.3%)
# Processing index 591 out of 7105 (8.32%)
# Processing index 592 out of 7105 (8.33%)
# Processing index 593 out of 7105 (8.35%)
# Processing index 594 out of 7105 (8.36%)
# Processing index 595 out of 7105 (8.37%)
# alaska_state_troopers has multiple candidates 3
# Processing index 596 out of 7105 (8.39%)
# Processing index 597 out of 7105 (8.4%)
# Processing index 598 out of 7105 (8.42%)
# Processing index 599 out of 7105 (8.43%)
# las_vegas_police has multiple candidates 18
# Processing index 600 out of 7105 (8.44%)
# Processing index 601 out of 7105 (8.46%)
# calcasieu_parish_sheriff has multiple candidates 3
# Processing index 602 out of 7105 (8.47%)
# new_york_state_police has multiple candidates 3
# Processing index 603 out of 7105 (8.49%)
# Processing index 604 out of 7105 (8.5%)
# Processing index 605 out of 7105 (8.52%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 606 out of 7105 (8.53%)
# Processing index 607 out of 7105 (8.54%)
# billings_police has multiple candidates 3
# Processing index 608 out of 7105 (8.56%)
# Processing index 609 out of 7105 (8.57%)
# Processing index 610 out of 7105 (8.59%)
# Processing index 611 out of 7105 (8.6%)
# Processing index 612 out of 7105 (8.61%)
# Processing index 613 out of 7105 (8.63%)
# phoenix_police has multiple candidates 4
# Processing index 614 out of 7105 (8.64%)
# Processing index 615 out of 7105 (8.66%)
# Processing index 616 out of 7105 (8.67%)
# Processing index 617 out of 7105 (8.68%)
# Processing index 618 out of 7105 (8.7%)
# Processing index 619 out of 7105 (8.71%)
# Processing index 620 out of 7105 (8.73%)
# indiana_state_police has multiple candidates 2
# Processing index 621 out of 7105 (8.74%)
# atlanta_police has multiple candidates 4
# Processing index 622 out of 7105 (8.75%)
# Processing index 623 out of 7105 (8.77%)
# Processing index 624 out of 7105 (8.78%)
# Processing index 625 out of 7105 (8.8%)
# Processing index 626 out of 7105 (8.81%)
# polk_sheriff has multiple candidates 2
# Processing index 627 out of 7105 (8.82%)
# Processing index 628 out of 7105 (8.84%)
# Processing index 629 out of 7105 (8.85%)
# orange_sheriff has multiple candidates 2
# Processing index 630 out of 7105 (8.87%)
# Processing index 631 out of 7105 (8.88%)
# Processing index 632 out of 7105 (8.9%)
# las_cruces_police has multiple candidates 2
# Processing index 633 out of 7105 (8.91%)
# Processing index 634 out of 7105 (8.92%)
# Processing index 635 out of 7105 (8.94%)
# Processing index 636 out of 7105 (8.95%)
# Processing index 637 out of 7105 (8.97%)
# Processing index 638 out of 7105 (8.98%)
# Processing index 639 out of 7105 (8.99%)
# arizona__police has multiple candidates 3
# Processing index 640 out of 7105 (9.01%)
# Processing index 641 out of 7105 (9.02%)
# Trying fuzzy match for  metro_transit_police
# No match for metro_transit_police
# Processing index 642 out of 7105 (9.04%)
# Processing index 643 out of 7105 (9.05%)
# Processing index 644 out of 7105 (9.06%)
# Processing index 645 out of 7105 (9.08%)
# aiken_sheriff has multiple candidates 2
# Processing index 646 out of 7105 (9.09%)
# Processing index 647 out of 7105 (9.11%)
# Processing index 648 out of 7105 (9.12%)
# Processing index 649 out of 7105 (9.13%)
# Processing index 650 out of 7105 (9.15%)
# city_new_york_police has multiple candidates 2
# Processing index 651 out of 7105 (9.16%)
# Processing index 652 out of 7105 (9.18%)
# las_vegas_police has multiple candidates 18
# Processing index 653 out of 7105 (9.19%)
# davenport_police has multiple candidates 2
# Processing index 654 out of 7105 (9.2%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 655 out of 7105 (9.22%)
# Processing index 656 out of 7105 (9.23%)
# Processing index 657 out of 7105 (9.25%)
# Processing index 658 out of 7105 (9.26%)
# Processing index 659 out of 7105 (9.28%)
# Processing index 660 out of 7105 (9.29%)
# Processing index 661 out of 7105 (9.3%)
# Processing index 662 out of 7105 (9.32%)
# Processing index 663 out of 7105 (9.33%)
# Processing index 664 out of 7105 (9.35%)
# philadelphia_police has multiple candidates 101
# Processing index 665 out of 7105 (9.36%)
# Processing index 666 out of 7105 (9.37%)
# Processing index 667 out of 7105 (9.39%)
# Processing index 668 out of 7105 (9.4%)
# Processing index 669 out of 7105 (9.42%)
# arapahoe_sheriff has multiple candidates 2
# Processing index 670 out of 7105 (9.43%)
# Processing index 671 out of 7105 (9.44%)
# Processing index 672 out of 7105 (9.46%)
# Processing index 673 out of 7105 (9.47%)
# Processing index 674 out of 7105 (9.49%)
# Processing index 675 out of 7105 (9.5%)
# jefferson_parish_sheriff has multiple candidates 11
# Processing index 676 out of 7105 (9.51%)
# Processing index 677 out of 7105 (9.53%)
# Processing index 678 out of 7105 (9.54%)
# Processing index 679 out of 7105 (9.56%)
# Processing index 680 out of 7105 (9.57%)
# Processing index 681 out of 7105 (9.58%)
# Processing index 682 out of 7105 (9.6%)
# new_york_state_police has multiple candidates 3
# Processing index 683 out of 7105 (9.61%)
# Processing index 684 out of 7105 (9.63%)
# Processing index 685 out of 7105 (9.64%)
# Processing index 686 out of 7105 (9.66%)
# orange_sheriff has multiple candidates 2
# Processing index 687 out of 7105 (9.67%)
# arizona__police has multiple candidates 3
# Processing index 688 out of 7105 (9.68%)
# washington_sheriff has multiple candidates 2
# Processing index 689 out of 7105 (9.7%)
# Processing index 690 out of 7105 (9.71%)
# Processing index 691 out of 7105 (9.73%)
# Processing index 692 out of 7105 (9.74%)
# Processing index 693 out of 7105 (9.75%)
# Processing index 694 out of 7105 (9.77%)
# Processing index 695 out of 7105 (9.78%)
# Processing index 696 out of 7105 (9.8%)
# Processing index 697 out of 7105 (9.81%)
# Processing index 698 out of 7105 (9.82%)
# new_jersey_state_police has multiple candidates 32
# Processing index 699 out of 7105 (9.84%)
# Trying fuzzy match for  us__defense
# No match for us__defense
# Processing index 700 out of 7105 (9.85%)
# Processing index 701 out of 7105 (9.87%)
# phoenix_police has multiple candidates 4
# Processing index 702 out of 7105 (9.88%)
# Processing index 703 out of 7105 (9.89%)
# Processing index 704 out of 7105 (9.91%)
# Processing index 705 out of 7105 (9.92%)
# Processing index 706 out of 7105 (9.94%)
# Trying fuzzy match for  hayward_police_police
# No match for hayward_police_police
# Processing index 707 out of 7105 (9.95%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 708 out of 7105 (9.96%)
# city_new_york_police has multiple candidates 2
# Processing index 709 out of 7105 (9.98%)
# Processing index 710 out of 7105 (9.99%)
# Processing index 711 out of 7105 (10.01%)
# seattle_police has multiple candidates 10
# Processing index 712 out of 7105 (10.02%)
# Processing index 713 out of 7105 (10.04%)
# Processing index 714 out of 7105 (10.05%)
# Processing index 715 out of 7105 (10.06%)
# east_baton_rouge_parish_sheriff has multiple candidates 5
# Processing index 716 out of 7105 (10.08%)
# Processing index 717 out of 7105 (10.09%)
# Processing index 718 out of 7105 (10.11%)
# Processing index 719 out of 7105 (10.12%)
# Processing index 720 out of 7105 (10.13%)
# baltimore_police has multiple candidates 4
# Uh oh! Multiple parent agencies! Please identify the ORI for [baltimore_police] ([Baltimore County Police Department])
# --> 12337 | Baltimore County Police Department | baltimore_police | MD00301 | MD0030100
# --> 12586 | Baltimore Police Department | baltimore_police | MDBPD00 | MDBPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  12337
# Processing index 721 out of 7105 (10.15%)
# Processing index 722 out of 7105 (10.16%)
# Processing index 723 out of 7105 (10.18%)
# Trying fuzzy match for  us_marshals
# No match for us_marshals
# Processing index 724 out of 7105 (10.19%)
# alameda_sheriff has multiple candidates 2
# Processing index 725 out of 7105 (10.2%)
# Processing index 726 out of 7105 (10.22%)
# Processing index 727 out of 7105 (10.23%)
# berkeley_sheriff has multiple candidates 2
# Processing index 728 out of 7105 (10.25%)
# Processing index 729 out of 7105 (10.26%)
# Processing index 730 out of 7105 (10.27%)
# Processing index 731 out of 7105 (10.29%)
# union_township_police has multiple candidates 2
# Uh oh! Multiple parent agencies! Please identify the ORI for [union_township_police] ([Union Township Police Department])
# --> 22535 | Union Township Police Department | union_township_police | OH01316 | OH0131600
# --> 23139 | Union Township Police Department | union_township_police | OH04515 | OH0451500
# We will go one-by-one. Please select the match you want to use
# Using index  22535
# Processing index 732 out of 7105 (10.3%)
# rapid_city_police has multiple candidates 2
# Processing index 733 out of 7105 (10.32%)
# raleigh_police has multiple candidates 3
# Processing index 734 out of 7105 (10.33%)
# Processing index 735 out of 7105 (10.34%)
# city_new_york_police has multiple candidates 2
# Processing index 736 out of 7105 (10.36%)
# volusia_sheriff has multiple candidates 2
# Processing index 737 out of 7105 (10.37%)
# Processing index 738 out of 7105 (10.39%)
# Processing index 739 out of 7105 (10.4%)
# Processing index 740 out of 7105 (10.42%)
# Processing index 741 out of 7105 (10.43%)
# colorado_state_patrol has multiple candidates 2
# Processing index 742 out of 7105 (10.44%)
# Processing index 743 out of 7105 (10.46%)
# Processing index 744 out of 7105 (10.47%)
# Processing index 745 out of 7105 (10.49%)
# Processing index 746 out of 7105 (10.5%)
# Processing index 747 out of 7105 (10.51%)
# Processing index 748 out of 7105 (10.53%)
# delaware_state_police has multiple candidates 2
# Processing index 749 out of 7105 (10.54%)
# Processing index 750 out of 7105 (10.56%)
# montgomery_police has multiple candidates 3
# Processing index 751 out of 7105 (10.57%)
# Processing index 752 out of 7105 (10.58%)
# indianapolis_police has multiple candidates 2
# Processing index 753 out of 7105 (10.6%)
# indianapolis_police has multiple candidates 2
# Processing index 754 out of 7105 (10.61%)
# Processing index 755 out of 7105 (10.63%)
# Processing index 756 out of 7105 (10.64%)
# Processing index 757 out of 7105 (10.65%)
# Processing index 758 out of 7105 (10.67%)
# Processing index 759 out of 7105 (10.68%)
# phoenix_police has multiple candidates 4
# Processing index 760 out of 7105 (10.7%)
# las_vegas_police has multiple candidates 18
# Processing index 761 out of 7105 (10.71%)
# Processing index 762 out of 7105 (10.72%)
# Processing index 763 out of 7105 (10.74%)
# Processing index 764 out of 7105 (10.75%)
# Processing index 765 out of 7105 (10.77%)
# Processing index 766 out of 7105 (10.78%)
# Processing index 767 out of 7105 (10.8%)
# Processing index 768 out of 7105 (10.81%)
# Processing index 769 out of 7105 (10.82%)
# Processing index 770 out of 7105 (10.84%)
# Processing index 771 out of 7105 (10.85%)
# Processing index 772 out of 7105 (10.87%)
# Processing index 773 out of 7105 (10.88%)
# Processing index 774 out of 7105 (10.89%)
# Processing index 775 out of 7105 (10.91%)
# Processing index 776 out of 7105 (10.92%)
# little_rock_police has multiple candidates 2
# Processing index 777 out of 7105 (10.94%)
# little_rock_police has multiple candidates 2
# Processing index 778 out of 7105 (10.95%)
# Processing index 779 out of 7105 (10.96%)
# Processing index 780 out of 7105 (10.98%)
# Processing index 781 out of 7105 (10.99%)
# Processing index 782 out of 7105 (11.01%)
# Processing index 783 out of 7105 (11.02%)
# Processing index 784 out of 7105 (11.03%)
# Processing index 785 out of 7105 (11.05%)
# kentucky_state_police has multiple candidates 2
# Processing index 786 out of 7105 (11.06%)
# Processing index 787 out of 7105 (11.08%)
# Trying fuzzy match for  sikeston__police
# Processing index 788 out of 7105 (11.09%)
# las_vegas_police has multiple candidates 18
# Processing index 789 out of 7105 (11.1%)
# indiana_state_police has multiple candidates 2
# Processing index 790 out of 7105 (11.12%)
# seattle_police has multiple candidates 10
# Processing index 791 out of 7105 (11.13%)
# Trying fuzzy match for  pennslyvania_state_police
# pennslyvania_state_police has multiple candidates 28
# Processing index 792 out of 7105 (11.15%)
# tampa_police has multiple candidates 2
# Processing index 793 out of 7105 (11.16%)
# phoenix_police has multiple candidates 4
# Processing index 794 out of 7105 (11.18%)
# Processing index 795 out of 7105 (11.19%)
# Processing index 796 out of 7105 (11.2%)
# Processing index 797 out of 7105 (11.22%)
# Processing index 798 out of 7105 (11.23%)
# Processing index 799 out of 7105 (11.25%)
# Processing index 800 out of 7105 (11.26%)
# Processing index 801 out of 7105 (11.27%)
# maine_state_police has multiple candidates 5
# ...
# No match for rancho_cordova_police
# Processing index 5459 out of 7105 (76.83%)
# Processing index 5463 out of 7105 (76.89%)
# Processing index 5468 out of 7105 (76.96%)
# Processing index 5479 out of 7105 (77.11%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 5482 out of 7105 (77.16%)
# Processing index 5488 out of 7105 (77.24%)
# Processing index 5509 out of 7105 (77.54%)
# west_virginia_state_police has multiple candidates 18
# Processing index 5563 out of 7105 (78.3%)
# Trying fuzzy match for  us_drug_enforcement_administration
# No match for us_drug_enforcement_administration
# Processing index 5577 out of 7105 (78.49%)
# Trying fuzzy match for  oregon_police_division
# No match for oregon_police_division
# Processing index 5589 out of 7105 (78.66%)
# Processing index 5629 out of 7105 (79.23%)
# Processing index 5630 out of 7105 (79.24%)
# Processing index 5638 out of 7105 (79.35%)
# Processing index 5647 out of 7105 (79.48%)
# Processing index 5671 out of 7105 (79.82%)
# Processing index 5691 out of 7105 (80.1%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 5700 out of 7105 (80.23%)
# st_louis_police has multiple candidates 3
# Uh oh! Multiple parent agencies! Please identify the ORI for [st_louis_police] ([ St. Louis County Police Department])
# --> 16786 | St. Louis County Police Dept | st_louis_police | MO09500 | MO0950000
# --> 16934 | St. Louis (City) Police Dept | st_louis_police | MOSPD00 | MOSPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  16786
# Processing index 5711 out of 7105 (80.38%)
# Processing index 5716 out of 7105 (80.45%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 5719 out of 7105 (80.49%)
# Processing index 5768 out of 7105 (81.18%)
# Processing index 5791 out of 7105 (81.51%)
# Processing index 5795 out of 7105 (81.56%)
# Processing index 5811 out of 7105 (81.79%)
# arizona__police has multiple candidates 3
# Processing index 5832 out of 7105 (82.08%)
# Processing index 5834 out of 7105 (82.11%)
# st_tammany_parish_sheriff has multiple candidates 4
# Processing index 5836 out of 7105 (82.14%)
# Processing index 5864 out of 7105 (82.53%)
# Processing index 5866 out of 7105 (82.56%)
# alaska_state_troopers has multiple candidates 3
# Processing index 5876 out of 7105 (82.7%)
# indiana_state_police has multiple candidates 2
# Processing index 5884 out of 7105 (82.81%)
# Processing index 5922 out of 7105 (83.35%)
# Processing index 5925 out of 7105 (83.39%)
# Processing index 5926 out of 7105 (83.41%)
# Processing index 5936 out of 7105 (83.55%)
# Processing index 5937 out of 7105 (83.56%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 5943 out of 7105 (83.65%)
# Processing index 5944 out of 7105 (83.66%)
# Processing index 5969 out of 7105 (84.01%)
# Trying fuzzy match for  us_border_patrol
# No match for us_border_patrol
# Processing index 5978 out of 7105 (84.14%)
# Processing index 5988 out of 7105 (84.28%)
# Processing index 6015 out of 7105 (84.66%)
# Processing index 6032 out of 7105 (84.9%)
# Trying fuzzy match for  carroll__sheriff
# No match for carroll__sheriff
# Processing index 6081 out of 7105 (85.59%)
# Processing index 6086 out of 7105 (85.66%)
# Trying fuzzy match for  us_alcohol_tobacco_firearms_and_explosives
# No match for us_alcohol_tobacco_firearms_and_explosives
# Processing index 6089 out of 7105 (85.7%)
# Processing index 6132 out of 7105 (86.31%)
# Processing index 6156 out of 7105 (86.64%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 6190 out of 7105 (87.12%)
# Processing index 6197 out of 7105 (87.22%)
# Processing index 6198 out of 7105 (87.23%)
# Processing index 6215 out of 7105 (87.47%)
# michigan_state_police has multiple candidates 8
# Processing index 6249 out of 7105 (87.95%)
# Processing index 6267 out of 7105 (88.21%)
# Processing index 6283 out of 7105 (88.43%)
# Processing index 6290 out of 7105 (88.53%)
# Processing index 6291 out of 7105 (88.54%)
# Processing index 6303 out of 7105 (88.71%)
# Trying fuzzy match for  kansas_capitol_police
# No match for kansas_capitol_police
# Processing index 6304 out of 7105 (88.73%)
# Processing index 6311 out of 7105 (88.82%)
# Processing index 6325 out of 7105 (89.02%)
# Processing index 6328 out of 7105 (89.06%)
# Processing index 6333 out of 7105 (89.13%)
# tampa_police has multiple candidates 2
# Processing index 6379 out of 7105 (89.78%)
# Processing index 6410 out of 7105 (90.22%)
# Processing index 6421 out of 7105 (90.37%)
# Processing index 6427 out of 7105 (90.46%)
# Trying fuzzy match for  ackson_police
# Processing index 6447 out of 7105 (90.74%)
# Processing index 6448 out of 7105 (90.75%)
# Processing index 6454 out of 7105 (90.84%)
# Trying fuzzy match for  texas__criminal_justice
# No match for texas__criminal_justice
# Processing index 6459 out of 7105 (90.91%)
# Processing index 6473 out of 7105 (91.1%)
# Processing index 6484 out of 7105 (91.26%)
# Processing index 6497 out of 7105 (91.44%)
# chandler_police has multiple candidates 2
# Processing index 6500 out of 7105 (91.48%)
# Processing index 6512 out of 7105 (91.65%)
# Processing index 6515 out of 7105 (91.7%)
# Processing index 6518 out of 7105 (91.74%)
# Processing index 6521 out of 7105 (91.78%)
# Processing index 6541 out of 7105 (92.06%)
# Processing index 6548 out of 7105 (92.16%)
# Processing index 6557 out of 7105 (92.29%)
# Processing index 6560 out of 7105 (92.33%)
# st_louis_police has multiple candidates 3
# Uh oh! Multiple parent agencies! Please identify the ORI for [st_louis_police] ([St. Louis County Police Departmen])
# --> 16786 | St. Louis County Police Dept | st_louis_police | MO09500 | MO0950000
# --> 16934 | St. Louis (City) Police Dept | st_louis_police | MOSPD00 | MOSPD0000
# We will go one-by-one. Please select the match you want to use
# Using index  16786
# Processing index 6573 out of 7105 (92.51%)
# Processing index 6595 out of 7105 (92.82%)
# Trying fuzzy match for  utah_highway_patrol
# No match for utah_highway_patrol
# Processing index 6596 out of 7105 (92.84%)
# Processing index 6614 out of 7105 (93.09%)
# Processing index 6615 out of 7105 (93.1%)
# Trying fuzzy match for  us__homeland_security
# No match for us__homeland_security
# Processing index 6630 out of 7105 (93.31%)
# Processing index 6639 out of 7105 (93.44%)
# Processing index 6644 out of 7105 (93.51%)
# Processing index 6656 out of 7105 (93.68%)
# arkansas_state_police has multiple candidates 6
# Processing index 6676 out of 7105 (93.96%)
# Trying fuzzy match for  creek_sheriff�s
# Processing index 6679 out of 7105 (94.0%)
# idaho_state_police has multiple candidates 2
# Processing index 6683 out of 7105 (94.06%)
# shelby_sheriff has multiple candidates 2
# Processing index 6687 out of 7105 (94.12%)
# Processing index 6690 out of 7105 (94.16%)
# Processing index 6693 out of 7105 (94.2%)
# porterdale_police has multiple candidates 2
# Processing index 6700 out of 7105 (94.3%)
# Processing index 6712 out of 7105 (94.47%)
# Processing index 6761 out of 7105 (95.16%)
# Processing index 6810 out of 7105 (95.85%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 6828 out of 7105 (96.1%)
# Processing index 6840 out of 7105 (96.27%)
# Processing index 6888 out of 7105 (96.95%)
# Processing index 6936 out of 7105 (97.62%)
# Trying fuzzy match for  us_border_patrol
# No match for us_border_patrol
# Processing index 6952 out of 7105 (97.85%)
# Processing index 6995 out of 7105 (98.45%)
# Trying fuzzy match for  clark_s_sheriff
# Processing index 7052 out of 7105 (99.25%)
# Processing index 7060 out of 7105 (99.37%)
# Processing index 7064 out of 7105 (99.42%)
# Processing index 7073 out of 7105 (99.55%)
# Processing index 7080 out of 7105 (99.65%)
# Processing index 7081 out of 7105 (99.66%)
# Processing index 7085 out of 7105 (99.72%)
# las_vegas_police has multiple candidates 18
# Processing index 7097 out of 7105 (99.89%)
# Trying fuzzy match for  texas_rangers
# No match for texas_rangers
# Processing index 7101 out of 7105 (99.94%)
# Trying fuzzy match for  wasketa_police
# No match for wasketa_police
#
# ********************************************************************************
# MATCHING AGENCIES IN [agency_responsible_3] WITH AN ORI
# ********************************************************************************
#
# Processing index 55 out of 7105 (0.77%)
# Processing index 63 out of 7105 (0.89%)
# west_virginia_state_police has multiple candidates 18
# Processing index 78 out of 7105 (1.1%)
# Processing index 169 out of 7105 (2.38%)
# new_mexico_state_police has multiple candidates 2
# Processing index 173 out of 7105 (2.43%)
# new_mexico_state_police has multiple candidates 2
# Processing index 200 out of 7105 (2.81%)
# Processing index 275 out of 7105 (3.87%)
# indiana_state_police has multiple candidates 2
# Processing index 311 out of 7105 (4.38%)
# Processing index 403 out of 7105 (5.67%)
# Processing index 417 out of 7105 (5.87%)
# Processing index 542 out of 7105 (7.63%)
# Processing index 614 out of 7105 (8.64%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 625 out of 7105 (8.8%)
# Processing index 627 out of 7105 (8.82%)
# oregon_state_police has multiple candidates 7
# Processing index 673 out of 7105 (9.47%)
# new_york_state_police has multiple candidates 3
# Processing index 722 out of 7105 (10.16%)
# Processing index 734 out of 7105 (10.33%)
# Processing index 798 out of 7105 (11.23%)
# Trying fuzzy match for  wayne_police
# No match for wayne_police
# Processing index 819 out of 7105 (11.53%)
# Processing index 822 out of 7105 (11.57%)
# Processing index 834 out of 7105 (11.74%)
# Processing index 846 out of 7105 (11.91%)
# Processing index 875 out of 7105 (12.32%)
# Processing index 884 out of 7105 (12.44%)
# Processing index 902 out of 7105 (12.7%)
# Trying fuzzy match for  us_indian_affairs
# Processing index 976 out of 7105 (13.74%)
# Processing index 1000 out of 7105 (14.07%)
# Processing index 1048 out of 7105 (14.75%)
# Processing index 1142 out of 7105 (16.07%)
# Trying fuzzy match for  nevada_highway_patrol
# No match for nevada_highway_patrol
# Processing index 1220 out of 7105 (17.17%)
# Trying fuzzy match for  us_alcohol_tobacco_firearms_and_explosives
# No match for us_alcohol_tobacco_firearms_and_explosives
# Processing index 1259 out of 7105 (17.72%)
# Processing index 1261 out of 7105 (17.75%)
# Processing index 1264 out of 7105 (17.79%)
# Processing index 1265 out of 7105 (17.8%)
# Processing index 1266 out of 7105 (17.82%)
# Processing index 1267 out of 7105 (17.83%)
# Processing index 1277 out of 7105 (17.97%)
# Processing index 1320 out of 7105 (18.58%)
# Processing index 1385 out of 7105 (19.49%)
# Processing index 1419 out of 7105 (19.97%)
# idaho_state_police has multiple candidates 2
# Processing index 1467 out of 7105 (20.65%)
# Processing index 1521 out of 7105 (21.41%)
# Processing index 1543 out of 7105 (21.72%)
# Processing index 1676 out of 7105 (23.59%)
# indiana_state_police has multiple candidates 2
# Processing index 1706 out of 7105 (24.01%)
# Processing index 1726 out of 7105 (24.29%)
# Processing index 1760 out of 7105 (24.77%)
# las_cruces_police has multiple candidates 2
# Processing index 1908 out of 7105 (26.85%)
# Processing index 1929 out of 7105 (27.15%)
# Processing index 1963 out of 7105 (27.63%)
# louisiana_state_police has multiple candidates 14
# Processing index 1969 out of 7105 (27.71%)
# Processing index 1976 out of 7105 (27.81%)
# Processing index 2257 out of 7105 (31.77%)
# new_york_state_police has multiple candidates 3
# Processing index 2274 out of 7105 (32.01%)
# Trying fuzzy match for  mississippi_highway_patrol
# Processing index 2406 out of 7105 (33.86%)
# Trying fuzzy match for  california__fish_and_wildlife
# No match for california__fish_and_wildlife
# Processing index 2420 out of 7105 (34.06%)
# Processing index 2445 out of 7105 (34.41%)
# Processing index 2477 out of 7105 (34.86%)
# Processing index 2591 out of 7105 (36.47%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 2645 out of 7105 (37.23%)
# Processing index 2834 out of 7105 (39.89%)
# oregon_state_police has multiple candidates 7
# Processing index 2901 out of 7105 (40.83%)
# Processing index 2944 out of 7105 (41.44%)
# Processing index 3173 out of 7105 (44.66%)
# Processing index 3175 out of 7105 (44.69%)
# Processing index 3351 out of 7105 (47.16%)
# Processing index 3554 out of 7105 (50.02%)
# Processing index 3557 out of 7105 (50.06%)
# Processing index 3769 out of 7105 (53.05%)
# Processing index 4071 out of 7105 (57.3%)
# Processing index 4236 out of 7105 (59.62%)
# Trying fuzzy match for  us_drug_enforcement_administration
# No match for us_drug_enforcement_administration
# Processing index 4447 out of 7105 (62.59%)
# Trying fuzzy match for  georgia_state_patrol
# No match for georgia_state_patrol
# Processing index 4561 out of 7105 (64.19%)
# Processing index 4733 out of 7105 (66.62%)
# Processing index 4969 out of 7105 (69.94%)
# Processing index 5389 out of 7105 (75.85%)
# Processing index 5412 out of 7105 (76.17%)
# Processing index 5434 out of 7105 (76.48%)
# Trying fuzzy match for  ocean_sheriff\s
# Processing index 5463 out of 7105 (76.89%)
# Processing index 5834 out of 7105 (82.11%)
# Processing index 5926 out of 7105 (83.41%)
# Processing index 5988 out of 7105 (84.28%)
# louisiana_state_police has multiple candidates 14
# Processing index 6215 out of 7105 (87.47%)
# Processing index 6328 out of 7105 (89.06%)
# illinois_state_police has multiple candidates 10
# Processing index 6410 out of 7105 (90.22%)
# Processing index 6448 out of 7105 (90.75%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 6497 out of 7105 (91.44%)
# mesa_police has multiple candidates 2
# Processing index 6500 out of 7105 (91.48%)
# chandler_police has multiple candidates 2
# Processing index 6560 out of 7105 (92.33%)
# Processing index 6596 out of 7105 (92.84%)
# Trying fuzzy match for  ranson_city_police
# Processing index 6679 out of 7105 (94.0%)
# Processing index 6712 out of 7105 (94.47%)
# Trying fuzzy match for  michigan__corrections
# No match for michigan__corrections
# Processing index 6810 out of 7105 (95.85%)
# Trying fuzzy match for  federal_investigation
# No match for federal_investigation
# Processing index 7060 out of 7105 (99.37%)
# Processing index 7080 out of 7105 (99.65%)
# reno_police has multiple candidates 2
# Processing index 7101 out of 7105 (99.94%)
# indiana_state_police has multiple candidates 2
#
# ********************************************************************************
# MATCHING AGENCIES IN [agency_responsible_4] WITH AN ORI
# ********************************************************************************
#
# Processing index 403 out of 7105 (5.67%)
# Processing index 627 out of 7105 (8.82%)
# Processing index 673 out of 7105 (9.47%)
# Processing index 846 out of 7105 (11.91%)
# terre_haute_police has multiple candidates 2
# Processing index 976 out of 7105 (13.74%)
# Processing index 1048 out of 7105 (14.75%)
# Processing index 1220 out of 7105 (17.17%)
# Trying fuzzy match for  us_federal_investigation
# No match for us_federal_investigation
# Processing index 1385 out of 7105 (19.49%)
# Trying fuzzy match for  cherokee_nation_marshals_service
# Processing index 1676 out of 7105 (23.59%)
# Processing index 1726 out of 7105 (24.29%)
# Processing index 1908 out of 7105 (26.85%)
# Processing index 1976 out of 7105 (27.81%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
# Processing index 2445 out of 7105 (34.41%)
# Processing index 4733 out of 7105 (66.62%)
# Processing index 5389 out of 7105 (75.85%)
# Processing index 6215 out of 7105 (87.47%)
# Processing index 6500 out of 7105 (91.48%)
# mesa_police has multiple candidates 2
# Processing index 6712 out of 7105 (94.47%)
# Trying fuzzy match for  us_marshals_service
# No match for us_marshals_service
#
# ********************************************************************************
# MATCHING AGENCIES IN [agency_responsible_5] WITH AN ORI
# ********************************************************************************
#
# Processing index 1676 out of 7105 (23.59%)
# Processing index 4733 out of 7105 (66.62%)

# %% [markdown]
# ### 5.4 | OPTIONAL: Inspects data for manual corrections

# %% [markdown]
# When applying manual corrections, we needed to pair (i) the LEA without an ORI code in DM-FS (ii) the correct LEA in the Crosswalk file. Thus, we needed to identify two indices: the original index in DM-FS (of the LEA with a missing ORI) and the corrected index in the crosswalk file. These two functions helped us manually lookup these indices so we can add them to our dictionary in the next section.
#
# This code is not essential unless the user wishes to initiate additional manual corrections. It can be safely skipped.

# %%
# Want to get an ORI via a CSLLEA index? 
# Type the LEA name you wish to query and copy its index
lea_name_to_query = "UMATILLA TRIBAL POLICE DEPARTMENT"
df_ori[df_ori["LEA_NAME"].str.strip().str.startswith(lea_name_to_query)]
# Out:
#             FSTATE  FCOUNTY   FPLACE  FIPS_ST  FIPS_COUNTY     FIPS  \
# 25426  (41) Oregon     59.0  57150.0     41.0         59.0  41059.0
#
#             ORI9     ORI7                                           LEA_NAME  \
# 25426  OR0301200  OR03012  UMATILLA TRIBAL POLICE DEPARTMENT             ...
#
#             UA STATENAME                         COUNTYNAME  \
# 25426  68428.0    Oregon  UMATILLA
#
#                                                   UANAME             PARTOF  \
# 25426  Pendleton, OR Urban Cluster                   ...  (0) Parent agency
#
#                             AGCYTYPE              SUBTYPE1  \
# 25426  (000) Local police department  (888) Not applicable
#
#                    SUBTYPE2        GOVID  \
# 25426  (888) Not applicable  387030001.0
#
#                                                  LG_NAME  \
# 25426  CONFEDERATED TRIBES OF THE UMATILLA INDIAN RES...
#
#                        address_corrected  \
# 25426  UMATILLA TRIBAL POLICE DEPARTMENT
#
#                                             ADDRESS_NAME  \
# 25426  UMATILLA TRIBAL POLICE DEPARTMENT             ...
#
#                                   ADDRESS_STR1  \
# 25426  73320 HIGHWAY 331
#
#                                          ADDRESS_STR2  \
# 25426  PO BOX 638
#
#                      ADDRESS_CITY ADDRESS_STATE ADDRESS_ZIP  \
# 25426  PENDLETON                             OR       97801
#
#                         REPORT_FLAG  CSLLEA08_ID  LEMAS_ID    U_STATENO  \
# 25426  (1) ORI reported 1+ offenses   12085690.0      -1.0  (36) Oregon
#
#        U_CNTY U_POPGRP  U_TPOP  LG_POPULATION  \
# 25426    -2.0        7     0.0    999999999.0
#
#                                     CSLLEA_SUB  \
# 25426  (1) Include record to appoximate CSLLEA
#
#                                                  COMMENT  INTPTLAT  INTPTLONG  \
# 25426                                                ...   45.5912 -118.73388
#
#        CONGDIST1                                       CONGDIST2_18  \
# 25426        2.0                                                ...
#
#                                  DISTNAME  SOURCE_CSLLEA2008  SOURCE_UCR2010  \
# 25426  District of Oregon                                1.0             1.0
#
#        SOURCE_UCR2011  SOURCE_UCR2012  SOURCE_NCIC2012  SOURCE_VENDOR  \
# 25426             1.0             1.0              1.0            1.0
#
#              LEA_NAME_CLEANED
# 25426  umatilla_tribal_police

# %%
# Lists all the LEAs to check - i.e., those that don't have anything in their ORI code (not -1 --- literally nothing, showing it's uninitialized)
agency_responsible_col = "agency_responsible_1"
LEAs_to_check = df_civ.query(f"{agency_responsible_col}_ORI7.isnull() & {agency_responsible_col} != 'N/A'")
LEAs_to_check = LEAs_to_check.sort_values(by=['state_of_death', agency_responsible_col], ascending=[True, True]) # Sorts by (i) state and (ii) LEA

# Prints results, all the LEAs with an undefined ORI code
print(f"LEAs to check = {LEAs_to_check.shape[0]}")
LEAs_to_check.loc[: , [agency_responsible_col, "state_of_death"] ].head(300)
# Out:
# LEAs to check = 313
#                                    agency_responsible_1        state_of_death
# 3110                     Alabama Law Enforcement Agency               Alabama
# 5768                     Alabama Law Enforcement Agency               Alabama
# 6113                     Alabama Law Enforcement Agency               Alabama
# 707                U.S. Federal Bureau of Investigation               Alabama
# 4733                              U.S. Marshals Service               Alabama
# 1143                 Alaska Department of Public Safety                Alaska
# 330                                       Border Patrol               Arizona
# 163                                Navajo Nation Police               Arizona
# 6370                               Navajo Nation Police               Arizona
# 6956                    Navajo Nation Police Department               Arizona
# 1863                           Navajo Police Department               Arizona
# 3215             Pima County Adult Probation Department               Arizona
# 6433              Riverside County Sheriff's Department               Arizona
# 5074                                 U.S. Border Patrol               Arizona
# 3498                 U.S. Customs and Border Protection               Arizona
# 1959               U.S. Department of Homeland Security               Arizona
# 90                 U.S. Federal Bureau of Investigation               Arizona
# 511                U.S. Federal Bureau of Investigation               Arizona
# 3397                                U.S. Forest Service               Arizona
# 3890                                U.S. Forest Service               Arizona
# 2968           U.S. Immigration and Customs Enforcement               Arizona
# 3210           U.S. Immigration and Customs Enforcement               Arizona
# 336                               U.S. Marshals Service               Arizona
# 1018                              U.S. Marshals Service               Arizona
# 2397                              U.S. Marshals Service               Arizona
# 2692                              U.S. Marshals Service               Arizona
# 6500                              U.S. Marshals Service               Arizona
# 2519                         U.S. National Park Service               Arizona
# 6656                         "Memphis Police Department              Arkansas
# 6198        Arkansas Department of Community Correction              Arkansas
# 1434                 Arkansas Department of Corrections              Arkansas
# 4798                     Shelby County Sheriff's Office              Arkansas
# 654                               U.S. Marshals Service              Arkansas
# 3784                         U.S. National Park Service              Arkansas
# 2977                    bastian County Sheriff's Office              Arkansas
# 3403           Bay Area Rapid Transit Police Department            California
# 6251         California Department of Fish and Wildlife            California
# 1752                      California State Park Rangers            California
# 706                    Hayward Police Police Department            California
# 820                   Lancaster County Sheriff's Office            California
# 1398            Los Angeles County Probation Department            California
# 4983                         Temecula Police Department            California
# 5170                         Temecula Police Department            California
# 225                                  U.S. Border Patrol            California
# 6613                                 U.S. Border Patrol            California
# 544                  U.S. Customs and Border Protection            California
# 1815                 U.S. Customs and Border Protection            California
# 4044                 U.S. Customs and Border Protection            California
# 5741                 U.S. Customs and Border Protection            California
# 5053               U.S. Department of Homeland Security            California
# 1304               U.S. Drug Enforcement Administration            California
# 3381               U.S. Federal Bureau of Investigation            California
# 3382               U.S. Federal Bureau of Investigation            California
# 4842               U.S. Federal Bureau of Investigation            California
# 5755           U.S. Immigration and Customs Enforcement            California
# 1437                              U.S. Marshals Service            California
# 2061                              U.S. Marshals Service            California
# 2430                              U.S. Marshals Service            California
# 5703  University of California Merced Police Department            California
# 6922                    Valley Transportation Authority            California
# 433   Burlington Northern Santa Fe Railway Police De...              Colorado
# 2918                     U.S. Bureau of Land Management              Colorado
# 3041                              U.S. Marshals Service              Colorado
# 5689                                            Unknown              Colorado
# 4133                    Federal Bureau of Investigation              Delaware
# 5677                 Baltimore County Police Department  District Of Columbia
# 377                   DC Metropolitan Police Department  District Of Columbia
# 1498                  DC Metropolitan Police Department  District Of Columbia
# 4300                  DC Metropolitan Police Department  District Of Columbia
# 4504                  DC Metropolitan Police Department  District Of Columbia
# 4794                  DC Metropolitan Police Department  District Of Columbia
# 5010                  DC Metropolitan Police Department  District Of Columbia
# 5453                  DC Metropolitan Police Department  District Of Columbia
# 5657                  DC Metropolitan Police Department  District Of Columbia
# 5729                  DC Metropolitan Police Department  District Of Columbia
# 4988                    Metro Transit Police Department  District Of Columbia
# 6394                    Metro Transit Police Department  District Of Columbia
# 7071                    Metro Transit Police Department  District Of Columbia
# 2875                     Metropolitan Police Department  District Of Columbia
# 5708           Prince George's County Police Department  District Of Columbia
# 3267                 U.S. Customs and Border Protection               Florida
# 5502               U.S. Department of Homeland Security               Florida
# 182                               U.S. Marshals Service               Florida
# 1839                              U.S. Marshals Service               Florida
# 3028                              U.S. Marshals Service               Florida
# 6333                              U.S. Marshals Service               Florida
# 4539                       Peach County Drug Task Force               Georgia
# 1422                           Athens Police Department               Georgia
# 22                    Georgia Department of Corrections               Georgia
# 251                                Georgia State Patrol               Georgia
# 455                                Georgia State Patrol               Georgia
# 1094                               Georgia State Patrol               Georgia
# 2083                               Georgia State Patrol               Georgia
# 2343                               Georgia State Patrol               Georgia
# 2480                               Georgia State Patrol               Georgia
# 2975                               Georgia State Patrol               Georgia
# 3416                               Georgia State Patrol               Georgia
# 4228                               Georgia State Patrol               Georgia
# 4291                               Georgia State Patrol               Georgia
# 4673                               Georgia State Patrol               Georgia
# 5018                               Georgia State Patrol               Georgia
# 5471                               Georgia State Patrol               Georgia
# 87                           Savannah Police Department               Georgia
# 1095                         Savannah Police Department               Georgia
# 1881                         Savannah Police Department               Georgia
# 2728                         Savannah Police Department               Georgia
# 6706                         Savannah Police Department               Georgia
# 4131               U.S. Federal Bureau of Investigation               Georgia
# 2106           U.S. Immigration and Customs Enforcement               Georgia
# 8                                 U.S. Marshals Service               Georgia
# 309                               U.S. Marshals Service               Georgia
# 2326                              U.S. Marshals Service               Georgia
# 4609                              U.S. Marshals Service               Georgia
# 4901                              U.S. Marshals Service               Georgia
# 6217                              U.S. Marshals Service                Hawaii
# 4360                           Amtrak Police Department              Illinois
# 3104   U.S. Department of Housing and Urban Development              Illinois
# 2904               U.S. Drug Enforcement Administration              Illinois
# 5141               U.S. Federal Bureau of Investigation              Illinois
# 327                               U.S. Marshals Service              Illinois
# 3319                              U.S. Marshals Service              Illinois
# 5108                              U.S. Marshals Service              Illinois
# 3756                    U.S. Federal Protective Service               Indiana
# 5270                               Colfax Town Marshall               Indiana
# 3810                            Crete Police Department               Indiana
# 138        Indiana State Police Emergency Response Team               Indiana
# 2891  U.S. Bureau of Alcohol Tobacco Firearms and Ex...               Indiana
# 928                                   Iowa State Patrol                  Iowa
# 3003                                  Iowa State Patrol                  Iowa
# 3351                                  Iowa State Patrol                  Iowa
# 5341                              U.S. Marshals Service                Kansas
# 5925                              U.S. Marshals Service                Kansas
# 6028                              U.S. Marshals Service                Kansas
# 6805                             U.S. Marshals Service                 Kansas
# 5424                              U.S. Marshals Service              Kentucky
# 3019                     West Buechel Police Department              Kentucky
# 3852  Louisiana Department of Public Safety & Correc...             Louisiana
# 2711                            Shreveport City Marshal             Louisiana
# 99                         U.S. Bureau of Investigation             Louisiana
# 6177               U.S. Federal Bureau of Investigation             Louisiana
# 1654                              U.S. Marshals Service             Louisiana
# 5840                              U.S. Marshals Service             Louisiana
# 6403                              U.S. Marshals Service             Louisiana
# 6839                             U.S. Marshals Service              Louisiana
# 4345                                 Maine State Police                 Maine
# 4351                                 Maine State Police                 Maine
# 6335  National Security Administration Police Depart...              Maryland
# 245                           Pennsylvania State Police              Maryland
# 1045                              U.S. Marshals Service              Maryland
# 3073                                   U.S. Park Police              Maryland
# 1409                Bristol (Indiana) Police Department              Michigan
# 302                U.S. Federal Bureau of Investigation              Michigan
# 5508               U.S. Federal Bureau of Investigation              Michigan
# 6255           U.S. Immigration and Customs Enforcement              Michigan
# 4235                              U.S. Marshals Service              Michigan
# 641                     Metro Transit Police Department             Minnesota
# 2098                          Memphis Police Department           Mississippi
# 1598                            Tippah County Constable           Mississippi
# 723                                       U.S. Marshals           Mississippi
# 4976                              U.S. Marshals Service           Mississippi
# 196                     Drug Enforcement Administration              Missouri
# 5076               U.S. Drug Enforcement Administration              Missouri
# 907                U.S. Federal Bureau of Investigation              Missouri
# 999                U.S. Federal Bureau of Investigation              Missouri
# 2059                              U.S. Marshals Service              Missouri
# 6390                              U.S. Marshals Service              Missouri
# 5049                            Butte Police Department               Montana
# 1221                              U.S. Marshals Service               Montana
# 1297                              U.S. Marshals Service               Montana
# 1442  Burlington Northern Santa Fe Railway Police De...              Nebraska
# 6420                              U.S. Marshals Service              Nebraska
# 2774                   Nevada Department of Corrections                Nevada
# 7085                              U.S. Marshals Service                Nevada
# 3985                         Massachusetts State Police         New Hampshire
# 2003               U.S. Drug Enforcement Administration         New Hampshire
# 2884                Deptford Township Police Department            New Jersey
# 1408                           Howell Police Department            New Jersey
# 6677                           Howell Police Department            New Jersey
# 6174            Monmouth County Emergency Response Team            New Jersey
# 3729               New Jersey Department of Corrections            New Jersey
# 4875               New Jersey Department of Corrections            New Jersey
# 6550               New Jersey Department of Corrections            New Jersey
# 6861                       Old Bridge Police Department            New Jersey
# 548                               U.S. Marshals Service            New Jersey
# 1760                                 U.S. Border Patrol            New Mexico
# 4354                               Navajo Nation Police            New Mexico
# 2186                           Navajo Police Department            New Mexico
# 5279                 Pueblo of Laguna Police Department            New Mexico
# 1355                                 U.S. Border Patrol            New Mexico
# 50                   U.S. Customs and Border Protection            New Mexico
# 1794               U.S. Federal Bureau of Investigation            New Mexico
# 2892                              U.S. Marshals Service            New Mexico
# 5120                              U.S. Marshals Service            New Mexico
# 5391                             U.S. Marshals Service             New Mexico
# 913                          U.S. National Park Service            New Mexico
# 2333                         Fredonia Police Department              New York
# 2334                         Fredonia Police Department              New York
# 5734                        New Paltz Police Department              New York
# 4776                      New York State Court Officers              New York
# 1165  New York State Department of Corrections and C...              New York
# 5861                          Potsdam Police Department              New York
# 6093                                 U.S. Border Patrol              New York
# 1814               U.S. Federal Bureau of Investigation              New York
# 88                                U.S. Marshals Service              New York
# 6410               U.S. Department of Homeland Security        North Carolina
# 2045                   Hertford County Sheriff's Office        North Carolina
# 1328        North Carolina Department of Motor Vehicles        North Carolina
# 6669        North Carolina Department of Motor Vehicles        North Carolina
# 2120               U.S. Federal Bureau of Investigation        North Carolina
# 2640           U.S. Immigration and Customs Enforcement        North Carolina
# 605                               U.S. Marshals Service        North Carolina
# 1214                              U.S. Marshals Service        North Carolina
# 3627                        York County Sheriffs Office        North Carolina
# 6767                           Bureau of Indian Affairs          North Dakota
# 6115               Spirit Lake Tribal Police Department          North Dakota
# 403                       U.S. Bureau of Indian Affairs          North Dakota
# 3614                      U.S. Bureau of Indian Affairs          North Dakota
# 1041                              U.S. Marshals Service          North Dakota
# 3781  Adult Probation Department Jefferson County Co...                  Ohio
# 5610             Cleveland Metroparks Ranger Department                  Ohio
# 2079               U.S. Federal Bureau of Investigation                  Ohio
# 6870  U.S. Marshals Service Violent Fugitive Task Force                  Ohio
# 6547                U.S. Department of Veterans Affairs              Oklahoma
# 1345                              U.S. Marshals Service              Oklahoma
# 2235                              U.S. Marshals Service              Oklahoma
# 2943                              U.S. Marshals Service              Oklahoma
# 3306                             U.S. Marshals Service               Oklahoma
# 6960                            Kelso Police Department                Oregon
# 6825                                            Unknown                Oregon
# 1658  Bureau of Narcotics Investigations of the Offi...          Pennsylvania
# 2559                  German Township Police Department          Pennsylvania
# 1682                       Penn Hills Police Department          Pennsylvania
# 5516                       Pennsylvania State Constable          Pennsylvania
# 5454          Port Authority of Allegheny County Police          Pennsylvania
# 5855               U.S. Federal Bureau of Investigation          Pennsylvania
# 3345                              U.S. Marshals Service          Pennsylvania
# 3346                              U.S. Marshals Service          Pennsylvania
# 4538                              U.S. Marshals Service          Pennsylvania
# 6581                              U.S. Marshals Service          Pennsylvania
# 2302                                            Unknown          Pennsylvania
# 125                       Upper Darby Police Department          Pennsylvania
# 6871                      Upper Darby Police Department          Pennsylvania
# 5692  Spartanburg Methodist College Campus Safety De...        South Carolina
# 5089                Pine Ridge Tribal Police Department          South Dakota
# 7006       Rosebud Sioux Tribe Law Enforcement Services          South Dakota
# 2217                              U.S. Marshals Service          South Dakota
# 5538                              U.S. Marshals Service          South Dakota
# 571                             Johnson City Department             Tennessee
# 520                            Tennessee Highway Patrol             Tennessee
# 2103                           Tennessee Highway Patrol             Tennessee
# 3720                           Tennessee Highway Patrol             Tennessee
# 1777                              U.S. Marshals Service             Tennessee
# 4873                              U.S. Marshals Service             Tennessee
# 5531                              U.S. Marshals Service             Tennessee
# 6498                              U.S. Marshals Service             Tennessee
# 1220                                 U.S. Border Patrol                 Texas
# 6639                              U.S. Marshals Service                 Texas
# 3080                   Corpus Christi Police Department                 Texas
# 6508                    Harris County Attorney's Office                 Texas
# 5376                 Harris County Constable Precinct 6                 Texas
# 5634                              Jal Police Department                 Texas
# 2431                 San Antonio Park Police Department                 Texas
# 3016                 San Antonio Park Police Department                 Texas
# 6971                 San Antonio Park Police Department                 Texas
# 3361                                 U.S. Border Patrol                 Texas
# 5442                                 U.S. Border Patrol                 Texas
# 6534                                 U.S. Border Patrol                 Texas
# 6538                                 U.S. Border Patrol                 Texas
# 6615                                 U.S. Border Patrol                 Texas
# 6548  U.S. Bureau of Alcohol Tobacco Firearms and Ex...                 Texas
# 2576                     U.S. Customs and Border Patrol                 Texas
# 2585                     U.S. Customs and Border Patrol                 Texas
# 2586                     U.S. Customs and Border Patrol                 Texas
# 2612                     U.S. Customs and Border Patrol                 Texas
# 2928                     U.S. Customs and Border Patrol                 Texas
# 1508                 U.S. Customs and Border Protection                 Texas
# 699                          U.S. Department of Defense                 Texas
# 1140                U.S. Department of Veterans Affairs                 Texas
# 513                U.S. Federal Bureau of Investigation                 Texas
# 1653               U.S. Federal Bureau of Investigation                 Texas
# 3324               U.S. Federal Bureau of Investigation                 Texas
# 1759                    U.S. Federal Protective Service                 Texas
# 2996           U.S. Immigration and Customs Enforcement                 Texas
# 5332                              U.S. Marshals Service                 Texas
# 6454                              U.S. Marshals Service                 Texas
# 2117                          U.S. Navy Security Forces                 Texas
# 3255                  Montezuma County Sheriff's Office                  Utah
# 6751                  Montezuma County Sheriff's Office                  Utah
# 3161  U.S. Bureau of Alcohol Tobacco Firearms and Ex...                  Utah
# 1443                               U.S. Marshal Service                  Utah
# 1040                              U.S. Marshals Service                  Utah
# 391                              U.S. Marshals Service                   Utah
# 3233                Immigration and Customs Enforcement              Virginia
# 537                   DC Metropolitan Police Department              Virginia
# 4905                     Hawkins County Sheriffs Office              Virginia
# 1044                Montgomery County Police Department              Virginia
# 3526                                     US Park Police              Virginia
# 3986                       United States Capitol Police              Virginia
# 6865                         Lewiston Police Department            Washington
# 91                    Spokane County Detention Services            Washington

# %% [markdown]
# ### 5.5 | Initialize Manual Corrections to Make

# %%
# Creates a dict to store manual corrections for agency_responsible_1, agency_responsible_2, etc.

manual_corrections_dict = {}

# %%
# ****************************************
# CORRECTIONS FOR AGENCY_RESPONSIBLE_1
# ****************************************

manual_corrections = {
    3110 : [420, "Alabama Law Enforcement Agency was mapped to Alabama Department of Public Safety: Former was formed in 2015, whereas latter was what came before it."],
    6113 : [420, "Alabama Law Enforcement Agency was mapped to Alabama Department of Public Safety: Former was formed in 2015, whereas latter was what came before it."],
    5768 : [420, "Alabama Law Enforcement Agency was mapped to Alabama Department of Public Safety: Former was formed in 2015, whereas latter was what came before it."],
    1143 : [592, "Alaska State Troopers were involved, a subset of the Department of Public Safety. Thus, the ORI code of the State Trooper HQ was used."],
    3215 : [820, "Pima County Probation Department doesn't have its own ORI. Thus, we usd the ORI of the HQ of Arizona's Department of Corrections, which manages probation broadly."],
    6433 : [2351, "While death occured in AZ, the sheriff appears to be from CA."],
    6656 : [1170, "Memphis, Arkansas doesn't exist. Instead, there's West Memphis, Arkansas. Thus, we used the ORI code for West Memphis Police Department."],
    4798 : [16846, "The state of death, Arkansas, does not have a Shelby County. The neighboring state, MO, does, so its ORI was taken, assuming that the Shelby sheriff's office from MO was involved."],
    2977 : [1514, "\"bastian\" county appears to be a typo for Sebastian County, Arkansas, thus Sebastian County Sheriff's ORI was used."],
    3403 : [1712, "Bay Area Rapid Transit doesn't have an ORI. It was mapped onto an agency titled 'SF Bay Rapid Transit', which appears to be the same thing."],
    6251 : [2371, "Mapped onto headquarters of California Department of Fish and Game"],
    706 : [1614, "Mapped onto Hayward Police Department. There's a typo in the name (i.e., police was spelled twice) that prevented it from automatically matching."],
    820 : [2071, "Lancaster, CA does not have its own sheriff's department. Instead, it is part of Los Angeles County, so it uses its sheriff."],	
    1398 : [2089, "LA County Probation has no ORI code. Instead, we used LA County Department of Corrections."],
    4983 : [2349, "Mapped onto Temecula PD in California."],
    5170 : [2349, "Mapped onto Temecula PD in California."],
    1752 : [2387, "Mapped onto HQ of California Park Rangers"], 
    5703 : [2147, "Mapped onto University of California, Mercedees Police "],
    433 : [3092, "There's only one transportation authority in Colorado with an ORI code. Thus, it was used."],
    5677 : [12336, "Not automatically matched because the victim perished in DC, not Maryland. This is now corrected."],
    4988 : [3782, "This is the only transit authority in Washington, DC, with an ORI code. Thus, its ORI code was used."],
    6394 : [3782, "This is the only transit authority in Washington, DC, with an ORI code. Thus, its ORI code was used."],
    7071 : [3782, "This is the only transit authority in Washington, DC, with an ORI code. Thus, its ORI code was used."],
    377 : [3783, "Mapped onto the DC Metro Police Department."],
    1498 : [3783, "Mapped onto the DC Metro Police Department."],
    4300 : [3783, "Mapped onto the DC Metro Police Department."],
    4504 : [3783, "Mapped onto the DC Metro Police Department."],
    4794 : [3783, "Mapped onto the DC Metro Police Department."],
    5010 : [3783, "Mapped onto the DC Metro Police Department."],
    5453 : [3783, "Mapped onto the DC Metro Police Department."],
    5657 : [3783, "Mapped onto the DC Metro Police Department."],
    5729 : [3783, "Mapped onto the DC Metro Police Department."],
    2875 : [3783, "Mapped onto the DC Metro Police Department."],
    537 : [3783, "Mapped onto the DC Metro Police Department."],
    5708 : [33948, "The victim perished in DC, not in VA. Thus, the program couldn't automatically link Prince George's County PD to its proper ORI. This is now fixed."],
    1422 : [5404, "Athens, GA does not have its own police department. Instead, it is merged with Clarke County. Thus, the ORI of Athens-Clarke County PD was used."],
    251 : [5661, "HQ of Georgia State Patrol was used."],
    455 : [5661, "HQ of Georgia State Patrol was used."],
    1094 : [5661, "HQ of Georgia State Patrol was used."],
    2083 : [5661, "HQ of Georgia State Patrol was used."],
    2343 : [5661, "HQ of Georgia State Patrol was used."],
    2480 : [5661, "HQ of Georgia State Patrol was used."],
    3416 : [5661, "HQ of Georgia State Patrol was used."],
    3416 : [5661, "HQ of Georgia State Patrol was used."],
    4228 : [5661, "HQ of Georgia State Patrol was used."],
    4291 : [5661, "HQ of Georgia State Patrol was used."],
    4673 : [5661, "HQ of Georgia State Patrol was used."],
    5018 : [5661, "HQ of Georgia State Patrol was used."],
    2975 : [5661, "HQ of Georgia State Patrol was used."],
    5471 : [5661, "HQ of Georgia State Patrol was used."],
    22 : [5668, "There's two ORI codes associated with the GA Department of Corrections. The investigative arm was the only one with an ORI7 and ORI9, thus it was used."],
    87 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    1095 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    1881 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    2728 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    6706 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    4360 : [3738, "Amtrak Police is an LEA with federal jurisdiction. Amtrak's HQ is in Delaware, thus, the ORI was set to its HQ."],
    5270 : [8179, "Colfax Town Marshal is apparently the name of the highest ranked police officer in Colfax, Indiana. Thus, the ORI of the police station was used."],
    3810 : [7998, "Indiana does not have a Crete Police Departments. It's neighboring state, Illinois, does; hence, the ORI from IL was used."],
    138 : [8536, "There's no ORI code associated with the Indiana State Police's emergency response department. Instead, the ORI of Indiana State Police HQ was used."],
    928 : [9334, "HQ of Iowa State Patrol was used."],
    3003 : [9334, "HQ of Iowa State Patrol was used."],
    3351 : [9334, "HQ of Iowa State Patrol was used."], 
    3019 : [10626, "There is no ORI code for West Buechel Police anywhere in the country. However, there is one code for Buechel police, and it's in Kentucky. Thus, it is assumed that the Buechel ORI also corresponds to the West Beuchel one. "],
    2711 : [11259, "The Shreveport Marshal has his own police department, which this ORI points to."],
    4345 : [12056, "Mapped to Maine State Police."],
    4351 : [12056, "Mapped to Maine State Police."],
    245 : [26467, "Victim died to Penn State Police in Maryland, hence, the program could not automatically link the ORI. This has been corrected."],
    1409 : [8246, "Victim perished in Michigan, yet Bristol PD is from Indianna, preventing program from linking ORI. This has been fixed."],
    641 : [14664, "There's only one transit police in Minnesota associated with an ORI. Thus, the Minnesota Transit Police was linked to this ORI."],
    2098 : [15273, "Mapped Memphis Police, MS to Village of Memphis Police, MS."],
    5049 : [17134, "There is no Butte PD. Instead, there's a police department that oversees the Butte-Silver Bowe area stationed in Butte. This is where the ORI was taken from."],
    2774 : [17768, "Nevada Department of Corrections does not have an ORI. However, it's headquartered in Carson City, and a Nevada Prison is headquartered there. Thus, the ORI of the latter was used."],
    3985 : [12963, "Victim perished in New Hampshire, not MA, hence, the program was not able to automatically detect MA State Police. This has been fixed."],
    2994 : [18463, "Depford Police doesn't have 'township' in its name, hence it was corrected via the proper ORI code."],
    1408 : [18742, "ORI Code Points to Howell Township Police, NJ, which is assumed to be the same as Howell Police, NJ"],
    6677 : [18742, "ORI Code Points to Howell Township Police, NJ, which is assumed to be the same as Howell Police, NJ"],
    3729 : [18588, "New Jersey Department of Corrections only appears once, in the Internal Affair Unit at its HQ in Trenton. Thus, that ORI code was used."],
    4875 : [18588, "New Jersey Department of Corrections only appears once, in the Internal Affair Unit at its HQ in Trenton. Thus, that ORI code was used."],
    6550 : [18588, "New Jersey Department of Corrections only appears once, in the Internal Affair Unit at its HQ in Trenton. Thus, that ORI code was used."],
    6861 : [18696, "Old Bridge Police, NJ doens't exist, but Old Bridge Township Police, NJ, does. Hence, the ORI code of the latter was used."],
    2884 : [18463, "Mapped onto Deptford Police. The \"Township\" was missing from the name in the CSLLEA, hence an automatic match couldn't be triggered."],
    5279 : [19086, "Mapped to LAGUNA TRIBAL POLICE department HQ, New Mexico"],
    2333 : [19487, "Fredonia Police, NY, doesn't exist, but Fredonia Village Police, NY does. Thus, the ORI code of the latter was used."],
    2334 : [19487, "Fredonia Police, NY, doesn't exist, but Fredonia Village Police, NY does. Thus, the ORI code of the latter was used."],
    5734 : [20849, "There's both a town and village of New Paltz, NY. The article revealed that the LEA involved was the town, not the village, so its ORI was used."],
    5861 : [20560, "There's no Postdam Police, NY, but there is Postdamn Village PD, NY. Thus, ORI was taken from latter."],
    2045 : [21516, "Mapped to Hertford County Sheriff."],
    6669 : [21970, "Linked to North Carolina DMV."],
    1328 : [21360, "Article confirms that agent responsible is investigator from department of motors & theft. See https://abc11.com/officer-involved-shooting-wilson-assault-robbery-officer/5697568/ "],
    5610 : [22613, "Mapped onto Cleveland Metro Parks."], 
    6960 : [34350, "Mapped to Kelso PD, which is in Washington. There is no Kelso PD in Oregon, and WA contained the closest Kelso PD, hence its ORI was taken."],
    5454 : [25686, "Mapped onto ALLEGHENY PORT AUTHORITY TRANSIT POLICE"],
    1658 : [26021, "The Attorney General has multiple narcotics investigation offices, with no clear headquarters. This death occured in Pittsburg, so we used the ORI of the office that belonged to the closest county: Butler "],
    2559 : [26682, "German Township, PA, only has one LEA with an ORI, so it was used."],
    1682 : [25623, "Penn Hills doesn't have a PD in PA, but Penn Hills Township does. Thus, the latter was used."],
    125 : [26612, "Upper Darby, NY, doesn't have a PD, but Upper Darby Township, NY, does, hence latter was used."],
    6871 : [26612, "Upper Darby, NY, doesn't have a PD, but Upper Darby Township, NY, does, hence latter was used."],
    5692 : [28785, "There are two LEAs in SC for Spartanburg College police. We chose the ORI of the methodist one."],
    571 : [9969, "There was no \"Police\" in \"Johnson City Department\", so this could not be algorithmically matched. This has been corrected."],
    5089 : [29121, "Mapped onto Pine Ridge Law Enforcement, SD."],
    7006 : [29134, "Mapped to ROSEBUD SIOUX TRIBAL POLICE, South Dakota."],
    520 : [29352, "Of all the Tennessee Highway Patrol offices, this was the only one with an ORI7 code. Hence, it was selected."],
    2103 : [29352, "Of all the Tennessee Highway Patrol offices, this was the only one with an ORI7 code. Hence, it was selected."],
    3720 : [29352, "Of all the Tennessee Highway Patrol offices, this was the only one with an ORI7 code. Hence, it was selected."],
    303 : [4509, "Victim perished in Florida, not in Tennessee as the original databases claim. After this correction, Leon County Sheriff's Office could be correctly matched."],
    3080 : [32237, "Article confirms that these officers are actually from Corpus Christi police department: https://www.kristv.com/news/2018/04/16/two-corpus-christi-police-officers-placed-back-on-duty/"],
    5634 : [19140, "Jal Police is in New Mexico, not Texas. The ORI code fixes this"],
    5376 : [31311, "There's multiple Harris County Constables. This ensures the correct precinct - 6 - is linked to this LEA."],
    2431 : [30100, "There is no San Antonio Park Police. There is, however, San Atonio Park Rangers, so the ORI of that LEA was used."],
    3016 : [30100, "There is no San Antonio Park Police. There is, however, San Atonio Park Rangers, so the ORI of that LEA was used."],
    6971 : [30100, "There is no San Antonio Park Police. There is, however, San Atonio Park Rangers, so the ORI of that LEA was used."],
    3255 : [3296, "Although death was in Utah, Sheriff is stationed in Colorado. This ORI fixes that."],
    6751 : [3296, "Although death was in Utah, Sheriff is stationed in Colorado. This ORI fixes that."],
    1044 : [12470, "Death occured in VA, yet death was inflicted by Montgomery County Police in MD. This ORI corrects this."],
    6865 : [6508, "Death occure din WA, yet Lewiston PD is in Idaho. Hence, the Idaho ORI was used"],
    1798 : [34731, "Mapped to fish & wildlife enforcement"],
}

# Adds to Manual Corrections Dict
manual_corrections_dict["agency_responsible_1_corrections"] = manual_corrections

# %%
# ****************************************
# CORRECTIONS FOR AGENCY_RESPONSIBLE_2
# ****************************************

manual_corrections = {
    5451 : [2366, "Mapped to RANCHO CORDOV PD, California"],
    1207 : [8739, "The Lynn Town Marshal appears to be a police officer, and his office is in the Lynn Town Police Department. Thus, they're assumed to be the same thing, and the ORI was therefore mapped to the Lynn Town Police. See https://www.in.gov/towns/lynn/our-staff/"],
    6303 : [9946, "Mapped to capitol police (Kansas / Topeka)"],
    902 : [17021, "Mapped to Blackfeet LES, Montana"],
    2834 : [25426, "Mapped to UMATILLA TRIBAL POLICE DEPARTMENT, Oregon"],
    169 : [17649, "Las Vegas State Polie to Nevada State Police (highway patrol), the Las Vegas division"],
    173 : [17649, "Las Vegas State Polie to Nevada State Police (highway patrol), the Las Vegas division"],
    531 : [15445 , "Brookhaven Police. Even though state of death was in Georgia, assumed the MS Brookhaven Police got involved"],
    673 : [19807, "Le Roy Police to Le Roy Village Police"],
    798 : [18415, "Fairfield Police to Fairfield Township Police"],
    976 : [420, "Alabama Law Enforcement Agency was mapped to Alabama Department of Public Safety: Former was formed in 2015, whereas latter was what came before it."],
    1205 : [33330, "Utah Highway Patorl to Headquarters; we used the headquarters rather than any satellite LEAs"],
    1969 : [33330, "Utah Highway Patorl to Headquarters; we used the headquarters rather than any satellite LEAs"],
    4285 : [33330, "Utah Highway Patorl to Headquarters; we used the headquarters rather than any satellite LEAs"],
    6595 : [33330,"Utah Highway Patorl to Headquarters; we used the headquarters rather than any satellite LEAs"],
    59 : [33330,"Utah Highway Patorl to Headquarters; we used the headquarters rather than any satellite LEAs"],
    1974 : [5661, "Georgia State patrol mapped onto Headquarters in Atlanta"],
    2343 : [5382, "Savannah PD merged with Chatham to form Savannah-Chatham PD. Thus, we mapped Savannah PD onto Savanah-Chatham"],
    2740 : [29325, "Mapped Highway Patrol to Nashville; Nashville office is its headquarters"],
    2821 : [2031, "Death occured in Pomona, yet no CA State Police is in Pomona. Instead, we used California Polytech State Police, which is in Pomona."],
    4907 : [13678, "Only one branch of MI department of corrections has an ORI: Lansing. Thus, we used that."],
    5057 : [12680, "No Fall River PD in state of death (RI). Instead, there was one in MA, so we used that."],
    5577 : [23184, "Oregon police ot Oregon police; nothing to note"],
    6032 : [5349, "Caroll County is in Georgia, so the ORI was mapped appropriately"],
    6454 : [32934, "TX department of corrections is headquartered in Huntsville, so that location was used"],
    7097 : [32806, "Texas Rangers are headquartered in Austin, so that location was used "],
    7101 : [7159, "Wasketa Police doesn't exist, but Watseka does. Thus, it was assumed to be a typo"],
    1976 : [13678,  "Only one branch of MI department of corrections has an ORI: Lansing. Thus, we used that"],
    4907 : [13678,  "Only one branch of MI department of corrections has an ORI: Lansing. Thus, we used that"],
}

# Adds to Manual Corrections Dict
manual_corrections_dict["agency_responsible_2_corrections"] = manual_corrections

# %%
# ****************************************
# CORRECTIONS FOR AGENCY_RESPONSIBLE_3
# ****************************************

manual_corrections = {
    4447 : [5661, "HQ of Georgia State Patrol was used."],
    798 : [18903, "We mapped Wayne Police to Wayne Township Police because the former does not exist."], 
    1142 : [17765, "Mapped Nevada Highway Patrol onto its headquarters."],
    2406 : [2371,  "CA Fish & Wildlife. Multiple offices, so we selected the generic one that wasn't specific to a region."],
    6712 : [13678,  "Only one branch of MI department of corrections has an ORI: Lansing. Thus, we used that"],
}

# Adds to Manual Corrections Dict
manual_corrections_dict["agency_responsible_3_corrections"] = manual_corrections

# %% [markdown]
# AGENCY_RESPONSIBLE_4 and AGENCY_RESPONSIBLE_5 need no manual corrections

# %% [markdown]
# ### 5.6 | Apply Manual Corrections

# %%
# Statistics
total_lea_counter, missing_ori_counter, corrected_ori_counter = 0, 0, 0

# Loops through each agency_responsible column (i.e., #1-#5)
for agency_responsible_num in range(1,6):

    # Inits key vars
    agency_responsible_col = f"agency_responsible_{agency_responsible_num}"
    agency_correction_key = f"{agency_responsible_col}_corrections"
    print(f"\n{'*'*80}\nAPPLYING MANUAL CORRECTIONS TO [{agency_responsible_col}]\n{'*'*80}\n")

    # Stats: Missing values
    total_LEAs = df_civ.query(f"{agency_responsible_col} != 'N/A'").shape[0]
    total_lea_counter += total_LEAs
    missed_LEAs = df_civ.query(f"{agency_responsible_col}_ORI7.isnull() & {agency_responsible_col} != 'N/A'") 
    missing_ori_counter += missed_LEAs.shape[0]    
    print(f"Of the {total_LEAs} agencies in [{agency_responsible_col}], {missed_LEAs.shape[0]} have missing values ({ round( missed_LEAs.shape[0] / total_LEAs * 100, 2)})%")

    # If there's no manual corrections to make, continue with the loop
    if agency_correction_key not in manual_corrections_dict.keys():
        print("No manual matches found.")
        continue
        
    # Stats: Manual Corrections
    manual_corrections = manual_corrections_dict[agency_correction_key]
    corrected_LEAs = len(manual_corrections.keys())
    corrected_ori_counter += corrected_LEAs
    print(f"Applying {corrected_LEAs} manual corrections to the {missed_LEAs.shape[0]} agencies with missing ORIs, thereby remedying {round( corrected_LEAs / missed_LEAs.shape[0] * 100, 2)}% of the data")

    # Goes through each LEA with a missing value (either due to N/A or due to a genuine missing value)
    for index, ind_LEA in missed_LEAs.iterrows():
    
        # Applies manual correctioon, if it exists
        if index in manual_corrections.keys():
            ori_index = manual_corrections[index][0]
            match_to_add = initialize_match_to_add_for_dmfs_civs( df_ori.loc[ ori_index ], agency_responsible_col) 

            # Records manual match for transparency & replication
            record_manual_match("dmfs_civilians", agency_responsible_num, ind_LEA[agency_responsible_col], df_ori.loc[ori_index, "LEA_NAME"].strip().title(), 
                                ori_index, df_ori.loc[ori_index, "ORI7"], df_ori.loc[ori_index, "ORI9"], manual_corrections[index][1])

        # Else, just create a bunch of blank/NA cells to add
        else:
            match_to_add = initialize_match_to_add_for_dmfs_civs( pd.Series(), agency_responsible_col )
            record_manual_match("dmfs_civilians", agency_responsible_num, ind_LEA[agency_responsible_col], "No Match Found", -1, -1, -1, notes="")
        
        # Adds data to DM-FS
        df_civ.loc[index, match_to_add.keys()] =  match_to_add.values()
# Out:
# ********************************************************************************
# APPLYING MANUAL CORRECTIONS TO [agency_responsible_1]
# ********************************************************************************
#
# Of the 7105 agencies in [agency_responsible_1], 313 have missing values (4.41)%
# Applying 116 manual corrections to the 313 agencies with missing ORIs, thereby remedying 37.06% of the data
#
# ********************************************************************************
# APPLYING MANUAL CORRECTIONS TO [agency_responsible_2]
# ********************************************************************************
#
# Of the 467 agencies in [agency_responsible_2], 64 have missing values (13.7)%
# Applying 28 manual corrections to the 64 agencies with missing ORIs, thereby remedying 43.75% of the data
#
# ********************************************************************************
# APPLYING MANUAL CORRECTIONS TO [agency_responsible_3]
# ********************************************************************************
#
# Of the 96 agencies in [agency_responsible_3], 11 have missing values (11.46)%
# Applying 5 manual corrections to the 11 agencies with missing ORIs, thereby remedying 45.45% of the data
#
# ********************************************************************************
# APPLYING MANUAL CORRECTIONS TO [agency_responsible_4]
# ********************************************************************************
#
# Of the 18 agencies in [agency_responsible_4], 3 have missing values (16.67)%
# No manual matches found.
#
# ********************************************************************************
# APPLYING MANUAL CORRECTIONS TO [agency_responsible_5]
# ********************************************************************************
#
# Of the 2 agencies in [agency_responsible_5], 0 have missing values (0.0)%
# No manual matches found.

# %%
# Replaces any remaining missing values relates to ORIs.
# These values only exists if there was no agency_responsible_2, agency_responsible_3, or agency_responsible_4, as there were no agencies by which ORIs & its associated data could be pulled from

print("There are still 'None' values in agency_responsible if agency_responsible was N/A. For example, the ORI code for agency_responsible_3 will be None if there weren't 3 agencies responsible for someone's death")
print("Let's fill these missing values with appropriate indicators.")

for agency_responsible_num in range(1,6):
    agency_responsible_col = f"agency_responsible_{agency_responsible_num}"
    print(f"Applying missing value correction to {agency_responsible_col}")

    # Fill with -1
    df_civ[f"{agency_responsible_col}_ORI7"] = df_civ[f"{agency_responsible_col}_ORI7"].fillna(-1)
    df_civ[f"{agency_responsible_col}_ORI9"] = df_civ[f"{agency_responsible_col}_ORI9"].fillna(-1)
    df_civ[f"{agency_responsible_col}_FIPS_STATE"] = df_civ[f"{agency_responsible_col}_FIPS_STATE"].fillna(-1)
    df_civ[f"{agency_responsible_col}_FIPS_COUNTY"] = df_civ[f"{agency_responsible_col}_FIPS_COUNTY"].fillna(-1)

    # Fill with NA
    df_civ[f"{agency_responsible_col}_LEA_TYPE"] = df_civ[f"{agency_responsible_col}_LEA_TYPE"].fillna("N/A")
    df_civ[f"{agency_responsible_col}_LEA_SUBTYPE_1"] = df_civ[f"{agency_responsible_col}_LEA_SUBTYPE_1"].fillna("N/A")
    df_civ[f"{agency_responsible_col}_LEA_SUBTYPE_2"] = df_civ[f"{agency_responsible_col}_LEA_SUBTYPE_2"].fillna("N/A")
    df_civ[f"{agency_responsible_col}_LOCAL_GOVERNMENT_NAME"] = df_civ[f"{agency_responsible_col}_LOCAL_GOVERNMENT_NAME"].fillna("N/A")
    df_civ[f"{agency_responsible_col}_DISTRICT"] = df_civ[f"{agency_responsible_col}_DISTRICT"].fillna("N/A")
# Out:
# There are still 'None' values in agency_responsible if agency_responsible was N/A. For example, the ORI code for agency_responsible_3 will be None if there weren't 3 agencies responsible for someone's death
# Let's fill these missing values with appropriate indicators.
# Applying missing value correction to agency_responsible_1
# Applying missing value correction to agency_responsible_2
# Applying missing value correction to agency_responsible_3
# Applying missing value correction to agency_responsible_4
# Applying missing value correction to agency_responsible_5

# %%
# Prints total statistics
print(f"Total LEAs = {total_lea_counter} | LEAs with missing ORIs = {missing_ori_counter} ({round(missing_ori_counter/total_lea_counter * 100, 2)}% of total) "
      f"| Corrected LEAs with missing values = {corrected_ori_counter} ({ round( corrected_ori_counter / missing_ori_counter * 100, 2)})% of missing ORIs")
# Out:
# Total LEAs = 7688 | LEAs with missing ORIs = 391 (5.09% of total) | Corrected LEAs with missing values = 149 (38.11)% of missing ORIs

# %% [markdown]
# ### 5.7 | Exports

# %%
# Exports DMFS-CIV via EXPORT_DIR
df_civ.drop(columns=["agency_responsible_1_CLEANED", "agency_responsible_2_CLEANED", "agency_responsible_3_CLEANED", "agency_responsible_4_CLEANED", "agency_responsible_5_CLEANED"], inplace=True)
df_civ.to_csv(f"{EXPORT_DIR}DMFS Civilians.csv", index=False)

# %%
# Also exports any manual corrections we've made
print(f"Exporting manual corrections to [{MATCH_DIR}]")
manual_corrections_df.to_csv(f"{MATCH_DIR}manual_ori_corrections.csv", index = False)
# Out:
# Exporting manual corrections to [res/3.0 - Manual ORI Matches/]

# %%
# Exports Manual Match Dataframe, the one that records all our manual matches (if appliable)

if not USE_PRE_EXISTING_MATCH_DATAFRAME:
    print(f"Saving manual ORI matches to dir [{MATCH_DIR}] so that the manual matches can be replicated in a future run.")
    match_verification_df.to_csv(f"{MATCH_DIR}manual_ori_matches.csv", index = False)
else:
    print("Used pre-existing manual match dataframe. That dataframe was not modified in any way, hence, no saving is necessary.\nNo action is needed. Please proceed.")
# Out:
# Used pre-existing manual match dataframe. That dataframe was not modified in any way, hence, no saving is necessary.
# No action is needed. Please proceed.
